# %%
import numpy as np
from numpy.linalg import eigh
from functools import lru_cache
import tensorcircuit as tc
from collections import Counter
import quimb as qu
from scipy.stats import unitary_group
from scipy.linalg import expm
from scipy.linalg import sqrtm
import logging
from renormalizer import Model, Op, BasisHalfSpin, Mps, Mpo, optimize_mps
import itertools
from itertools import product
import matplotlib.pyplot as plt
print("当前 quimb 版本：", qu.__version__)
# 确保使用合适的计算后端 (tensorflow, jax, numpy)
tc.set_backend("numpy")
# Out:
# 当前 quimb 版本： 1.10.0
# numpy_backend

# %%
def apply_k_local_unitary(state, U, targets, n):
    """
    在 n 比特系统中，直接在态向量 state 上局部作用 k 比特酉矩阵 U
    targets: 作用位点列表，如 [1,2,3]
    """
    state = state.reshape([2] * n)  # reshape 成 tensor

    # 将目标比特移动到前面，其他维度放后面
    perm = targets + [i for i in range(n) if i not in targets]
    inv_perm = np.argsort(perm)

    state_perm = np.transpose(state, perm)
    k = len(targets)
    shape_k = (2,) * k
    shape_rest = (2,) * (n - k)
    state_perm = state_perm.reshape(2 ** k, -1)

    # 对每个后部坐标应用 U
    state_perm = U @ state_perm  # 作用在目标比特上

    # 还原回原始排列
    state_perm = state_perm.reshape(shape_k + shape_rest)
    state_new = np.transpose(state_perm, inv_perm)
    return state_new.reshape(-1)

def generate_ladder_state_efficient(n, k, seed=None):
    """
    高效生成随机链式锁定态（不构造大型矩阵）
    """
    if seed is not None:
        np.random.seed(seed)
    dim = 2 ** n
    state = np.zeros(dim, dtype=complex)
    state[0] = 1.0  # 初始为 |00...0>

    for start in range(n - k + 1):
        U = unitary_group.rvs(2 ** k)
        targets = list(range(start, start + k))
        state = apply_k_local_unitary(state, U, targets, n)

    return state
def expand_random_k_unitary(U, start, k, n):
    """
    将一个 k 比特酉矩阵 U 作用在 n 比特系统的 [start, ..., start+k-1] 上
    """
    dim = 2 ** n
    result = np.zeros((dim, dim), dtype=complex)

    targets = list(range(start, start + k))

    for bits_in in product([0, 1], repeat=n):
        for bits_out in product([0, 1], repeat=n):
            if all(bits_in[t] == bits_out[t] for t in range(n) if t not in targets):
                in_sub = [bits_in[t] for t in targets]
                out_sub = [bits_out[t] for t in targets]

                in_idx = int("".join(str(b) for b in in_sub), 2)
                out_idx = int("".join(str(b) for b in out_sub), 2)

                i_idx = int("".join(str(b) for b in bits_in), 2)
                j_idx = int("".join(str(b) for b in bits_out), 2)

                result[i_idx, j_idx] = U[in_idx, out_idx]
    return result

def generate_random_ladder_state(n, k, seed=None):
    """
    从 |0...0⟩ 出发，自动以阶梯结构作用 n-k+1 个随机 k 比特酉矩阵，返回最终状态向量
    """
    assert k <= n, "作用的比特数 k 不能大于总比特数 n"

    if seed is not None:
        np.random.seed(seed)

    dim = 2 ** n
    state = np.zeros(dim, dtype=complex)
    state[0] = 1.0  # 初始态为 |0...0⟩

    for start in range(n - k + 1):
        U = unitary_group.rvs(2 ** k)  # 随机生成 k 比特酉矩阵
        U_full = expand_random_k_unitary(U, start, k, n)
        state = U_full @ state
    return state

def construct_spin_orbit_locked_state(n, theta=0.0, l_plus_idx=None, l_minus_idx=None):
    """
    构造 n 比特系统中具有自旋-轨道锁定的态向量。
    
    参数：
        n: 总比特数（>=2），其中第0位表示spin，其余为OAM
        theta: 旋转角参数
        l_plus_idx: OAM部分中 |l=+q⟩ 的索引（在 [0, 2**(n-1) - 1] 范围）
        l_minus_idx: OAM部分中 |l=-q⟩ 的索引

    返回：
        psi: (2**n,) 的复数态向量
    """
    assert n >= 2, "至少需要一个 spin 和一个 OAM 比特"
    dim = 2 ** n
    oam_dim = 2 ** (n - 1)
    
    # 默认选择 |l=+q⟩ = |00...0⟩，|l=-q⟩ = |11...1⟩
    if l_plus_idx is None:
        l_plus_idx = 0
    if l_minus_idx is None:
        l_minus_idx = oam_dim - 1

    # 构造 σ⁻ 和 σ⁺
    sigma_minus = (np.array([1, -1j]) / np.sqrt(2))
    sigma_plus  = (np.array([1,  1j]) / np.sqrt(2))
    
    # 构造 OAM 态
    oam_plus  = np.zeros(oam_dim, dtype=complex)
    oam_minus = np.zeros(oam_dim, dtype=complex)
    oam_plus[l_plus_idx]   = 1.0
    oam_minus[l_minus_idx] = 1.0

    # Kronecker 外积得到完整态（spin × OAM）
    term1 = np.kron(np.exp(1j * theta) * sigma_minus, oam_plus)
    term2 = np.kron(np.exp(-1j * theta) * sigma_plus,  oam_minus)

    # 合成并归一化
    psi = (term1 + term2) / np.sqrt(2)
    return psi

def get_spin_state_vector(n, spin_levels):
    """
    计算 |s_12, s_123, ..., s_n, s_z> 状态对应的态矢量。

    参数：
    - n: 自旋-1/2粒子的数量。
    - spin_levels: 列表，[s_12, s_123, ..., s_n, s_z]，
                   依次为每步耦合得到的总自旋值，以及最终态的总磁量子数 s_z（总自旋的投影）。

    返回：
    - 对应态的状态向量（numpy 数组，长度 2^n）。
    """
    if n < 1:
        raise ValueError("n 必须是正整数")
    if len(spin_levels) != n:
        raise ValueError("spin_levels 列表长度应为 n（包含 n-1 个中间总自旋和最终的 s_z）")
    # 拆分中间总自旋序列和最终 s_z
    intermediate_s = spin_levels[:-1]
    final_m = spin_levels[-1]
    # n=1 特殊处理：只有一个自旋
    if n == 1:
        if abs(final_m) != 0.5:
            raise ValueError("对于单个自旋，m 必须是 ±0.5")
        # 返回 [1, 0] 表示 |↑>，或 [0, 1] 表示 |↓>
        return np.array([1.0, 0.0]) if final_m == 0.5 else np.array([0.0, 1.0])
    # 校验 intermediate_s 长度
    if len(intermediate_s) != n - 1:
        raise ValueError("spin_levels 应包含 n-1 个总自旋值加最终 s_z")
    # 校验物理可行性：逐步检查每次耦合 s 值是否满足 j = j_prev ± 1/2
    prev_s = 0.5  # 第一个自旋的总自旋
    for s_val in intermediate_s:
        # 可能的耦合结果（去除负值的情况）
        allowed = set([abs(prev_s - 0.5), prev_s + 0.5])
        allowed = {x for x in allowed if x >= 0}
        # 判断给定 s_val 是否在 allowed 集合（考虑浮点误差）
        if not any(abs(s_val - a) < 1e-8 for a in allowed):
            raise ValueError(f"耦合不一致：无法从自旋 {prev_s} 加 1/2 得到 {s_val}")
        prev_s = s_val
    total_S = intermediate_s[-1]
    # 检查最终 m 是否在 [-S, S] 范围内
    if abs(final_m) > total_S + 1e-8:
        raise ValueError("最终 m 超出总自旋范围")

    # 将自旋值转换为 2*j 的整数形式，便于处理半整数
    def to_2j(x):
        return int(round(x * 2))

    # 使用缓存的递归函数逐步耦合
    @lru_cache(maxsize=None)
    def couple(i, j1_twice, m1_twice):
        """
        返回前 i 个自旋（总自旋 j1_twice/2， 磁量子数 m1_twice/2）的态矢量。
        参数:
        - i: 耦合的自旋数目
        - j1_twice: 前 i 个自旋的总自旋的两倍 (2*s_i)
        - m1_twice: 该态总磁量子数的两倍 (2*m_i)
        """
        # 基础：单个自旋态
        if i == 1:
            # 单个自旋 j 必须为 1 (即 2*0.5)
            if j1_twice != 1:
                raise ValueError("单个自旋的总自旋应为 1/2")
            if m1_twice == 1:  # |↑>
                return np.array([1.0, 0.0])
            elif m1_twice == -1:  # |↓>
                return np.array([0.0, 1.0])
            else:
                raise ValueError("单个自旋的 m 必须为 ±0.5")
        # 确定前 i-1 个自旋的总自旋 j_prev_twice
        if i == 2:
            # 前1个自旋总自旋固定为1/2（j_prev_twice=1）
            j_prev_twice = 1
        else:
            # 对于 i>2，从 intermediate_s 获取前 i-1 个自旋的总自旋
            j_prev_twice = to_2j(intermediate_s[i - 3])
        j_curr_twice = j1_twice  # 当前 i 个自旋的 2*j 值
        M_twice = m1_twice  # 当前总 m 的两倍
        j2_twice = 1  # 新加入的单个自旋(1/2)的 2*j 值为1
        # 初始化长度 2^i 的零向量
        state_vec = np.zeros(2 ** i)
        # 遍历第 i 个自旋的可能 m ( +1/2 或 -1/2 )
        for m2_twice in (1, -1):
            m1_prev_twice = M_twice - m2_twice  # 前 i-1 个自旋需承担的磁量子数之和 (2*m_prev)
            # 判断 m1_prev_twice 是否在前 i-1 个自旋总自旋范围内
            if abs(m1_prev_twice) <= j_prev_twice and (j_prev_twice - m1_prev_twice) % 2 == 0:
                # 判断耦合的总自旋是否匹配期望值
                # 只能在 j_prev ± 1 范围内取到 j_curr_twice
                if not (j_curr_twice == j_prev_twice + j2_twice or j_curr_twice == abs(j_prev_twice - j2_twice)):
                    continue  # 若不匹配，系数为0，跳过
                # 将量子数从 2*j 表示转换回实际值用于公式计算
                j_prev = j_prev_twice / 2.0
                m_prev = m1_prev_twice / 2.0
                j_curr = j_curr_twice / 2.0
                M = M_twice / 2.0
                m2 = m2_twice / 2.0  # 新粒子的 m（±0.5）
                # 根据大/小耦合支路使用对应公式计算 CG 系数
                if abs(j_curr - (j_prev + 0.5)) < 1e-8:
                    # 情况1： j_curr = j_prev + 1/2
                    if m2 == 0.5:
                        cgc = np.sqrt((j_prev + M + 0.5) / (2 * j_prev + 1))
                    else:  # m2 = -0.5
                        cgc = np.sqrt((j_prev - M + 0.5) / (2 * j_prev + 1))
                else:
                    # 情况2： j_curr = j_prev - 1/2
                    if m2 == 0.5:
                        cgc = np.sqrt((j_prev - M + 0.5) / (2 * j_prev + 1))
                    else:  # m2 = -0.5
                        cgc = -np.sqrt((j_prev + M + 0.5) / (2 * j_prev + 1))
                if abs(cgc) < 1e-12:
                    continue  # 系数近似为0，不计入
                # 递归获得前 i-1 个自旋的态矢量
                prev_state = couple(i - 1, j_prev_twice, m1_prev_twice)
                # 构造第 i 个自旋对应的基向量
                spin_state = np.array([1.0, 0.0]) if m2 == 0.5 else np.array([0.0, 1.0])
                # 计算张量积并按系数加权累加
                state_vec += cgc * np.kron(prev_state, spin_state)
        return state_vec
    # 调用递归函数获取最终 n 个自旋的态矢量
    # print(intermediate_s[-1])
    total_j_twice = to_2j(intermediate_s[-1])  # 2 * s_n
    # print(total_j_twice)
    total_m_twice = to_2j(final_m)  # 2 * s_z
    state = couple(n, total_j_twice, total_m_twice)
    # （可选）规范化结果向量（正常情况下 CG 系数保证规范归一，这里做一下保险处理）
    norm = np.linalg.norm(state)
    if norm < 1e-12:
        raise ValueError("计算得到的态矢量归一化因子接近0，请检查输入参数的有效性")
    return state / norm
def generate_w_state(n):
    """
    生成 n 比特的 W 态态矢量
    返回：
        state_vector: 形状为 (2**n,) 的 numpy 复数数组，已归一化
    """
    dim = 2 ** n
    state_vector = np.zeros(dim, dtype=np.complex128)
    for i in range(n):
        # 第 i 个位置为 '1'，其余为 '0'
        bitstring = ['0'] * n
        bitstring[i] = '1'
        index = int(''.join(bitstring), 2)
        state_vector[index] = 1.0
    # 归一化
    state_vector /= np.sqrt(n)
    return state_vector
def generate_neel_state(n):
    # 创建长度为2^n的零向量
    state = np.zeros(2**n, dtype=np.complex128)
    
    # 生成交替自旋的二进制表示，例如：10101010...对于n=8
    binary_state = ''.join(['0' if i % 2 == 0 else '1' for i in range(n)])
    
    # 将对应二进制数的位置设为1
    state[int(binary_state, 2)] = 1
    return state
def generate_random_state(n):
    """
    生成一个 n 比特的随机纯态（复数），归一化。
    
    参数：
        n: 量子比特数
    返回：
        state_vector: 形状为 (2**n,) 的归一化复数 numpy 数组
    """
    dim = 2 ** n
    # 复高斯分布实部+虚部（独立标准正态）
    real_part = np.random.randn(dim)
    imag_part = np.random.randn(dim)
    state_vector = real_part + 1j * imag_part
    # 归一化
    state_vector /= np.linalg.norm(state_vector)

    return state_vector
def generate_ghz_state(n):
    """
    生成 n 比特 GHZ 态的态矢量
    """
    dim = 2 ** n
    state_vector = np.zeros(dim, dtype=np.complex128)
    # |000...0> 的索引是 0，|111...1> 的索引是 2^n - 1
    state_vector[0] = 1.0 / np.sqrt(2)
    state_vector[-1] = 1.0 / np.sqrt(2)
    return state_vector

# %%
from scipy.linalg import expm
# Pauli 基定义
pauli_ops = {
    'I': np.array([[1, 0], [0, 1]], dtype=np.complex128),
    'X': np.array([[0, 1], [1, 0]], dtype=np.complex128),
    'Y': np.array([[0, -1j], [1j, 0]], dtype=np.complex128),
    'Z': np.array([[1, 0], [0, -1]], dtype=np.complex128),
    '+': np.array([[0, 1], [0, 0]], dtype=np.complex128),  # σ^+
    '-': np.array([[0, 0], [1, 0]], dtype=np.complex128),  # σ^-
    "RX": (1/2) * np.array([[1, -1j], [-1j, 1]]),
    "RY": (1/2) * np.array([[1, -1], [1, 1]]),
    "RZ":  np.array([[0.5, 0], [0, 0.5]], dtype=np.complex128)
}

# 构造n比特上某两个位置作用的多体算符
def build_manybody_operator(n, op_string):
    op = 1
    for p in op_string:
        op = np.kron(op, pauli_ops[p])
    return op

# 构造严格意义上的 H_XY 哈密顿量
def XY_Hamiltonian(n, J, B, alpha):
    H = np.zeros((2**n, 2**n), dtype=np.complex128)

    for i in range(n - 1):
        for j in range(i + 1, n):
            Jij = J / abs(i - j)**alpha

            # σ⁺_i σ⁻_j
            ops1 = ['I'] * n
            ops1[i] = '+'
            ops1[j] = '-'
            H += Jij * build_manybody_operator(n, ops1)

            # σ⁻_i σ⁺_j
            ops2 = ['I'] * n
            ops2[i] = '-'
            ops2[j] = '+'
            H += Jij * build_manybody_operator(n, ops2)

    # 场项 B σ^z
    for i in range(n):
        opsz = ['I'] * n
        opsz[i] = 'Z'
        H += B * build_manybody_operator(n, opsz)
    return H
#时间演化
def time_evolution(state, H, t):
    U = expm(-1j * H * t)  # 演化算符
    return np.dot(U, state)

# 计算 <σ_i σ_j> - <σ_i><σ_j>
def two_point_correlation(state, pauli1, pauli2, i, j, n):
    def build_op(p1, p2, i, j, n):
        # 初始化 ops 为全 I 的操作符列表
        ops = [pauli_ops["I"]] * n
        # 根据位置i和j进行相应的乘法操作
        if i == j:
            if p1 =="I":
                ops[i] = pauli_ops[p2]
            elif p2 =="I":
                ops[i] = pauli_ops[p1]
            else:
                ops[i] = pauli_ops[p1]*pauli_ops[p2]
        else:
            ops[i] = pauli_ops[p1]  # 第 i 位置的操作符乘以 pauli1
            ops[j] = pauli_ops[p2]  # 第 j 位置的操作符乘以 pauli2
        
        # 逐步计算 Kronecker 积
        result = ops[0]
        for op in ops[1:]:
            result = np.kron(result, op)
        return result

    # 构建自旋算符
    op1 = build_op(pauli1, "I", i, j, n)
    op2 = build_op("I", pauli2, i, j, n)
    op12 = build_op(pauli1, pauli2, i, j, n)

    # 计算期望值
    s1 = np.real(state.conj().T @ op1 @ state)
    s2 = np.real(state.conj().T @ op2 @ state)
    s12 = np.real(state.conj().T @ op12 @ state)

    return s12-s1 * s2

# 构造整张图的矩阵
def build_corr_matrix(state, pauli1, pauli2, n):
    mat = np.zeros((n, n))
 
    for i in range(n):
        for j in range(n):
            mat[i, j] = two_point_correlation(state, pauli1, pauli2, i, j, n)
    return mat

# %%
n=8
k=3     # 局部测量比特数
np.random.seed(12)
# state_1=[0,0.5,0,0]
# state_2=[0,0.5,1,0]
# state_3=[1,1.5,2,1]
# state_vector =generate_ghz_state(n)
# state_vector = (get_spin_state_vector(n, state_1)+get_spin_state_vector(n, state_2))*np.sqrt(0.5)
# state_vector = get_spin_state_vector(n, state_3)
# state_vector=generate_random_state(n)
# state_vector = generate_w_state(n)
# state_vector = construct_spin_orbit_locked_state(n=n, theta=np.pi/3)
# state_vector =generate_random_ladder_state(n=n, k=2, seed=12)
# state_vector =generate_ladder_state_efficient(n=n, k=3, seed=12)
state_vector = generate_neel_state(n)
# state_vector=neel_state
# state_vector =np.array([0,np.sqrt(0.5),np.sqrt(0.5),0])
# print("状态向量:", state_vector)
# 创建哈密顿量
J = 1  # 假设相互作用强度
B = 0  # 横向场强度
alpha=1.8
H = XY_Hamiltonian(n, J, B,alpha)
t =0.3# 演化时间
# evolved_state=state_vector
evolved_state = time_evolution(state_vector, H, t)
print(evolved_state)
# Out:
# [ 0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -3.66160052e-03+0.00501007j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -9.57317652e-03-0.007245j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -9.89073137e-03+0.01134509j
#   0.00000000e+00+0.j         -2.65825927e-02-0.02123768j
#  -6.75294578e-03+0.00942679j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -9.89073137e-03+0.01134509j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          7.45203920e-03+0.03135336j
#   0.00000000e+00+0.j         -8.36416106e-02+0.01376927j
#   6.32524987e-03+0.02718962j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -7.52518738e-02+0.01435358j
#   0.00000000e+00+0.j         -1.85704658e-02-0.23312877j
#  -7.34000992e-02+0.01023758j  0.00000000e+00+0.j
#   0.00000000e+00+0.j         -7.63023681e-02+0.01528452j
#   6.13009789e-03+0.02717917j  0.00000000e+00+0.j
#  -6.99213796e-03+0.00894259j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -2.65825927e-02-0.02123768j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -8.36416106e-02+0.01376927j
#   0.00000000e+00+0.j         -2.05227502e-02-0.23104895j
#  -7.46996822e-02+0.01142917j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -1.85704658e-02-0.23312877j
#   0.00000000e+00+0.j          7.19211485e-01+0.0159743j
#  -7.78358505e-03-0.22722417j  0.00000000e+00+0.j
#   0.00000000e+00+0.j         -2.03115937e-02-0.23136935j
#  -8.17676432e-02+0.00898975j  0.00000000e+00+0.j
#  -2.33476454e-02-0.02239414j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -7.63023681e-02+0.01528452j
#   0.00000000e+00+0.j         -2.03115937e-02-0.23136935j
#  -7.31314431e-02+0.01110481j  0.00000000e+00+0.j
#   0.00000000e+00+0.j         -8.29982083e-02+0.01440883j
#   5.77908839e-03+0.03044832j  0.00000000e+00+0.j
#  -1.01127384e-02+0.00989388j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -2.68175077e-02-0.02063693j
#  -9.91758653e-03+0.01041125j  0.00000000e+00+0.j
#  -8.37769691e-03-0.00750843j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#  -3.80129438e-03+0.0044241j   0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -6.75294578e-03+0.00942679j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          6.32524987e-03+0.02718962j
#   0.00000000e+00+0.j         -7.46996822e-02+0.01142917j
#   5.31407948e-03+0.0241269j   0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -7.34000992e-02+0.01023758j
#   0.00000000e+00+0.j         -7.78358505e-03-0.22722417j
#  -7.16372791e-02+0.00659844j  0.00000000e+00+0.j
#   0.00000000e+00+0.j         -7.31314431e-02+0.01110481j
#   4.58299660e-03+0.02592285j  0.00000000e+00+0.j
#  -6.79726862e-03+0.00809823j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          6.13009789e-03+0.02717917j
#   0.00000000e+00+0.j         -8.17676432e-02+0.00898975j
#   4.58299660e-03+0.02592285j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          5.77908839e-03+0.03044832j
#   1.13762880e-02-0.00229058j  0.00000000e+00+0.j
#   3.77968310e-03+0.00415042j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -9.91758653e-03+0.01041125j
#   4.00986391e-03+0.00485172j  0.00000000e+00+0.j
#  -4.16685345e-03+0.00341778j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   1.84617720e-03+0.00199155j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -6.99213796e-03+0.00894259j
#   0.00000000e+00+0.j         -2.33476454e-02-0.02239414j
#  -6.79726862e-03+0.00809823j  0.00000000e+00+0.j
#   0.00000000e+00+0.j         -1.01127384e-02+0.00989388j
#   3.77968310e-03+0.00415042j  0.00000000e+00+0.j
#  -1.62084979e-03+0.00277621j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -8.37769691e-03-0.00750843j
#  -4.16685345e-03+0.00341778j  0.00000000e+00+0.j
#  -3.50701093e-03-0.00452074j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#  -1.80053239e-03+0.00180831j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j         -3.80129438e-03+0.0044241j
#   1.84617720e-03+0.00199155j  0.00000000e+00+0.j
#  -1.80053239e-03+0.00180831j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   9.64399066e-04+0.00091529j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#  -4.93959571e-05+0.00056444j  0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j
#   0.00000000e+00+0.j          0.00000000e+00+0.j        ]

# %%
# 计算三个相关矩阵
mat_YY = build_corr_matrix(evolved_state, "Y", "Y", n)
mat_XY = build_corr_matrix(evolved_state, "X", "Y", n)
mat_ZZ = build_corr_matrix(evolved_state, "Z", "Z", n)
# 绘图
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

for ax, mat, title in zip(
    axs,
    [mat_YY, mat_XY, mat_ZZ],
    [r"Theory: $\langle YY\rangle - \langle Y\rangle\langle Y\rangle$",
     r"Theory: $\langle XY\rangle - \langle X\rangle\langle Y\rangle$",
     r"Theory: $\langle ZZ\rangle - \langle Z\rangle\langle Z\rangle$"]
):
    im = ax.imshow(mat, cmap="bwr", vmin=-0.25, vmax=0.25)  # 设置vmin和vmax以确保一致性
    ax.set_title(title, fontsize=10)
    ax.set_xlabel("Spin", fontsize=10)
    ax.set_ylabel("Spin", fontsize=10)

# 调整子图间距，避免颜色条与图形重叠
fig.subplots_adjust(hspace=0.4, wspace=0.4, right=0.85)  # 调整右侧边距以为颜色条腾出空间
# 将颜色条放置在最右侧，并设置为竖直方向
cbar = fig.colorbar(im, ax=axs.ravel().tolist(), orientation='vertical', shrink=0.4, pad=0.01)
cbar.ax.tick_params(labelsize=10)  # 调整颜色条刻度标签的字体大小
plt.show()

# %%
def generate_all_bitstrings(m):
    return [''.join(bits) for bits in product('01', repeat=m)]

# 展开测量基
def expand_measurement_basis(n, k, basis):
    return (basis * ((n // k) + 1))[:n]

# 应用测量门到态矢量
def apply_measurement_gate(state, basis):
    state = state.copy()
    for q, b in enumerate(basis):
        if b == "X":
            U = (1/np.sqrt(2)) * np.array([[1, 1], [-1, 1]])
            
        elif b == "Y":
            U = (1/np.sqrt(2)) * np.array([[1, -1j], [-1j, 1]])
        else:  # Z 或 I 不处理
            continue
        state = apply_single_qubit_gate(state, U, q)
    return state

def apply_single_qubit_gate(state, gate, qubit):
    n = int(np.log2(len(state)))
    state = state.reshape([2] * n)
    state = np.tensordot(gate, state, axes=[1, qubit])
    axes_order = list(range(1, qubit+1)) + [0] + list(range(qubit+1, n))
    state = np.transpose(state, axes_order).reshape(-1)
    return state

# 获取精确概率分布（无抽样）
def get_exact_probabilities(state_vector, n, k):
    pauli_bases = ["X", "Y", "Z"]
    measurement_bases = list(product(pauli_bases, repeat=k))
    all_bitstrings_n = generate_all_bitstrings(n)
    
    probabilities = {}
    raw_counts = {}
    for basis in measurement_bases:
        expanded_basis = expand_measurement_basis(n, k, basis)
        final_state = apply_measurement_gate(state_vector, expanded_basis)
        probs = np.abs(final_state) ** 2
        
        # 存储精确概率，不再进行抽样计数
        probabilities[tuple(expanded_basis)] = probs
        raw_counts[tuple(expanded_basis)] = dict(zip(all_bitstrings_n, probs))

    return probabilities, raw_counts, all_bitstrings_n

# %%
# 获取 POVM 概率向量
probabilities, raw_probs, bitstrings = get_exact_probabilities(evolved_state, n, k)

# %%
# 显示部分结果
print("\n 测量基数：", len(probabilities))
for key, ps in list(probabilities.items())[:3]:  # 显示前3组
    print(f"\n测量基 {key} 下的 p_s（前10项）:")
    print(ps[:15])
# Out:
#  测量基数： 27
#
# 测量基 ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X') 下的 p_s（前10项）:
# [0.00707464 0.00559022 0.00605975 0.00395831 0.00470959 0.0068199
#  0.00281654 0.00430718 0.00509275 0.00307345 0.00720388 0.00478819
#  0.00215142 0.00301434 0.00354377]
#
# 测量基 ('X', 'X', 'Y', 'X', 'X', 'Y', 'X', 'X') 下的 p_s（前10项）:
# [7.88241375e-04 9.34247436e-04 3.65578913e-04 3.23955814e-04
#  8.14202781e-05 9.15908186e-05 4.69687623e-04 4.93204583e-04
#  5.06936655e-04 4.66250740e-04 1.85001093e-04 1.23706298e-04
#  4.08008376e-04 3.73577934e-04 1.42094191e-03]
#
# 测量基 ('X', 'X', 'Z', 'X', 'X', 'Z', 'X', 'X') 下的 p_s（前10项）:
# [3.98234497e-03 3.55407053e-03 4.98331956e-04 3.82081086e-06
#  8.67960144e-03 9.49328976e-03 1.00460405e-02 9.53842559e-03
#  5.31683258e-04 1.29074575e-05 3.97688163e-03 3.43550295e-03
#  1.08393163e-02 9.69985977e-03 1.36733637e-02]

# %%
# 提取局部概率
def extract_local_probs_grouped_by_window(raw_probs, n, k):
    local_probs = {i: {} for i in range(n - k + 1)}
    all_bitstrings_k = generate_all_bitstrings(k)
    for full_basis, global_probs in raw_probs.items():
        for i in range(n - k + 1):
            local_basis = tuple(full_basis[i:i + k])
            local_probs_vector = np.zeros(2 ** k)
            for global_bitstr, prob in global_probs.items():  # ← 关键修正
                local_bitstr = global_bitstr[i:i + k]
                local_idx = int(local_bitstr, 2)
                local_probs_vector[local_idx] += prob
            local_probs[i][local_basis] = local_probs_vector

    return local_probs

# 补全4^k基概率
def expand_all_local_pauli_bases(k):
    return list(product(['I', 'X', 'Y', 'Z'], repeat=k))

def complete_local_probs_from_measured(local_probs_by_window, k):
    full_pauli_bases = expand_all_local_pauli_bases(k)
    completed_local_probs = {}
    for i, basis_data in local_probs_by_window.items():
        completed_local_probs[i] = {}
        for target_basis in full_pauli_bases:
            compatible_measured_bases = [
                mb for mb in basis_data
                if all(tb == 'I' or tb == mb for tb, mb in zip(target_basis, mb))
            ]

            if not compatible_measured_bases:
                completed_local_probs[i][target_basis] = None
                continue

            mask = [b == 'I' for b in target_basis]
            prob_sum = np.zeros(2 ** k)
            for cbasis in compatible_measured_bases:
                pvec = basis_data[cbasis]
                prob_sum += pvec
            completed_local_probs[i][target_basis] = prob_sum / len(compatible_measured_bases)

    return completed_local_probs

# %%
# 原始滑窗提取数据
local_probs_by_window = extract_local_probs_grouped_by_window(raw_probs, n, k)

# 补全所有 4^k 基的概率向量
completed_local_probs = complete_local_probs_from_measured(local_probs_by_window, k)

# 展示前几个窗口和基的结果
for i in range(min(4, n - k + 1)):
    print(f"\n 窗口位置 {i}：")
    cnt = 0
    for b, p in completed_local_probs[i].items():
        if p is not None:
            print(f"  基 {b}: p[:4] = {p}")
            cnt += 1
# Out:
#  窗口位置 0：
#   基 ('I', 'I', 'I'): p[:4] = [0.14534431 0.09374311 0.25335087 0.14513174 0.08325175 0.06748183
#  0.12899232 0.08270407]
#   基 ('I', 'I', 'X'): p[:4] = [0.15382508 0.08526233 0.17896873 0.21951388 0.07911514 0.07161845
#  0.08809105 0.12360534]
#   基 ('I', 'I', 'Y'): p[:4] = [0.09848913 0.14059829 0.23545556 0.16302705 0.05089571 0.09983787
#  0.1151596  0.09653679]
#   基 ('I', 'I', 'Z'): p[:4] = [0.18371871 0.0553687  0.34562831 0.05285431 0.11974441 0.03098918
#  0.18372631 0.02797008]
#   基 ('I', 'X', 'I'): p[:4] = [0.13945975 0.13266915 0.25923542 0.1062057  0.12048421 0.10738688
#  0.09175986 0.04279902]
#   基 ('I', 'X', 'X'): p[:4] = [0.13517747 0.13695144 0.19761634 0.16782478 0.10357862 0.12429248
#  0.06362757 0.07093131]
#   基 ('I', 'X', 'Y'): p[:4] = [0.06061737 0.21151154 0.27332732 0.0921138  0.06404957 0.16382153
#  0.10200574 0.03255314]
#   基 ('I', 'X', 'Z'): p[:4] = [0.22258441 0.04954449 0.30676261 0.05867851 0.19382445 0.03404664
#  0.10964626 0.02491262]
#   基 ('I', 'Y', 'I'): p[:4] = [0.25084349 0.10981979 0.14785169 0.12905506 0.09265585 0.04668087
#  0.11958822 0.10350503]
#   基 ('I', 'Y', 'X'): p[:4] = [0.27036296 0.09030032 0.06243085 0.2144759  0.1049701  0.03436662
#  0.06223608 0.16085717]
#   基 ('I', 'Y', 'Y'): p[:4] = [0.18002009 0.18064318 0.1539246  0.12298215 0.05873599 0.08060073
#  0.10731931 0.11577394]
#   基 ('I', 'Y', 'Z'): p[:4] = [0.30214741 0.05851587 0.22719961 0.04970714 0.11426146 0.02507526
#  0.18920925 0.033884  ]
#   基 ('I', 'Z', 'I'): p[:4] = [0.04572968 0.03874038 0.3529655  0.20013447 0.03661519 0.04837774
#  0.17562888 0.10180816]
#   基 ('I', 'Z', 'X'): p[:4] = [0.05593481 0.02853525 0.27685901 0.27624096 0.02879669 0.05619625
#  0.1384095  0.13902754]
#   基 ('I', 'Z', 'Y'): p[:4] = [0.05482992 0.02964014 0.27911478 0.27398519 0.02990158 0.05509136
#  0.13615373 0.14128331]
#   基 ('I', 'Z', 'Z'): p[:4] = [0.02642432 0.05804574 0.5029227  0.05017727 0.05114731 0.03384563
#  0.25232341 0.02511363]
#   基 ('X', 'I', 'I'): p[:4] = [0.15000027 0.08678849 0.17062903 0.09258221 0.07859579 0.07443645
#  0.21171416 0.13525361]
#   基 ('X', 'I', 'X'): p[:4] = [0.16514081 0.07164795 0.12861191 0.13459933 0.0677994  0.08523283
#  0.13844788 0.20851989]
#   基 ('X', 'I', 'Y'): p[:4] = [0.09565455 0.14113422 0.15607177 0.10713947 0.05373029 0.09930194
#  0.19454339 0.15242438]
#   基 ('X', 'I', 'Z'): p[:4] = [0.18920546 0.04758331 0.22720341 0.03600783 0.11425766 0.03877457
#  0.3021512  0.04481656]
#   基 ('X', 'X', 'I'): p[:4] = [0.1328553  0.10997794 0.187774   0.06939276 0.12708866 0.1300781
#  0.16322128 0.07961195]
#   基 ('X', 'X', 'X'): p[:4] = [0.13767102 0.10516221 0.1560817  0.10108507 0.10108507 0.1560817
#  0.10516221 0.13767102]
#   基 ('X', 'X', 'Y'): p[:4] = [0.05961324 0.18321999 0.19211307 0.06505369 0.06505369 0.19211307
#  0.18321999 0.05961324]
#   基 ('X', 'X', 'Z'): p[:4] = [0.20128163 0.0415516  0.21512723 0.04203953 0.21512723 0.04203953
#  0.20128163 0.0415516 ]
#   基 ('X', 'Y', 'I'): p[:4] = [0.26337819 0.11942337 0.05725111 0.05994733 0.08012115 0.03707729
#  0.21018879 0.17261276]
#   基 ('X', 'Y', 'X'): p[:4] = [0.27594367 0.10685789 0.01780905 0.09938939 0.09938939 0.01780905
#  0.10685789 0.27594367]
#   基 ('X', 'Y', 'Y'): p[:4] = [0.18664198 0.19615958 0.06508434 0.05211411 0.05211411 0.06508434
#  0.19615958 0.18664198]
#   基 ('X', 'Y', 'Z'): p[:4] = [0.32754892 0.05525263 0.08885995 0.0283385  0.08885995 0.0283385
#  0.32754892 0.05525263]
#   基 ('X', 'Z', 'I'): p[:4] = [0.05376732 0.03096417 0.26686198 0.14840653 0.02857755 0.05615395
#  0.2617324  0.15353611]
#   基 ('X', 'Z', 'X'): p[:4] = [0.08180775 0.00292375 0.21194497 0.20332353 0.00292375 0.08180775
#  0.20332353 0.21194497]
#   基 ('X', 'Z', 'Y'): p[:4] = [0.04070841 0.04402308 0.2110179  0.2042506  0.04402308 0.04070841
#  0.2042506  0.2110179 ]
#   基 ('X', 'Z', 'Z'): p[:4] = [0.03878581 0.04594568 0.37762306 0.03764545 0.03878581 0.04594568
#  0.37762306 0.03764545]
#   基 ('Y', 'I', 'I'): p[:4] = [0.09395249 0.0543019  0.22552594 0.12621967 0.13464357 0.10692303
#  0.15681725 0.10161614]
#   基 ('Y', 'I', 'X'): p[:4] = [0.09311906 0.05513533 0.15515462 0.19659099 0.13982116 0.10174545
#  0.11190516 0.14652823]
#   基 ('Y', 'I', 'Y'): p[:4] = [0.07909594 0.06915845 0.21465678 0.13708883 0.0702889  0.1712777
#  0.13595838 0.12247501]
#   基 ('Y', 'I', 'Z'): p[:4] = [0.10964246 0.03861193 0.3067664  0.04497921 0.19382066 0.04774595
#  0.22258821 0.03584518]
#   基 ('Y', 'X', 'I'): p[:4] = [0.0529277  0.06427074 0.26655072 0.11625083 0.20701626 0.17578529
#  0.08444456 0.03275388]
#   基 ('Y', 'X', 'X'): p[:4] = [0.05211411 0.06508434 0.19615958 0.18664198 0.18664198 0.19615958
#  0.06508434 0.05211411]
#   基 ('Y', 'X', 'Y'): p[:4] = [0.01780905 0.09938939 0.27594367 0.10685789 0.10685789 0.27594367
#  0.09938939 0.01780905]
#   基 ('Y', 'X', 'Z'): p[:4] = [0.08885995 0.0283385  0.32754892 0.05525263 0.32754892 0.05525263
#  0.08885995 0.0283385 ]
#   基 ('Y', 'Y', 'I'): p[:4] = [0.17405755 0.06877569 0.14542087 0.11174589 0.16944179 0.08772497
#  0.12201903 0.1208142 ]
#   基 ('Y', 'Y', 'X'): p[:4] = [0.18321999 0.05961324 0.06505369 0.19211307 0.19211307 0.06505369
#  0.05961324 0.18321999]
#   基 ('Y', 'Y', 'Y'): p[:4] = [0.13767102 0.10516221 0.1560817  0.10108507 0.10108507 0.1560817
#  0.10516221 0.13767102]
#   基 ('Y', 'Y', 'Z'): p[:4] = [0.20128163 0.0415516  0.21512723 0.04203953 0.21512723 0.04203953
#  0.20128163 0.0415516 ]
#   基 ('Y', 'Z', 'I'): p[:4] = [0.05487221 0.02985928 0.26460621 0.1506623  0.02747266 0.05725884
#  0.26398816 0.15128034]
#   基 ('Y', 'Z', 'X'): p[:4] = [0.04402308 0.04070841 0.2042506  0.2110179  0.04070841 0.04402308
#  0.2110179  0.2042506 ]
#   基 ('Y', 'Z', 'Y'): p[:4] = [0.08180775 0.00292375 0.21194497 0.20332353 0.00292375 0.08180775
#  0.20332353 0.21194497]
#   基 ('Y', 'Z', 'Z'): p[:4] = [0.03878581 0.04594568 0.37762306 0.03764545 0.03878581 0.04594568
#  0.37762306 0.03764545]
#   基 ('Z', 'I', 'I'): p[:4] = [0.19208016 0.14013893 0.36389764 0.21659335 0.0365159  0.02108601
#  0.01844554 0.01124247]
#   基 ('Z', 'I', 'X'): p[:4] = [0.20321536 0.12900372 0.25313968 0.32735132 0.02972485 0.02787706
#  0.01392011 0.0157679 ]
#   基 ('Z', 'I', 'Y'): p[:4] = [0.12071689 0.21150219 0.33563814 0.24485285 0.02866794 0.02893397
#  0.01497702 0.01471099]
#   基 ('Z', 'I', 'Z'): p[:4] = [0.25230821 0.07991087 0.50291511 0.07757589 0.05115491 0.00644701
#  0.02643951 0.0032485 ]
#   基 ('Z', 'X', 'I'): p[:4] = [0.23259625 0.22375878 0.32338155 0.13297349 0.02734771 0.01629725
#  0.02761374 0.01603123]
#   基 ('Z', 'X', 'X'): p[:4] = [0.21574728 0.24060776 0.24060776 0.21574728 0.02300881 0.02063615
#  0.02063615 0.02300881]
#   基 ('Z', 'X', 'Y'): p[:4] = [0.10442982 0.35192522 0.35192522 0.10442982 0.02023712 0.02340785
#  0.02340785 0.02023712]
#   基 ('Z', 'X', 'Z'): p[:4] = [0.37761166 0.07874338 0.37761166 0.07874338 0.03879721 0.00484776
#  0.03879721 0.00484776]
#   基 ('Z', 'Y', 'I'): p[:4] = [0.31509472 0.14126032 0.24088308 0.21547196 0.02840462 0.01524034
#  0.02655683 0.01708814]
#   基 ('Z', 'Y', 'X'): p[:4] = [0.35192522 0.10442982 0.10442982 0.35192522 0.02340785 0.02023712
#  0.02023712 0.02340785]
#   基 ('Z', 'Y', 'Y'): p[:4] = [0.21574728 0.24060776 0.24060776 0.21574728 0.02300881 0.02063615
#  0.02063615 0.02300881]
#   基 ('Z', 'Y', 'Z'): p[:4] = [0.37761166 0.07874338 0.37761166 0.07874338 0.03879721 0.00484776
#  0.03879721 0.00484776]
#   基 ('Z', 'Z', 'I'): p[:4] = [0.0285495  0.05539768 0.5274283  0.3013346  0.05379537 0.03172044
#  0.00116607 0.00060804]
#   基 ('Z', 'Z', 'X'): p[:4] = [0.04197359 0.04197359 0.41438145 0.41438145 0.04275791 0.04275791
#  0.00088705 0.00088705]
#   基 ('Z', 'Z', 'Y'): p[:4] = [0.04197359 0.04197359 0.41438145 0.41438145 0.04275791 0.04275791
#  0.00088705 0.00088705]
#   基 ('Z', 'Z', 'Z'): p[:4] = [1.70132144e-03 8.22458524e-02 7.53522000e-01 7.52409015e-02
#  7.58703036e-02 9.64551242e-03 1.72411111e-03 4.99979393e-05]
#
#  窗口位置 1：
#   基 ('I', 'I', 'I'): p[:4] = [0.08951778 0.13907828 0.07189255 0.08933239 0.13880332 0.24353986
#  0.08946368 0.13837214]
#   基 ('I', 'I', 'X'): p[:4] = [0.10320996 0.1253861  0.10639967 0.05482527 0.1563798  0.22596338
#  0.13401056 0.09382525]
#   基 ('I', 'I', 'Y'): p[:4] = [0.13429841 0.09429765 0.07535698 0.08586796 0.2091774  0.17316579
#  0.08116721 0.1466686 ]
#   基 ('I', 'I', 'Z'): p[:4] = [0.03104496 0.1975511  0.03392101 0.12730393 0.05085277 0.33149042
#  0.05321326 0.17462256]
#   基 ('I', 'X', 'I'): p[:4] = [0.10923312 0.1237071  0.05217721 0.10470357 0.12361173 0.14344805
#  0.10465527 0.23846395]
#   基 ('I', 'X', 'X'): p[:4] = [0.11998618 0.11295404 0.08962346 0.06725733 0.11820331 0.14885647
#  0.17218705 0.17093216]
#   基 ('I', 'X', 'Y'): p[:4] = [0.17048728 0.06245294 0.03916811 0.11771267 0.20534179 0.06171799
#  0.08500282 0.2581164 ]
#   基 ('I', 'X', 'Z'): p[:4] = [0.03722591 0.19571431 0.02774005 0.12914073 0.04729009 0.2197697
#  0.05677594 0.28634328]
#   基 ('I', 'Y', 'I'): p[:4] = [0.04718648 0.10219836 0.11422385 0.12621231 0.10177233 0.24884283
#  0.12649467 0.13306917]
#   基 ('I', 'Y', 'X'): p[:4] = [0.03539726 0.11398758 0.17421237 0.06622379 0.08877367 0.26184149
#  0.2016167  0.05794715]
#   基 ('I', 'Y', 'Y'): p[:4] = [0.07823137 0.07115347 0.13142402 0.10901214 0.15995812 0.19065704
#  0.13038649 0.12917735]
#   基 ('I', 'Y', 'Z'): p[:4] = [0.02793081 0.12145403 0.03703516 0.203401   0.05658519 0.29402997
#  0.04748084 0.212083  ]
#   基 ('I', 'Z', 'I'): p[:4] = [0.11213373 0.19132939 0.0492766  0.03708128 0.19102591 0.3383287
#  0.03724109 0.0435833 ]
#   基 ('I', 'Z', 'X'): p[:4] = [0.15424644 0.14921668 0.05536319 0.03099469 0.26216242 0.26719219
#  0.02822794 0.05259644]
#   基 ('I', 'Z', 'Y'): p[:4] = [0.15417658 0.14928654 0.05547881 0.03087907 0.26223229 0.26712233
#  0.02811233 0.05271206]
#   基 ('I', 'Z', 'Z'): p[:4] = [0.02797815 0.27548497 0.03698781 0.04937007 0.04868303 0.48067158
#  0.05538299 0.02544139]
#   基 ('X', 'I', 'I'): p[:4] = [0.10319791 0.15674606 0.10638564 0.13367039 0.12512319 0.22587209
#  0.05497059 0.09403413]
#   基 ('X', 'I', 'X'): p[:4] = [0.12423402 0.13570995 0.16993202 0.07012402 0.13535575 0.21563953
#  0.07047822 0.0785265 ]
#   基 ('X', 'I', 'Y'): p[:4] = [0.14896302 0.11098094 0.10110561 0.13895043 0.19451279 0.15648249
#  0.05541858 0.09358614]
#   基 ('X', 'I', 'Z'): p[:4] = [0.03639669 0.22354728 0.04811931 0.19193673 0.04550104 0.30549424
#  0.03901496 0.10998976]
#   基 ('X', 'X', 'I'): p[:4] = [0.12014228 0.11861381 0.08944128 0.17180263 0.11270257 0.14854134
#  0.0673912  0.17136489]
#   基 ('X', 'X', 'X'): p[:4] = [0.13555581 0.10320028 0.15861023 0.10263368 0.10263368 0.15861023
#  0.10320028 0.13555581]
#   基 ('X', 'X', 'Y'): p[:4] = [0.18232689 0.0564292  0.06774174 0.19350217 0.19350217 0.06774174
#  0.0564292  0.18232689]
#   基 ('X', 'X', 'Z'): p[:4] = [0.04254413 0.19621196 0.04197187 0.21927204 0.04197187 0.21927204
#  0.04254413 0.19621196]
#   基 ('X', 'Y', 'I'): p[:4] = [0.03542661 0.08924033 0.17415694 0.20117612 0.1135322  0.26180087
#  0.06656158 0.05810536]
#   基 ('X', 'Y', 'X'): p[:4] = [0.02150195 0.10316498 0.27266408 0.10266898 0.10266898 0.27266408
#  0.10316498 0.02150195]
#   基 ('X', 'Y', 'Y'): p[:4] = [0.05646253 0.06820441 0.1936061  0.18172696 0.18172696 0.1936061
#  0.06820441 0.05646253]
#   基 ('X', 'Y', 'Z'): p[:4] = [0.02831535 0.09635159 0.05620065 0.31913242 0.05620065 0.31913242
#  0.02831535 0.09635159]
#   基 ('X', 'Z', 'I'): p[:4] = [0.15402484 0.26238403 0.05555871 0.02803242 0.1491348  0.26727407
#  0.03095898 0.05263215]
#   基 ('X', 'Z', 'X'): p[:4] = [0.21564429 0.20076457 0.07852174 0.00506939 0.20076457 0.21564429
#  0.00506939 0.07852174]
#   基 ('X', 'Z', 'Y'): p[:4] = [0.20809964 0.20830923 0.04196899 0.04162214 0.20830923 0.20809964
#  0.04162214 0.04196899]
#   基 ('X', 'Z', 'Z'): p[:4] = [0.03833059 0.37807827 0.0461854  0.03740573 0.03833059 0.37807827
#  0.0461854  0.03740573]
#   基 ('Y', 'I', 'I'): p[:4] = [0.1341561  0.20934324 0.0753817  0.08111896 0.09416499 0.17327491
#  0.08597454 0.14658556]
#   基 ('Y', 'I', 'X'): p[:4] = [0.1488218  0.19467754 0.10110957 0.05539109 0.11076797 0.15667194
#  0.13930066 0.09325943]
#   基 ('Y', 'I', 'Y'): p[:4] = [0.20795473 0.13554461 0.08621131 0.07028935 0.13552108 0.13191882
#  0.07031289 0.16224721]
#   基 ('Y', 'I', 'Z'): p[:4] = [0.04569179 0.29780755 0.0388242  0.11767645 0.03620594 0.23123397
#  0.04831006 0.18425004]
#   基 ('Y', 'X', 'I'): p[:4] = [0.17019723 0.20513583 0.03934057 0.08532637 0.06264762 0.06201932
#  0.11749191 0.25784115]
#   基 ('Y', 'X', 'X'): p[:4] = [0.18172696 0.1936061  0.06820441 0.05646253 0.05646253 0.06820441
#  0.1936061  0.18172696]
#   基 ('Y', 'X', 'Y'): p[:4] = [0.27266408 0.10266898 0.02150195 0.10316498 0.10316498 0.02150195
#  0.10266898 0.27266408]
#   基 ('Y', 'X', 'Z'): p[:4] = [0.05620065 0.31913242 0.02831535 0.09635159 0.02831535 0.09635159
#  0.05620065 0.31913242]
#   基 ('Y', 'Y', 'I'): p[:4] = [0.07817638 0.16057971 0.13136142 0.12988249 0.07078243 0.19046148
#  0.1093571  0.12939899]
#   基 ('Y', 'Y', 'X'): p[:4] = [0.0564292  0.18232689 0.19350217 0.06774174 0.06774174 0.19350217
#  0.18232689 0.0564292 ]
#   基 ('Y', 'Y', 'Y'): p[:4] = [0.13555581 0.10320028 0.15861023 0.10263368 0.10263368 0.15861023
#  0.10320028 0.13555581]
#   基 ('Y', 'Y', 'Z'): p[:4] = [0.04254413 0.19621196 0.04197187 0.21927204 0.04197187 0.21927204
#  0.04254413 0.19621196]
#   基 ('Y', 'Z', 'I'): p[:4] = [0.15409471 0.26231416 0.05544309 0.02814804 0.14906494 0.26734393
#  0.03107459 0.05251654]
#   基 ('Y', 'Z', 'X'): p[:4] = [0.20830923 0.20809964 0.04162214 0.04196899 0.20809964 0.20830923
#  0.04196899 0.04162214]
#   基 ('Y', 'Z', 'Y'): p[:4] = [0.21564429 0.20076457 0.07852174 0.00506939 0.20076457 0.21564429
#  0.00506939 0.07852174]
#   基 ('Y', 'Z', 'Z'): p[:4] = [0.03833059 0.37807827 0.0461854  0.03740573 0.03833059 0.37807827
#  0.0461854  0.03740573]
#   基 ('Z', 'I', 'I'): p[:4] = [0.03119931 0.05114556 0.03391032 0.0532078  0.19712179 0.33147259
#  0.12744591 0.17449672]
#   基 ('Z', 'I', 'X'): p[:4] = [0.03657407 0.0457708  0.04815742 0.0389607  0.22301569 0.30557868
#  0.19225281 0.10968982]
#   基 ('Z', 'I', 'Y'): p[:4] = [0.04597748 0.03636739 0.03875402 0.0483641  0.29749833 0.23109604
#  0.11777017 0.18417246]
#   基 ('Z', 'I', 'Z'): p[:4] = [0.01104639 0.07129848 0.01481951 0.07229861 0.07085133 0.45774304
#  0.07231476 0.22962788]
#   基 ('Z', 'X', 'I'): p[:4] = [0.03735986 0.04737164 0.02774977 0.05698172 0.19548499 0.21978351
#  0.12908271 0.2861858 ]
#   基 ('Z', 'X', 'X'): p[:4] = [0.04267576 0.04205573 0.04205573 0.04267576 0.19551373 0.21975478
#  0.21975478 0.19551373]
#   基 ('Z', 'X', 'Y'): p[:4] = [0.05647085 0.02826064 0.02826064 0.05647085 0.31935821 0.09591029
#  0.09591029 0.31935821]
#   基 ('Z', 'X', 'Z'): p[:4] = [0.01293295 0.07179855 0.01293295 0.07179855 0.07158305 0.34368546
#  0.07158305 0.34368546]
#   基 ('Z', 'Y', 'I'): p[:4] = [0.02795645 0.05677504 0.03715318 0.04757832 0.12100235 0.29426615
#  0.20356535 0.21170316]
#   基 ('Z', 'Y', 'X'): p[:4] = [0.02826064 0.05647085 0.05647085 0.02826064 0.09591029 0.31935821
#  0.31935821 0.09591029]
#   基 ('Z', 'Y', 'Y'): p[:4] = [0.04267576 0.04205573 0.04205573 0.04267576 0.19551373 0.21975478
#  0.21975478 0.19551373]
#   基 ('Z', 'Y', 'Z'): p[:4] = [0.01293295 0.07179855 0.01293295 0.07179855 0.07158305 0.34368546
#  0.07158305 0.34368546]
#   基 ('Z', 'Z', 'I'): p[:4] = [0.02828163 0.04928999 0.036828   0.05506337 0.27487801 0.4803681
#  0.04968969 0.02560121]
#   基 ('Z', 'Z', 'X'): p[:4] = [0.03878581 0.03878581 0.04594568 0.04594568 0.37762306 0.37762306
#  0.03764545 0.03764545]
#   基 ('Z', 'Z', 'Y'): p[:4] = [0.03878581 0.03878581 0.04594568 0.04594568 0.37762306 0.37762306
#  0.03764545 0.03764545]
#   基 ('Z', 'Z', 'Z'): p[:4] = [0.00727327 0.07029835 0.01859262 0.07329874 0.06938791 0.6858582
#  0.07377818 0.00151272]
#
#  窗口位置 2：
#   基 ('I', 'I', 'I'): p[:4] = [0.1386612  0.0896599  0.24371992 0.13889823 0.08940037 0.07195586
#  0.13854118 0.08916334]
#   基 ('I', 'I', 'X'): p[:4] = [0.14687974 0.08144136 0.17333215 0.20928599 0.08582256 0.07553367
#  0.09396555 0.13373898]
#   基 ('I', 'I', 'Y'): p[:4] = [0.09408673 0.13423437 0.22612981 0.15648834 0.05488587 0.10647036
#  0.12489759 0.10280694]
#   基 ('I', 'I', 'Z'): p[:4] = [0.17501712 0.05330398 0.3316978  0.05092035 0.12749269 0.03386354
#  0.19676041 0.03094412]
#   基 ('I', 'X', 'I'): p[:4] = [0.13304019 0.12654958 0.24934093 0.10200855 0.12625508 0.11415515
#  0.10168647 0.04696405]
#   基 ('I', 'X', 'X'): p[:4] = [0.12907388 0.13051589 0.19113801 0.16021147 0.10892248 0.13148776
#  0.07086563 0.07778489]
#   基 ('I', 'X', 'Y'): p[:4] = [0.05799853 0.20159123 0.26221801 0.08913147 0.06640692 0.17400332
#  0.11337654 0.03527398]
#   基 ('I', 'X', 'Z'): p[:4] = [0.21204816 0.04754161 0.29466676 0.05668272 0.20343585 0.03697439
#  0.12081725 0.02783327]
#   基 ('I', 'Y', 'I'): p[:4] = [0.23864034 0.10483547 0.14374078 0.12372266 0.10438463 0.05213956
#  0.12355692 0.10897964]
#   基 ('I', 'Y', 'X'): p[:4] = [0.25827885 0.08519696 0.06193304 0.2055304  0.1173157  0.03920849
#  0.06247241 0.17006415]
#   基 ('I', 'Y', 'Y'): p[:4] = [0.17101923 0.17245658 0.14919732 0.11826612 0.06697713 0.08954706
#  0.11280632 0.11973024]
#   基 ('I', 'Y', 'Z'): p[:4] = [0.28662293 0.05685287 0.22009198 0.04737146 0.12886107 0.02766312
#  0.19539202 0.03714454]
#   基 ('I', 'Z', 'I'): p[:4] = [0.04430306 0.03759466 0.33807805 0.19096347 0.0375614  0.04957286
#  0.19038015 0.11154634]
#   基 ('I', 'Z', 'X'): p[:4] = [0.05328648 0.02861124 0.26692541 0.26211611 0.03122951 0.05590475
#  0.1485586  0.15336789]
#   基 ('I', 'Z', 'Y'): p[:4] = [0.05324244 0.02865528 0.2669741  0.26206742 0.03127355 0.05586071
#  0.1485099  0.15341659]
#   基 ('I', 'Z', 'Z'): p[:4] = [0.02638027 0.05551745 0.48033464 0.04870688 0.05018115 0.03695312
#  0.27407195 0.02785454]
#   基 ('X', 'I', 'I'): p[:4] = [0.14680151 0.08604334 0.17310675 0.0940484  0.08126006 0.07557241
#  0.20915435 0.13401317]
#   基 ('X', 'I', 'X'): p[:4] = [0.16241444 0.07043041 0.13181935 0.1353358  0.07028786 0.08654462
#  0.13547835 0.20768917]
#   基 ('X', 'I', 'Y'): p[:4] = [0.0934697  0.13937515 0.15653728 0.11061787 0.0555029  0.10132958
#  0.19449012 0.1486774 ]
#   基 ('X', 'I', 'Z'): p[:4] = [0.18452038 0.04832447 0.23096362 0.03619153 0.11798943 0.03884305
#  0.29749458 0.04567294]
#   基 ('X', 'X', 'I'): p[:4] = [0.12906235 0.10912714 0.19084591 0.0709646  0.13023292 0.13157759
#  0.16018149 0.078008  ]
#   基 ('X', 'X', 'X'): p[:4] = [0.13520982 0.10297967 0.15902397 0.10278654 0.10278654 0.15902397
#  0.10297967 0.13520982]
#   基 ('X', 'X', 'Y'): p[:4] = [0.05630096 0.18188853 0.19370602 0.06810449 0.06810449 0.19370602
#  0.18188853 0.05630096]
#   基 ('X', 'X', 'Z'): p[:4] = [0.19567626 0.04251323 0.21980774 0.04200277 0.21980774 0.04200277
#  0.19567626 0.04251323]
#   基 ('X', 'Y', 'I'): p[:4] = [0.25811636 0.11771271 0.0617919  0.06237903 0.08490861 0.03926232
#  0.2055058  0.17032327]
#   基 ('X', 'Y', 'X'): p[:4] = [0.2728287  0.10300037 0.02140508 0.10276585 0.10276585 0.02140508
#  0.10300037 0.2728287 ]
#   基 ('X', 'Y', 'Y'): p[:4] = [0.1819162  0.19391286 0.06809078 0.05608016 0.05608016 0.06809078
#  0.19391286 0.1819162 ]
#   基 ('X', 'Y', 'Z'): p[:4] = [0.31960417 0.0562249  0.09587984 0.0282911  0.09587984 0.0282911
#  0.31960417 0.0562249 ]
#   基 ('X', 'Z', 'I'): p[:4] = [0.05322581 0.03129018 0.26668244 0.14880156 0.02863866 0.05587734
#  0.26177576 0.15370825]
#   基 ('X', 'Z', 'X'): p[:4] = [0.07920479 0.0053112  0.21502899 0.20045502 0.0053112  0.07920479
#  0.20045502 0.21502899]
#   基 ('X', 'Z', 'Y'): p[:4] = [0.04219194 0.04232406 0.20781504 0.20766896 0.04232406 0.04219194
#  0.20766896 0.20781504]
#   基 ('X', 'Z', 'Z'): p[:4] = [0.03828071 0.04623529 0.3772033  0.03828071 0.03828071 0.04623529
#  0.3772033  0.03828071]
#   基 ('Y', 'I', 'I'): p[:4] = [0.09399436 0.05496445 0.22590924 0.12513195 0.13406721 0.10665131
#  0.15635186 0.10292962]
#   基 ('Y', 'I', 'X'): p[:4] = [0.09343091 0.05552789 0.15656211 0.19447909 0.13927139 0.10144714
#  0.11073559 0.14854588]
#   基 ('Y', 'I', 'Y'): p[:4] = [0.07860656 0.07035224 0.21562722 0.13541398 0.07036604 0.17035249
#  0.13540018 0.1238813 ]
#   基 ('Y', 'I', 'Z'): p[:4] = [0.1099456  0.0390132  0.3055384  0.04550279 0.19256421 0.04815432
#  0.2229198  0.03636168]
#   基 ('Y', 'X', 'I'): p[:4] = [0.05778836 0.06638258 0.26211524 0.11371382 0.20150691 0.17432215
#  0.08891216 0.03525878]
#   基 ('Y', 'X', 'X'): p[:4] = [0.05608016 0.06809078 0.19391286 0.1819162  0.1819162  0.19391286
#  0.06809078 0.05608016]
#   基 ('Y', 'X', 'Y'): p[:4] = [0.02140508 0.10276585 0.2728287  0.10300037 0.10300037 0.2728287
#  0.10276585 0.02140508]
#   基 ('Y', 'X', 'Z'): p[:4] = [0.09587984 0.0282911  0.31960417 0.0562249  0.31960417 0.0562249
#  0.09587984 0.0282911 ]
#   基 ('Y', 'Y', 'I'): p[:4] = [0.17092487 0.06726462 0.14897873 0.11283178 0.1721001  0.08971041
#  0.11831897 0.11987052]
#   基 ('Y', 'Y', 'X'): p[:4] = [0.18188853 0.05630096 0.06810449 0.19370602 0.19370602 0.06810449
#  0.05630096 0.18188853]
#   基 ('Y', 'Y', 'Y'): p[:4] = [0.13520982 0.10297967 0.15902397 0.10278654 0.10278654 0.15902397
#  0.10297967 0.13520982]
#   基 ('Y', 'Y', 'Z'): p[:4] = [0.19567626 0.04251323 0.21980774 0.04200277 0.21980774 0.04200277
#  0.19567626 0.04251323]
#   基 ('Y', 'Z', 'I'): p[:4] = [0.05326985 0.03124614 0.26663375 0.14885026 0.02859462 0.05592138
#  0.26182445 0.15365955]
#   基 ('Y', 'Z', 'X'): p[:4] = [0.04232406 0.04219194 0.20766896 0.20781504 0.04219194 0.04232406
#  0.20781504 0.20766896]
#   基 ('Y', 'Z', 'Y'): p[:4] = [0.07920479 0.0053112  0.21502899 0.20045502 0.0053112  0.07920479
#  0.20045502 0.21502899]
#   基 ('Y', 'Z', 'Z'): p[:4] = [0.03828071 0.04623529 0.3772033  0.03828071 0.03828071 0.04623529
#  0.3772033  0.03828071]
#   基 ('Z', 'I', 'I'): p[:4] = [0.17518772 0.12797192 0.33214377 0.19751433 0.05287385 0.03364384
#  0.05011733 0.03054724]
#   基 ('Z', 'I', 'X'): p[:4] = [0.18479386 0.11836578 0.23161501 0.29804308 0.04790844 0.03860925
#  0.03568269 0.04498189]
#   基 ('Z', 'I', 'Y'): p[:4] = [0.11018393 0.19297571 0.30622493 0.22343316 0.03878867 0.04772902
#  0.04480247 0.03586211]
#   基 ('Z', 'I', 'Z'): p[:4] = [0.23058538 0.07257426 0.45859136 0.07106674 0.07192443 0.01459326
#  0.06986684 0.01079773]
#   基 ('Z', 'X', 'I'): p[:4] = [0.21226986 0.20413901 0.29506163 0.12134724 0.04702541 0.03656572
#  0.05596577 0.02762536]
#   基 ('Z', 'X', 'X'): p[:4] = [0.19593166 0.22047721 0.22047721 0.19593166 0.0420647  0.04152644
#  0.04152644 0.0420647 ]
#   基 ('Z', 'X', 'Y'): p[:4] = [0.09628955 0.32011932 0.32011932 0.09628955 0.0281159  0.05547523
#  0.05547523 0.0281159 ]
#   基 ('Z', 'X', 'Z'): p[:4] = [0.34458837 0.0718205  0.34458837 0.0718205  0.07089564 0.01269549
#  0.07089564 0.01269549]
#   基 ('Z', 'Y', 'I'): p[:4] = [0.28687978 0.12952909 0.22045171 0.19595716 0.05614519 0.02744594
#  0.04684599 0.03674514]
#   基 ('Z', 'Y', 'X'): p[:4] = [0.32011932 0.09628955 0.09628955 0.32011932 0.05547523 0.0281159
#  0.0281159  0.05547523]
#   基 ('Z', 'Y', 'Y'): p[:4] = [0.19593166 0.22047721 0.22047721 0.19593166 0.0420647  0.04152644
#  0.04152644 0.0420647 ]
#   基 ('Z', 'Y', 'Z'): p[:4] = [0.34458837 0.0718205  0.34458837 0.0718205  0.07089564 0.01269549
#  0.07089564 0.01269549]
#   基 ('Z', 'Z', 'I'): p[:4] = [0.02641353 0.05024766 0.48091796 0.27523859 0.05545094 0.03691986
#  0.04754024 0.02727122]
#   基 ('Z', 'Z', 'X'): p[:4] = [0.03833059 0.03833059 0.37807827 0.37807827 0.0461854  0.0461854
#  0.03740573 0.03740573]
#   基 ('Z', 'Z', 'Y'): p[:4] = [0.03833059 0.03833059 0.37807827 0.37807827 0.0461854  0.0461854
#  0.03740573 0.03740573]
#   基 ('Z', 'Z', 'Z'): p[:4] = [0.00257939 0.07408179 0.68659734 0.06955921 0.07398202 0.01838878
#  0.06780925 0.00700221]
#
#  窗口位置 3：
#   基 ('I', 'I', 'I'): p[:4] = [0.08916334 0.13889823 0.07195586 0.0896599  0.13854118 0.24371992
#  0.08940037 0.1386612 ]
#   基 ('I', 'I', 'X'): p[:4] = [0.10292962 0.12513195 0.10665131 0.05496445 0.15635186 0.22590924
#  0.13406721 0.09399436]
#   基 ('I', 'I', 'Y'): p[:4] = [0.13401317 0.0940484  0.07557241 0.08604334 0.20915435 0.17310675
#  0.08126006 0.14680151]
#   基 ('I', 'I', 'Z'): p[:4] = [0.03054724 0.19751433 0.03364384 0.12797192 0.05011733 0.33214377
#  0.05287385 0.17518772]
#   基 ('I', 'X', 'I'): p[:4] = [0.10897964 0.12372266 0.05213956 0.10483547 0.12355692 0.14374078
#  0.10438463 0.23864034]
#   基 ('I', 'X', 'X'): p[:4] = [0.11987052 0.11283178 0.08971041 0.06726462 0.11831897 0.14897873
#  0.1721001  0.17092487]
#   基 ('I', 'X', 'Y'): p[:4] = [0.17032327 0.06237903 0.03926232 0.11771271 0.2055058  0.0617919
#  0.08490861 0.25811636]
#   基 ('I', 'X', 'Z'): p[:4] = [0.03674514 0.19595716 0.02744594 0.12952909 0.04684599 0.22045171
#  0.05614519 0.28687978]
#   基 ('I', 'Y', 'I'): p[:4] = [0.04696405 0.10200855 0.11415515 0.12654958 0.10168647 0.24934093
#  0.12625508 0.13304019]
#   基 ('I', 'Y', 'X'): p[:4] = [0.03525878 0.11371382 0.17432215 0.06638258 0.08891216 0.26211524
#  0.20150691 0.05778836]
#   基 ('I', 'Y', 'Y'): p[:4] = [0.078008   0.0709646  0.13157759 0.10912714 0.16018149 0.19084591
#  0.13023292 0.12906235]
#   基 ('I', 'Y', 'Z'): p[:4] = [0.02762536 0.12134724 0.03656572 0.20413901 0.05596577 0.29506163
#  0.04702541 0.21226986]
#   基 ('I', 'Z', 'I'): p[:4] = [0.11154634 0.19096347 0.04957286 0.03759466 0.19038015 0.33807805
#  0.0375614  0.04430306]
#   基 ('I', 'Z', 'X'): p[:4] = [0.15365955 0.14885026 0.05592138 0.03124614 0.26182445 0.26663375
#  0.02859462 0.05326985]
#   基 ('I', 'Z', 'Y'): p[:4] = [0.15370825 0.14880156 0.05587734 0.03129018 0.26177576 0.26668244
#  0.02863866 0.05322581]
#   基 ('I', 'Z', 'Z'): p[:4] = [0.02727122 0.27523859 0.03691986 0.05024766 0.04754024 0.48091796
#  0.05545094 0.02641353]
#   基 ('X', 'I', 'I'): p[:4] = [0.10280694 0.15648834 0.10647036 0.13423437 0.12489759 0.22612981
#  0.05488587 0.09408673]
#   基 ('X', 'I', 'X'): p[:4] = [0.1238813  0.13541398 0.17035249 0.07035224 0.13540018 0.21562722
#  0.07036604 0.07860656]
#   基 ('X', 'I', 'Y'): p[:4] = [0.1486774  0.11061787 0.10132958 0.13937515 0.19449012 0.15653728
#  0.0555029  0.0934697 ]
#   基 ('X', 'I', 'Z'): p[:4] = [0.03586211 0.22343316 0.04772902 0.19297571 0.04480247 0.30622493
#  0.03878867 0.11018393]
#   基 ('X', 'X', 'I'): p[:4] = [0.11973024 0.11826612 0.08954706 0.17245658 0.11280632 0.14919732
#  0.06697713 0.17101923]
#   基 ('X', 'X', 'X'): p[:4] = [0.13520982 0.10278654 0.15902397 0.10297967 0.10297967 0.15902397
#  0.10278654 0.13520982]
#   基 ('X', 'X', 'Y'): p[:4] = [0.1819162  0.05608016 0.06809078 0.19391286 0.19391286 0.06809078
#  0.05608016 0.1819162 ]
#   基 ('X', 'X', 'Z'): p[:4] = [0.0420647  0.19593166 0.04152644 0.22047721 0.04152644 0.22047721
#  0.0420647  0.19593166]
#   基 ('X', 'Y', 'I'): p[:4] = [0.03527398 0.08913147 0.17400332 0.20159123 0.11337654 0.26221801
#  0.06640692 0.05799853]
#   基 ('X', 'Y', 'X'): p[:4] = [0.02140508 0.10300037 0.2728287  0.10276585 0.10276585 0.2728287
#  0.10300037 0.02140508]
#   基 ('X', 'Y', 'Y'): p[:4] = [0.05630096 0.06810449 0.19370602 0.18188853 0.18188853 0.19370602
#  0.06810449 0.05630096]
#   基 ('X', 'Y', 'Z'): p[:4] = [0.0281159  0.09628955 0.05547523 0.32011932 0.05547523 0.32011932
#  0.0281159  0.09628955]
#   基 ('X', 'Z', 'I'): p[:4] = [0.15341659 0.26206742 0.05586071 0.02865528 0.1485099  0.2669741
#  0.03127355 0.05324244]
#   基 ('X', 'Z', 'X'): p[:4] = [0.21502899 0.20045502 0.07920479 0.0053112  0.20045502 0.21502899
#  0.0053112  0.07920479]
#   基 ('X', 'Z', 'Y'): p[:4] = [0.20781504 0.20766896 0.04219194 0.04232406 0.20766896 0.20781504
#  0.04232406 0.04219194]
#   基 ('X', 'Z', 'Z'): p[:4] = [0.03740573 0.37807827 0.0461854  0.03833059 0.03740573 0.37807827
#  0.0461854  0.03833059]
#   基 ('Y', 'I', 'I'): p[:4] = [0.13373898 0.20928599 0.07553367 0.08144136 0.09396555 0.17333215
#  0.08582256 0.14687974]
#   基 ('Y', 'I', 'X'): p[:4] = [0.14854588 0.19447909 0.10144714 0.05552789 0.11073559 0.15656211
#  0.13927139 0.09343091]
#   基 ('Y', 'I', 'Y'): p[:4] = [0.20768917 0.1353358  0.08654462 0.07043041 0.13547835 0.13181935
#  0.07028786 0.16241444]
#   基 ('Y', 'I', 'Z'): p[:4] = [0.04498189 0.29804308 0.03860925 0.11836578 0.03568269 0.23161501
#  0.04790844 0.18479386]
#   基 ('Y', 'X', 'I'): p[:4] = [0.17006415 0.2055304  0.03920849 0.08519696 0.06247241 0.06193304
#  0.1173157  0.25827885]
#   基 ('Y', 'X', 'X'): p[:4] = [0.18188853 0.19370602 0.06810449 0.05630096 0.05630096 0.06810449
#  0.19370602 0.18188853]
#   基 ('Y', 'X', 'Y'): p[:4] = [0.2728287  0.10276585 0.02140508 0.10300037 0.10300037 0.02140508
#  0.10276585 0.2728287 ]
#   基 ('Y', 'X', 'Z'): p[:4] = [0.05547523 0.32011932 0.0281159  0.09628955 0.0281159  0.09628955
#  0.05547523 0.32011932]
#   基 ('Y', 'Y', 'I'): p[:4] = [0.07778489 0.16021147 0.13148776 0.13051589 0.07086563 0.19113801
#  0.10892248 0.12907388]
#   基 ('Y', 'Y', 'X'): p[:4] = [0.05608016 0.1819162  0.19391286 0.06809078 0.06809078 0.19391286
#  0.1819162  0.05608016]
#   基 ('Y', 'Y', 'Y'): p[:4] = [0.13520982 0.10278654 0.15902397 0.10297967 0.10297967 0.15902397
#  0.10278654 0.13520982]
#   基 ('Y', 'Y', 'Z'): p[:4] = [0.0420647  0.19593166 0.04152644 0.22047721 0.04152644 0.22047721
#  0.0420647  0.19593166]
#   基 ('Y', 'Z', 'I'): p[:4] = [0.15336789 0.26211611 0.05590475 0.02861124 0.1485586  0.26692541
#  0.03122951 0.05328648]
#   基 ('Y', 'Z', 'X'): p[:4] = [0.20766896 0.20781504 0.04232406 0.04219194 0.20781504 0.20766896
#  0.04219194 0.04232406]
#   基 ('Y', 'Z', 'Y'): p[:4] = [0.21502899 0.20045502 0.07920479 0.0053112  0.20045502 0.21502899
#  0.0053112  0.07920479]
#   基 ('Y', 'Z', 'Z'): p[:4] = [0.03740573 0.37807827 0.0461854  0.03833059 0.03740573 0.37807827
#  0.0461854  0.03833059]
#   基 ('Z', 'I', 'I'): p[:4] = [0.03094412 0.05092035 0.03386354 0.05330398 0.19676041 0.3316978
#  0.12749269 0.17501712]
#   基 ('Z', 'I', 'X'): p[:4] = [0.03636168 0.04550279 0.04815432 0.0390132  0.2229198  0.3055384
#  0.19256421 0.1099456 ]
#   基 ('Z', 'I', 'Y'): p[:4] = [0.04567294 0.03619153 0.03884305 0.04832447 0.29749458 0.23096362
#  0.11798943 0.18452038]
#   基 ('Z', 'I', 'Z'): p[:4] = [0.01079773 0.07106674 0.01459326 0.07257426 0.06986684 0.45859136
#  0.07192443 0.23058538]
#   基 ('Z', 'X', 'I'): p[:4] = [0.03714454 0.04737146 0.02766312 0.05685287 0.19539202 0.22009198
#  0.12886107 0.28662293]
#   基 ('Z', 'X', 'X'): p[:4] = [0.04251323 0.04200277 0.04200277 0.04251323 0.19567626 0.21980774
#  0.21980774 0.19567626]
#   基 ('Z', 'X', 'Y'): p[:4] = [0.0562249  0.0282911  0.0282911  0.0562249  0.31960417 0.09587984
#  0.09587984 0.31960417]
#   基 ('Z', 'X', 'Z'): p[:4] = [0.01269549 0.0718205  0.01269549 0.0718205  0.07089564 0.34458837
#  0.07089564 0.34458837]
#   基 ('Z', 'Y', 'I'): p[:4] = [0.02783327 0.05668272 0.03697439 0.04754161 0.12081725 0.29466676
#  0.20343585 0.21204816]
#   基 ('Z', 'Y', 'X'): p[:4] = [0.0282911  0.0562249  0.0562249  0.0282911  0.09587984 0.31960417
#  0.31960417 0.09587984]
#   基 ('Z', 'Y', 'Y'): p[:4] = [0.04251323 0.04200277 0.04200277 0.04251323 0.19567626 0.21980774
#  0.21980774 0.19567626]
#   基 ('Z', 'Y', 'Z'): p[:4] = [0.01269549 0.0718205  0.01269549 0.0718205  0.07089564 0.34458837
#  0.07089564 0.34458837]
#   基 ('Z', 'Z', 'I'): p[:4] = [0.02785454 0.04870688 0.03695312 0.05551745 0.27407195 0.48033464
#  0.05018115 0.02638027]
#   基 ('Z', 'Z', 'X'): p[:4] = [0.03828071 0.03828071 0.04623529 0.04623529 0.3772033  0.3772033
#  0.03828071 0.03828071]
#   基 ('Z', 'Z', 'Y'): p[:4] = [0.03828071 0.03828071 0.04623529 0.04623529 0.3772033  0.3772033
#  0.03828071 0.03828071]
#   基 ('Z', 'Z', 'Z'): p[:4] = [0.00700221 0.06955921 0.01838878 0.07408179 0.06780925 0.68659734
#  0.07398202 0.00257939]

# %%
def pauli_string_expectation(pvec, basis, all_bitstrings):
    """给定概率向量 p(x)，和 Pauli 基 basis，计算期望值 ⟨P⟩"""
    expval = 0.0
    for idx, bitstr in enumerate(all_bitstrings):
        val = 1.0
        for i, pauli in enumerate(basis):
            if pauli == 'I':
                continue
            elif pauli in ['X', 'Y', 'Z']:
                bit = int(bitstr[i])
                val *= 1 if bit == 0 else -1
        expval += pvec[idx] * val
    return expval
def compute_all_expectations(completed_local_probs, k):
    """计算所有窗口中所有 4^k 基的期望值"""
    all_bitstrings = generate_all_bitstrings(k)
    all_expectations = {}

    for i, basis_dict in completed_local_probs.items():
        all_expectations[i] = {}
        for basis, pvec in basis_dict.items():
            if pvec is None:
                all_expectations[i][basis] = None
            else:
                expval = pauli_string_expectation(pvec, basis, all_bitstrings)
                all_expectations[i][basis] = expval
    return all_expectations

# %%
all_expectations = compute_all_expectations(completed_local_probs, k)

# 查看前两个窗口前几个基的期望值
for i in range(min(5, len(all_expectations))):
    print(f"\n窗口 {i}：")
    cnt = 0
    for b, v in all_expectations[i].items():
        if v is not None:
            print(f"  基 {b} 的期望值 ⟨P⟩ = {v}")
            cnt += 1
# Out:
# 窗口 0：
#   基 ('I', 'I', 'I') 的期望值 ⟨P⟩ = 0.999999999999999
#   基 ('I', 'I', 'X') 的期望值 ⟨P⟩ = -4.163336342344337e-17
#   基 ('I', 'I', 'Y') 的期望值 ⟨P⟩ = 1.3877787807814457e-17
#   基 ('I', 'I', 'Z') 的期望值 ⟨P⟩ = 0.6656354714960993
#   基 ('I', 'X', 'I') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'X', 'X') 的期望值 ⟨P⟩ = -0.04497564661972034
#   基 ('I', 'X', 'Y') 的期望值 ⟨P⟩ = -0.5013322590983172
#   基 ('I', 'X', 'Z') 的期望值 ⟨P⟩ = 1.0408340855860843e-17
#   基 ('I', 'Y', 'I') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('I', 'Y', 'X') 的期望值 ⟨P⟩ = 0.5013322590983171
#   基 ('I', 'Y', 'Y') 的期望值 ⟨P⟩ = -0.04497564661972031
#   基 ('I', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'Z', 'I') 的期望值 ⟨P⟩ = -0.6610740203395036
#   基 ('I', 'Z', 'X') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('I', 'Z', 'Y') 的期望值 ⟨P⟩ = -2.7755575615628914e-17
#   基 ('I', 'Z', 'Z') 的期望值 ⟨P⟩ = -0.6942749511019086
#   基 ('X', 'I', 'I') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('X', 'I', 'X') 的期望值 ⟨P⟩ = 0.1750108749852746
#   基 ('X', 'I', 'Y') 的期望值 ⟨P⟩ = 0.006905264685119372
#   基 ('X', 'I', 'Z') 的期望值 ⟨P⟩ = 1.3183898417423734e-16
#   基 ('X', 'X', 'I') 的期望值 ⟨P⟩ = -0.028667061579872505
#   基 ('X', 'X', 'X') 的期望值 ⟨P⟩ = 0.0
#   基 ('X', 'X', 'Y') 的期望值 ⟨P⟩ = -2.0816681711721685e-17
#   基 ('X', 'X', 'Z') 的期望值 ⟨P⟩ = -0.0267153413182833
#   基 ('X', 'Y', 'I') 的期望值 ⟨P⟩ = 0.5312062272688035
#   基 ('X', 'Y', 'X') 的期望值 ⟨P⟩ = 0.0
#   基 ('X', 'Y', 'Y') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('X', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.4235496782405887
#   基 ('X', 'Z', 'I') 的期望值 ⟨P⟩ = 8.326672684688674e-17
#   基 ('X', 'Z', 'X') 的期望值 ⟨P⟩ = 0.14052511913843058
#   基 ('X', 'Z', 'Y') 的期望值 ⟨P⟩ = -0.02016395139711505
#   基 ('X', 'Z', 'Z') 的期望值 ⟨P⟩ = 1.3877787807814457e-17
#   基 ('Y', 'I', 'I') 的期望值 ⟨P⟩ = -1.3877787807814457e-17
#   基 ('Y', 'I', 'X') 的期望值 ⟨P⟩ = -0.0069052646851194
#   基 ('Y', 'I', 'Y') 的期望值 ⟨P⟩ = 0.17501087498527473
#   基 ('Y', 'I', 'Z') 的期望值 ⟨P⟩ = -6.938893903907228e-18
#   基 ('Y', 'X', 'I') 的期望值 ⟨P⟩ = -0.5312062272688036
#   基 ('Y', 'X', 'X') 的期望值 ⟨P⟩ = -6.938893903907228e-17
#   基 ('Y', 'X', 'Y') 的期望值 ⟨P⟩ = 3.469446951953614e-18
#   基 ('Y', 'X', 'Z') 的期望值 ⟨P⟩ = -0.4235496782405888
#   基 ('Y', 'Y', 'I') 的期望值 ⟨P⟩ = -0.02866706157987249
#   基 ('Y', 'Y', 'X') 的期望值 ⟨P⟩ = 8.326672684688674e-17
#   基 ('Y', 'Y', 'Y') 的期望值 ⟨P⟩ = 8.326672684688674e-17
#   基 ('Y', 'Y', 'Z') 的期望值 ⟨P⟩ = -0.02671534131828336
#   基 ('Y', 'Z', 'I') 的期望值 ⟨P⟩ = -2.7755575615628914e-17
#   基 ('Y', 'Z', 'X') 的期望值 ⟨P⟩ = 0.020163951397115187
#   基 ('Y', 'Z', 'Y') 的期望值 ⟨P⟩ = 0.14052511913843063
#   基 ('Y', 'Z', 'Z') 的期望值 ⟨P⟩ = 6.938893903907228e-17
#   基 ('Z', 'I', 'I') 的期望值 ⟨P⟩ = 0.8254201499247206
#   基 ('Z', 'I', 'X') 的期望值 ⟨P⟩ = 6.938893903907228e-18
#   基 ('Z', 'I', 'Y') 的期望值 ⟨P⟩ = -8.153200337090993e-17
#   基 ('Z', 'I', 'Z') 的期望值 ⟨P⟩ = 0.5298376628489301
#   基 ('Z', 'X', 'I') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Z', 'X', 'X') 的期望值 ⟨P⟩ = -0.054466272241795434
#   基 ('Z', 'X', 'Y') 的期望值 ⟨P⟩ = -0.4886493463794587
#   基 ('Z', 'X', 'Z') 的期望值 ⟨P⟩ = 4.0766001685454967e-17
#   基 ('Z', 'Y', 'I') 的期望值 ⟨P⟩ = -6.245004513516506e-17
#   基 ('Z', 'Y', 'X') 的期望值 ⟨P⟩ = 0.48864934637945884
#   基 ('Z', 'Y', 'Y') 的期望值 ⟨P⟩ = -0.054466272241795434
#   基 ('Z', 'Y', 'Z') 的期望值 ⟨P⟩ = -1.474514954580286e-17
#   基 ('Z', 'Z', 'I') 的期望值 ⟨P⟩ = -0.8285574342369014
#   基 ('Z', 'Z', 'X') 的期望值 ⟨P⟩ = 5.5402731014009277e-17
#   基 ('Z', 'Z', 'Y') 的期望值 ⟨P⟩ = 5.5402731014009277e-17
#   基 ('Z', 'Z', 'Z') 的期望值 ⟨P⟩ = -0.8233763070857857
#
# 窗口 1：
#   基 ('I', 'I', 'I') 的期望值 ⟨P⟩ = 0.9999999999999989
#   基 ('I', 'I', 'X') 的期望值 ⟨P⟩ = 8.326672684688674e-17
#   基 ('I', 'I', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('I', 'I', 'Z') 的期望值 ⟨P⟩ = -0.6619360213492678
#   基 ('I', 'X', 'I') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'X', 'X') 的期望值 ⟨P⟩ = -0.04724204050835226
#   基 ('I', 'X', 'Y') 的期望值 ⟨P⟩ = 0.5033162609464583
#   基 ('I', 'X', 'Z') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('I', 'Y', 'I') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('I', 'Y', 'X') 的期望值 ⟨P⟩ = -0.5033162609464583
#   基 ('I', 'Y', 'Y') 的期望值 ⟨P⟩ = -0.04724204050835243
#   基 ('I', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'Z', 'I') 的期望值 ⟨P⟩ = 0.665635471496099
#   基 ('I', 'Z', 'X') 的期望值 ⟨P⟩ = 6.938893903907228e-17
#   基 ('I', 'Z', 'Y') 的期望值 ⟨P⟩ = 6.245004513516506e-17
#   基 ('I', 'Z', 'Z') 的期望值 ⟨P⟩ = -0.6970547048055444
#   基 ('X', 'I', 'I') 的期望值 ⟨P⟩ = -4.163336342344337e-17
#   基 ('X', 'I', 'X') 的期望值 ⟨P⟩ = 0.17666413845176382
#   基 ('X', 'I', 'Y') 的期望值 ⟨P⟩ = 0.00027452135322435234
#   基 ('X', 'I', 'Z') 的期望值 ⟨P⟩ = -6.938893903907228e-17
#   基 ('X', 'X', 'I') 的期望值 ⟨P⟩ = -0.04497564661972042
#   基 ('X', 'X', 'X') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('X', 'X', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('X', 'X', 'Z') 的期望值 ⟨P⟩ = 0.047264683805854774
#   基 ('X', 'Y', 'I') 的期望值 ⟨P⟩ = -0.5013322590983171
#   基 ('X', 'Y', 'X') 的期望值 ⟨P⟩ = 3.469446951953614e-17
#   基 ('X', 'Y', 'Y') 的期望值 ⟨P⟩ = 9.71445146547012e-17
#   基 ('X', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.38979104634258727
#   基 ('X', 'Z', 'I') 的期望值 ⟨P⟩ = -4.163336342344337e-17
#   基 ('X', 'Z', 'X') 的期望值 ⟨P⟩ = -0.11714526475915929
#   基 ('X', 'Z', 'Y') 的期望值 ⟨P⟩ = -0.001112879455502272
#   基 ('X', 'Z', 'Z') 的期望值 ⟨P⟩ = -2.0816681711721685e-17
#   基 ('Y', 'I', 'I') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Y', 'I', 'X') 的期望值 ⟨P⟩ = -0.0002745213532242968
#   基 ('Y', 'I', 'Y') 的期望值 ⟨P⟩ = 0.17666413845176385
#   基 ('Y', 'I', 'Z') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Y', 'X', 'I') 的期望值 ⟨P⟩ = 0.5013322590983174
#   基 ('Y', 'X', 'X') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('Y', 'X', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Y', 'X', 'Z') 的期望值 ⟨P⟩ = -0.3897910463425873
#   基 ('Y', 'Y', 'I') 的期望值 ⟨P⟩ = -0.04497564661972048
#   基 ('Y', 'Y', 'X') 的期望值 ⟨P⟩ = 0.0
#   基 ('Y', 'Y', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Y', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.04726468380585469
#   基 ('Y', 'Z', 'I') 的期望值 ⟨P⟩ = -9.020562075079397e-17
#   基 ('Y', 'Z', 'X') 的期望值 ⟨P⟩ = 0.0011128794555025356
#   基 ('Y', 'Z', 'Y') 的期望值 ⟨P⟩ = -0.11714526475915929
#   基 ('Y', 'Z', 'Z') 的期望值 ⟨P⟩ = 3.469446951953614e-17
#   基 ('Z', 'I', 'I') 的期望值 ⟨P⟩ = -0.6610740203395036
#   基 ('Z', 'I', 'X') 的期望值 ⟨P⟩ = -1.3877787807814457e-17
#   基 ('Z', 'I', 'Y') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Z', 'I', 'Z') 的期望值 ⟨P⟩ = 0.4264736345424915
#   基 ('Z', 'X', 'I') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Z', 'X', 'X') 的期望值 ⟨P⟩ = 0.04972217452029595
#   基 ('Z', 'X', 'Y') 的期望值 ⟨P⟩ = -0.3904754099250558
#   基 ('Z', 'X', 'Z') 的期望值 ⟨P⟩ = -1.1102230246251565e-16
#   基 ('Z', 'Y', 'I') 的期望值 ⟨P⟩ = 0.0
#   基 ('Z', 'Y', 'X') 的期望值 ⟨P⟩ = 0.390475409925056
#   基 ('Z', 'Y', 'Y') 的期望值 ⟨P⟩ = 0.04972217452029598
#   基 ('Z', 'Y', 'Z') 的期望值 ⟨P⟩ = -1.1102230246251565e-16
#   基 ('Z', 'Z', 'I') 的期望值 ⟨P⟩ = -0.6942749511019085
#   基 ('Z', 'Z', 'X') 的期望值 ⟨P⟩ = -6.245004513516506e-17
#   基 ('Z', 'Z', 'Y') 的期望值 ⟨P⟩ = -6.938893903907228e-18
#   基 ('Z', 'Z', 'Z') 的期望值 ⟨P⟩ = 0.6804167887156783
#
# 窗口 2：
#   基 ('I', 'I', 'I') 的期望值 ⟨P⟩ = 0.9999999999999991
#   基 ('I', 'I', 'X') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('I', 'I', 'Y') 的期望值 ⟨P⟩ = 8.326672684688674e-17
#   基 ('I', 'I', 'Z') 的期望值 ⟨P⟩ = 0.6619360213492679
#   基 ('I', 'X', 'I') 的期望值 ⟨P⟩ = -1.3877787807814457e-17
#   基 ('I', 'X', 'X') 的期望值 ⟨P⟩ = -0.048014569159081116
#   基 ('I', 'X', 'Y') 的期望值 ⟨P⟩ = -0.5023781911391809
#   基 ('I', 'X', 'Z') 的期望值 ⟨P⟩ = 3.122502256758253e-17
#   基 ('I', 'Y', 'I') 的期望值 ⟨P⟩ = -2.7755575615628914e-17
#   基 ('I', 'Y', 'X') 的期望值 ⟨P⟩ = 0.502378191139181
#   基 ('I', 'Y', 'Y') 的期望值 ⟨P⟩ = -0.04801456915908109
#   基 ('I', 'Y', 'Z') 的期望值 ⟨P⟩ = -2.0816681711721685e-17
#   基 ('I', 'Z', 'I') 的期望值 ⟨P⟩ = -0.6619360213492679
#   基 ('I', 'Z', 'X') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'Z', 'Y') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'Z', 'Z') 的期望值 ⟨P⟩ = -0.6937543243423084
#   基 ('X', 'I', 'I') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('X', 'I', 'X') 的期望值 ⟨P⟩ = 0.17693513192745525
#   基 ('X', 'I', 'Y') 的期望值 ⟨P⟩ = 2.7921755086757205e-05
#   基 ('X', 'I', 'Z') 的期望值 ⟨P⟩ = -7.632783294297951e-17
#   基 ('X', 'X', 'I') 的期望值 ⟨P⟩ = -0.04724204050835232
#   基 ('X', 'X', 'X') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('X', 'X', 'Y') 的期望值 ⟨P⟩ = -6.938893903907228e-17
#   基 ('X', 'X', 'Z') 的期望值 ⟨P⟩ = -0.04928386990134452
#   基 ('X', 'Y', 'I') 的期望值 ⟨P⟩ = 0.5033162609464584
#   基 ('X', 'Y', 'X') 的期望值 ⟨P⟩ = -1.1102230246251565e-16
#   基 ('X', 'Y', 'Y') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('X', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.3915810670141291
#   基 ('X', 'Z', 'I') 的期望值 ⟨P⟩ = -1.3877787807814457e-16
#   基 ('X', 'Z', 'X') 的期望值 ⟨P⟩ = 0.11863923700033516
#   基 ('X', 'Z', 'Y') 的期望值 ⟨P⟩ = -0.0005563911630980523
#   基 ('X', 'Z', 'Z') 的期望值 ⟨P⟩ = 6.245004513516506e-17
#   基 ('Y', 'I', 'I') 的期望值 ⟨P⟩ = 4.163336342344337e-17
#   基 ('Y', 'I', 'X') 的期望值 ⟨P⟩ = -2.792175508672945e-05
#   基 ('Y', 'I', 'Y') 的期望值 ⟨P⟩ = 0.17693513192745525
#   基 ('Y', 'I', 'Z') 的期望值 ⟨P⟩ = -7.632783294297951e-17
#   基 ('Y', 'X', 'I') 的期望值 ⟨P⟩ = -0.5033162609464584
#   基 ('Y', 'X', 'X') 的期望值 ⟨P⟩ = 3.469446951953614e-17
#   基 ('Y', 'X', 'Y') 的期望值 ⟨P⟩ = -1.0408340855860843e-17
#   基 ('Y', 'X', 'Z') 的期望值 ⟨P⟩ = -0.3915810670141291
#   基 ('Y', 'Y', 'I') 的期望值 ⟨P⟩ = -0.047242040508352304
#   基 ('Y', 'Y', 'X') 的期望值 ⟨P⟩ = 1.3877787807814457e-16
#   基 ('Y', 'Y', 'Y') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Y', 'Y', 'Z') 的期望值 ⟨P⟩ = -0.04928386990134463
#   基 ('Y', 'Z', 'I') 的期望值 ⟨P⟩ = 0.0
#   基 ('Y', 'Z', 'X') 的期望值 ⟨P⟩ = 0.0005563911630981355
#   基 ('Y', 'Z', 'Y') 的期望值 ⟨P⟩ = 0.11863923700033524
#   基 ('Y', 'Z', 'Z') 的期望值 ⟨P⟩ = 6.245004513516506e-17
#   基 ('Z', 'I', 'I') 的期望值 ⟨P⟩ = 0.6656354714960991
#   基 ('Z', 'I', 'X') 的期望值 ⟨P⟩ = -4.85722573273506e-17
#   基 ('Z', 'I', 'Y') 的期望值 ⟨P⟩ = 0.0
#   基 ('Z', 'I', 'Z') 的期望值 ⟨P⟩ = 0.42913544616618
#   基 ('Z', 'X', 'I') 的期望值 ⟨P⟩ = -3.469446951953614e-18
#   基 ('Z', 'X', 'X') 的期望值 ⟨P⟩ = -0.050167608343364145
#   基 ('Z', 'X', 'Y') 的期望值 ⟨P⟩ = -0.39294088544761385
#   基 ('Z', 'X', 'Z') 的期望值 ⟨P⟩ = 1.734723475976807e-18
#   基 ('Z', 'Y', 'I') 的期望值 ⟨P⟩ = -4.163336342344337e-17
#   基 ('Z', 'Y', 'X') 的期望值 ⟨P⟩ = 0.39294088544761396
#   基 ('Z', 'Y', 'Y') 的期望值 ⟨P⟩ = -0.05016760834336414
#   基 ('Z', 'Y', 'Z') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Z', 'Z', 'I') 的期望值 ⟨P⟩ = -0.6970547048055444
#   基 ('Z', 'Z', 'X') 的期望值 ⟨P⟩ = 6.938893903907228e-18
#   基 ('Z', 'Z', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Z', 'Z', 'Z') 的期望值 ⟨P⟩ = -0.6833267366491611
#
# 窗口 3：
#   基 ('I', 'I', 'I') 的期望值 ⟨P⟩ = 0.999999999999999
#   基 ('I', 'I', 'X') 的期望值 ⟨P⟩ = -8.326672684688674e-17
#   基 ('I', 'I', 'Y') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('I', 'I', 'Z') 的期望值 ⟨P⟩ = -0.665635471496099
#   基 ('I', 'X', 'I') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'X', 'X') 的期望值 ⟨P⟩ = -0.047242040508352234
#   基 ('I', 'X', 'Y') 的期望值 ⟨P⟩ = 0.5033162609464583
#   基 ('I', 'X', 'Z') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'Y', 'I') 的期望值 ⟨P⟩ = 0.0
#   基 ('I', 'Y', 'X') 的期望值 ⟨P⟩ = -0.5033162609464583
#   基 ('I', 'Y', 'Y') 的期望值 ⟨P⟩ = -0.04724204050835226
#   基 ('I', 'Y', 'Z') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('I', 'Z', 'I') 的期望值 ⟨P⟩ = 0.6619360213492679
#   基 ('I', 'Z', 'X') 的期望值 ⟨P⟩ = -4.85722573273506e-17
#   基 ('I', 'Z', 'Y') 的期望值 ⟨P⟩ = -4.85722573273506e-17
#   基 ('I', 'Z', 'Z') 的期望值 ⟨P⟩ = -0.6970547048055444
#   基 ('X', 'I', 'I') 的期望值 ⟨P⟩ = 4.163336342344337e-17
#   基 ('X', 'I', 'X') 的期望值 ⟨P⟩ = 0.1769351319274553
#   基 ('X', 'I', 'Y') 的期望值 ⟨P⟩ = 2.7921755086743327e-05
#   基 ('X', 'I', 'Z') 的期望值 ⟨P⟩ = -6.938893903907228e-17
#   基 ('X', 'X', 'I') 的期望值 ⟨P⟩ = -0.04801456915908117
#   基 ('X', 'X', 'X') 的期望值 ⟨P⟩ = -2.7755575615628914e-17
#   基 ('X', 'X', 'Y') 的期望值 ⟨P⟩ = 0.0
#   基 ('X', 'X', 'Z') 的期望值 ⟨P⟩ = 0.05016760834336417
#   基 ('X', 'Y', 'I') 的期望值 ⟨P⟩ = -0.5023781911391809
#   基 ('X', 'Y', 'X') 的期望值 ⟨P⟩ = -8.673617379884035e-17
#   基 ('X', 'Y', 'Y') 的期望值 ⟨P⟩ = -1.3877787807814457e-17
#   基 ('X', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.392940885447614
#   基 ('X', 'Z', 'I') 的期望值 ⟨P⟩ = -2.0816681711721685e-17
#   基 ('X', 'Z', 'X') 的期望值 ⟨P⟩ = -0.11863923700033523
#   基 ('X', 'Z', 'Y') 的期望值 ⟨P⟩ = 0.000556391163097962
#   基 ('X', 'Z', 'Z') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('Y', 'I', 'I') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Y', 'I', 'X') 的期望值 ⟨P⟩ = -2.7921755086895983e-05
#   基 ('Y', 'I', 'Y') 的期望值 ⟨P⟩ = 0.17693513192745525
#   基 ('Y', 'I', 'Z') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('Y', 'X', 'I') 的期望值 ⟨P⟩ = 0.502378191139181
#   基 ('Y', 'X', 'X') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Y', 'X', 'Y') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('Y', 'X', 'Z') 的期望值 ⟨P⟩ = -0.392940885447614
#   基 ('Y', 'Y', 'I') 的期望值 ⟨P⟩ = -0.04801456915908106
#   基 ('Y', 'Y', 'X') 的期望值 ⟨P⟩ = -6.938893903907228e-17
#   基 ('Y', 'Y', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Y', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.050167608343364284
#   基 ('Y', 'Z', 'I') 的期望值 ⟨P⟩ = -2.0816681711721685e-17
#   基 ('Y', 'Z', 'X') 的期望值 ⟨P⟩ = -0.0005563911630979343
#   基 ('Y', 'Z', 'Y') 的期望值 ⟨P⟩ = -0.11863923700033528
#   基 ('Y', 'Z', 'Z') 的期望值 ⟨P⟩ = -6.245004513516506e-17
#   基 ('Z', 'I', 'I') 的期望值 ⟨P⟩ = -0.6619360213492678
#   基 ('Z', 'I', 'X') 的期望值 ⟨P⟩ = 1.3877787807814457e-17
#   基 ('Z', 'I', 'Y') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Z', 'I', 'Z') 的期望值 ⟨P⟩ = 0.4291354461661798
#   基 ('Z', 'X', 'I') 的期望值 ⟨P⟩ = 0.0
#   基 ('Z', 'X', 'X') 的期望值 ⟨P⟩ = 0.04928386990134451
#   基 ('Z', 'X', 'Y') 的期望值 ⟨P⟩ = -0.391581067014129
#   基 ('Z', 'X', 'Z') 的期望值 ⟨P⟩ = 0.0
#   基 ('Z', 'Y', 'I') 的期望值 ⟨P⟩ = 8.326672684688674e-17
#   基 ('Z', 'Y', 'X') 的期望值 ⟨P⟩ = 0.3915810670141292
#   基 ('Z', 'Y', 'Y') 的期望值 ⟨P⟩ = 0.04928386990134448
#   基 ('Z', 'Y', 'Z') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Z', 'Z', 'I') 的期望值 ⟨P⟩ = -0.6937543243423085
#   基 ('Z', 'Z', 'X') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Z', 'Z', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Z', 'Z', 'Z') 的期望值 ⟨P⟩ = 0.6833267366491609
#
# 窗口 4：
#   基 ('I', 'I', 'I') 的期望值 ⟨P⟩ = 0.9999999999999988
#   基 ('I', 'I', 'X') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('I', 'I', 'Y') 的期望值 ⟨P⟩ = -1.3877787807814457e-17
#   基 ('I', 'I', 'Z') 的期望值 ⟨P⟩ = 0.6610740203395031
#   基 ('I', 'X', 'I') 的期望值 ⟨P⟩ = 2.0816681711721685e-17
#   基 ('I', 'X', 'X') 的期望值 ⟨P⟩ = -0.04497564661972045
#   基 ('I', 'X', 'Y') 的期望值 ⟨P⟩ = -0.5013322590983175
#   基 ('I', 'X', 'Z') 的期望值 ⟨P⟩ = -3.8163916471489756e-17
#   基 ('I', 'Y', 'I') 的期望值 ⟨P⟩ = 9.71445146547012e-17
#   基 ('I', 'Y', 'X') 的期望值 ⟨P⟩ = 0.5013322590983172
#   基 ('I', 'Y', 'Y') 的期望值 ⟨P⟩ = -0.044975646619720464
#   基 ('I', 'Y', 'Z') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('I', 'Z', 'I') 的期望值 ⟨P⟩ = -0.665635471496099
#   基 ('I', 'Z', 'X') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('I', 'Z', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('I', 'Z', 'Z') 的期望值 ⟨P⟩ = -0.6942749511019086
#   基 ('X', 'I', 'I') 的期望值 ⟨P⟩ = -2.7755575615628914e-17
#   基 ('X', 'I', 'X') 的期望值 ⟨P⟩ = 0.17666413845176376
#   基 ('X', 'I', 'Y') 的期望值 ⟨P⟩ = 0.0002745213532243107
#   基 ('X', 'I', 'Z') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('X', 'X', 'I') 的期望值 ⟨P⟩ = -0.047242040508352304
#   基 ('X', 'X', 'X') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('X', 'X', 'Y') 的期望值 ⟨P⟩ = 9.020562075079397e-17
#   基 ('X', 'X', 'Z') 的期望值 ⟨P⟩ = -0.04972217452029586
#   基 ('X', 'Y', 'I') 的期望值 ⟨P⟩ = 0.5033162609464583
#   基 ('X', 'Y', 'X') 的期望值 ⟨P⟩ = 0.0
#   基 ('X', 'Y', 'Y') 的期望值 ⟨P⟩ = 0.0
#   基 ('X', 'Y', 'Z') 的期望值 ⟨P⟩ = 0.3904754099250559
#   基 ('X', 'Z', 'I') 的期望值 ⟨P⟩ = -2.7755575615628914e-17
#   基 ('X', 'Z', 'X') 的期望值 ⟨P⟩ = 0.11714526475915932
#   基 ('X', 'Z', 'Y') 的期望值 ⟨P⟩ = 0.001112879455502369
#   基 ('X', 'Z', 'Z') 的期望值 ⟨P⟩ = 3.469446951953614e-17
#   基 ('Y', 'I', 'I') 的期望值 ⟨P⟩ = 0.0
#   基 ('Y', 'I', 'X') 的期望值 ⟨P⟩ = -0.00027452135322439397
#   基 ('Y', 'I', 'Y') 的期望值 ⟨P⟩ = 0.17666413845176393
#   基 ('Y', 'I', 'Z') 的期望值 ⟨P⟩ = -6.245004513516506e-17
#   基 ('Y', 'X', 'I') 的期望值 ⟨P⟩ = -0.5033162609464584
#   基 ('Y', 'X', 'X') 的期望值 ⟨P⟩ = -8.326672684688674e-17
#   基 ('Y', 'X', 'Y') 的期望值 ⟨P⟩ = 1.1449174941446927e-16
#   基 ('Y', 'X', 'Z') 的期望值 ⟨P⟩ = -0.390475409925056
#   基 ('Y', 'Y', 'I') 的期望值 ⟨P⟩ = -0.04724204050835222
#   基 ('Y', 'Y', 'X') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Y', 'Y', 'Y') 的期望值 ⟨P⟩ = 5.551115123125783e-17
#   基 ('Y', 'Y', 'Z') 的期望值 ⟨P⟩ = -0.04972217452029575
#   基 ('Y', 'Z', 'I') 的期望值 ⟨P⟩ = 2.7755575615628914e-17
#   基 ('Y', 'Z', 'X') 的期望值 ⟨P⟩ = -0.001112879455502258
#   基 ('Y', 'Z', 'Y') 的期望值 ⟨P⟩ = 0.11714526475915926
#   基 ('Y', 'Z', 'Z') 的期望值 ⟨P⟩ = -2.0816681711721685e-17
#   基 ('Z', 'I', 'I') 的期望值 ⟨P⟩ = 0.661936021349268
#   基 ('Z', 'I', 'X') 的期望值 ⟨P⟩ = 1.1796119636642288e-16
#   基 ('Z', 'I', 'Y') 的期望值 ⟨P⟩ = 1.3877787807814457e-17
#   基 ('Z', 'I', 'Z') 的期望值 ⟨P⟩ = 0.42647363454249143
#   基 ('Z', 'X', 'I') 的期望值 ⟨P⟩ = -1.0408340855860843e-17
#   基 ('Z', 'X', 'X') 的期望值 ⟨P⟩ = -0.04726468380585461
#   基 ('Z', 'X', 'Y') 的期望值 ⟨P⟩ = -0.3897910463425871
#   基 ('Z', 'X', 'Z') 的期望值 ⟨P⟩ = 1.0408340855860843e-17
#   基 ('Z', 'Y', 'I') 的期望值 ⟨P⟩ = 1.3877787807814457e-17
#   基 ('Z', 'Y', 'X') 的期望值 ⟨P⟩ = 0.3897910463425872
#   基 ('Z', 'Y', 'Y') 的期望值 ⟨P⟩ = -0.04726468380585461
#   基 ('Z', 'Y', 'Z') 的期望值 ⟨P⟩ = 1.0408340855860843e-17
#   基 ('Z', 'Z', 'I') 的期望值 ⟨P⟩ = -0.6970547048055447
#   基 ('Z', 'Z', 'X') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('Z', 'Z', 'Y') 的期望值 ⟨P⟩ = -5.551115123125783e-17
#   基 ('Z', 'Z', 'Z') 的期望值 ⟨P⟩ = -0.6804167887156783

# %%
def reconstruct_rho_from_expectations(expectations_dict, k):
    """
    将期望值 ⟨P⟩ 构造成密度矩阵：ρ = 1/2^k ∑⟨P⟩ P
    参数：
        expectations_dict: dict[basis (tuple of str)] = ⟨P⟩
        k: 窗口长度
    返回：
        rho: 2^k × 2^k 的密度矩阵
    """
    dim = 2 ** k
    rho = np.zeros((dim, dim), dtype=np.complex128)
    
    for pauli_str, coeff in expectations_dict.items():
        if coeff is None:
            continue
        op = pauli_ops[pauli_str[0]]
        for p in pauli_str[1:]:
            op = np.kron(op, pauli_ops[p])
        rho += coeff * op
    rho = rho / dim
    return rho
def compute_all_local_density_matrices(all_expectations, k):
    """
    计算所有窗口的局部密度矩阵
    返回：dict[window] = rho (2^k × 2^k array)
    """
    local_rhos = {}
    for i, exp_dict in all_expectations.items():
        rho = reconstruct_rho_from_expectations(exp_dict, k)
        local_rhos[i] = rho
    return local_rhos

# %%
local_density_matrices = compute_all_local_density_matrices(all_expectations, k)
# 打印前两个窗口的局部密度矩阵
for i in sorted(local_density_matrices.keys()):
    print(f"\n 窗口 {i} 的 ρ_{i+1}...{i+k} 密度矩阵：")
    print(local_density_matrices[i])
# Out:
#  窗口 0 的 ρ_1...3 密度矩阵：
# [[ 1.70132144e-03+0.00000000e+00j  9.52742659e-18+5.00088252e-18j
#    9.86623977e-18+6.17995238e-18j -3.46944695e-18+0.00000000e+00j
#    3.55618313e-17-2.60208521e-18j -2.77555756e-17-1.38777878e-17j
#    6.07153217e-18+3.46944695e-17j -1.43114687e-17+2.16840434e-17j]
#  [ 9.52742659e-18-5.00088252e-18j  8.22458524e-02+0.00000000e+00j
#   -2.48604797e-02-2.47495401e-01j -2.92734587e-18+2.49366500e-18j
#    7.88839985e-02-3.31467168e-03j -8.67361738e-19+1.30104261e-17j
#   -6.50521303e-18-4.33680869e-18j -9.54097912e-18+0.00000000e+00j]
#  [ 9.86623977e-18-6.17995238e-18j -2.48604797e-02+2.47495401e-01j
#    7.53522000e-01+0.00000000e+00j -1.82010440e-17+1.19126714e-17j
#   -1.38456007e-02+2.38688976e-01j  1.34441069e-17+8.67361738e-19j
#    1.12757026e-17+7.80625564e-18j -1.04083409e-17+2.08166817e-17j]
#  [-3.46944695e-18+0.00000000e+00j -2.92734587e-18-2.49366500e-18j
#   -1.82010440e-17-1.19126714e-17j  7.52409015e-02+0.00000000e+00j
#    7.37257477e-18+1.64798730e-17j -4.87930065e-04+2.69141373e-02j
#    8.62143896e-03+6.76730402e-03j -1.82145965e-17-1.12757026e-17j]
#  [ 3.55618313e-17+2.60208521e-18j  7.88839985e-02+3.31467168e-03j
#   -1.38456007e-02-2.38688976e-01j  7.37257477e-18-1.64798730e-17j
#    7.58703036e-02+0.00000000e+00j -6.05797964e-18-1.53143557e-18j
#   -7.26415456e-18-1.31188463e-17j -3.46944695e-18+2.77555756e-17j]
#  [-2.77555756e-17+1.38777878e-17j -8.67361738e-19-1.30104261e-17j
#    1.34441069e-17-8.67361738e-19j -4.87930065e-04-2.69141373e-02j
#   -6.05797964e-18+1.53143557e-18j  9.64551242e-03+0.00000000e+00j
#    2.37265641e-03-3.17072818e-03j  3.25260652e-19-9.43255890e-18j]
#  [ 6.07153217e-18-3.46944695e-17j -6.50521303e-18+4.33680869e-18j
#    1.12757026e-17-7.80625564e-18j  8.62143896e-03-6.76730402e-03j
#   -7.26415456e-18+1.31188463e-17j  2.37265641e-03+3.17072818e-03j
#    1.72411111e-03+0.00000000e+00j -6.08508469e-18-2.23210122e-17j]
#  [-1.43114687e-17-2.16840434e-17j -9.54097912e-18+0.00000000e+00j
#   -1.04083409e-17-2.08166817e-17j -1.82145965e-17+1.12757026e-17j
#   -3.46944695e-18-2.77555756e-17j  3.25260652e-19+9.43255890e-18j
#   -6.08508469e-18+2.23210122e-17j  4.99979393e-05+0.00000000e+00j]]
#
#  窗口 1 的 ρ_2...4 密度矩阵：
# [[ 7.27327464e-03+0.00000000e+00j  9.54097912e-18-1.73472348e-17j
#   -1.38777878e-17+1.04083409e-17j  1.73472348e-17-2.77555756e-17j
#   -2.16840434e-17-3.46944695e-18j -3.46944695e-18-3.98986399e-17j
#    1.73472348e-17-2.08166817e-17j -1.56125113e-17+2.60208521e-18j]
#  [ 9.54097912e-18+1.73472348e-17j  7.02983504e-02+0.00000000e+00j
#    6.20033503e-04+2.82102128e-02j  2.77555756e-17-1.73472348e-17j
#    1.48797184e-02-2.09589526e-04j  8.67361738e-19+1.21430643e-17j
#    2.25514052e-17+2.60208521e-18j -3.46944695e-18-2.77555756e-17j]
#  [-1.38777878e-17-1.04083409e-17j  6.20033503e-04-2.82102128e-02j
#    1.85926236e-02+0.00000000e+00j  7.80625564e-18-3.46944695e-18j
#    5.72259297e-04-2.78853032e-02j  8.67361738e-18-2.60208521e-18j
#   -6.07153217e-18-1.73472348e-17j -6.93889390e-18+2.60208521e-17j]
#  [ 1.73472348e-17+2.77555756e-17j  2.77555756e-17+1.73472348e-17j
#    7.80625564e-18+3.46944695e-18j  7.32987412e-02+0.00000000e+00j
#   -1.73472348e-18+2.51534904e-17j -2.30600826e-02-2.22780826e-01j
#    7.34523508e-02+3.46850202e-04j  6.07153217e-18-1.90819582e-17j]
#  [-2.16840434e-17+3.46944695e-18j  1.48797184e-02+2.09589526e-04j
#    5.72259297e-04+2.78853032e-02j -1.73472348e-18-2.51534904e-17j
#    6.93879117e-02+0.00000000e+00j  2.86229374e-17-1.21430643e-17j
#    0.00000000e+00-1.73472348e-17j  2.42861287e-17+2.77555756e-17j]
#  [-3.46944695e-18+3.98986399e-17j  8.67361738e-19-1.21430643e-17j
#    8.67361738e-18+2.60208521e-18j -2.30600826e-02+2.22780826e-01j
#    2.86229374e-17+1.21430643e-17j  6.85858199e-01+0.00000000e+00j
#   -2.42410538e-02+2.23447918e-01j -1.38777878e-17+1.04083409e-17j]
#  [ 1.73472348e-17+2.08166817e-17j  2.25514052e-17-2.60208521e-18j
#   -6.07153217e-18+1.73472348e-17j  7.34523508e-02-3.46850202e-04j
#    0.00000000e+00+1.73472348e-17j -2.42410538e-02-2.23447918e-01j
#    7.37781794e-02+0.00000000e+00j -4.33680869e-18+5.20417043e-18j]
#  [-1.56125113e-17-2.60208521e-18j -3.46944695e-18+2.77555756e-17j
#   -6.93889390e-18-2.60208521e-17j  6.07153217e-18+1.90819582e-17j
#    2.42861287e-17-2.77555756e-17j -1.38777878e-17-1.04083409e-17j
#   -4.33680869e-18-5.20417043e-18j  1.51272001e-03+0.00000000e+00j]]
#
#  窗口 2 的 ρ_3...5 密度矩阵：
# [[ 2.57939398e-03+0.00000000e+00j -1.73472348e-18-1.73472348e-17j
#    1.95156391e-18+7.80625564e-18j -4.33680869e-18-2.77555756e-17j
#   -1.21430643e-17-3.46944695e-18j -6.93889390e-18-1.38777878e-17j
#    1.21430643e-17+0.00000000e+00j -2.64545330e-17+2.16840434e-17j]
#  [-1.73472348e-18+1.73472348e-17j  7.40817924e-02+0.00000000e+00j
#   -2.45455444e-02-2.23829769e-01j -6.28837260e-18+9.54097912e-18j
#    7.38935922e-02-1.32117352e-04j -8.67361738e-18-6.93889390e-18j
#   -2.21177243e-17-2.60208521e-18j -1.56125113e-17+0.00000000e+00j]
#  [ 1.95156391e-18-7.80625564e-18j -2.45455444e-02+2.23829769e-01j
#    6.86597341e-01+0.00000000e+00j -3.46944695e-18-3.46944695e-18j
#   -2.41314776e-02+2.23724332e-01j  1.51788304e-17-1.30104261e-17j
#    6.93889390e-18+1.21430643e-17j  1.04083409e-17+6.93889390e-18j]
#  [-4.33680869e-18+2.77555756e-17j -6.28837260e-18-9.54097912e-18j
#   -3.46944695e-18+3.46944695e-18j  6.95592086e-02+0.00000000e+00j
#    5.63785130e-18-2.34187669e-17j  5.10457348e-04+2.79337985e-02j
#    1.45739737e-02+1.46078230e-04j  4.16333634e-17-2.25514052e-17j]
#  [-1.21430643e-17+3.46944695e-18j  7.38935922e-02+1.32117352e-04j
#   -2.41314776e-02-2.23724332e-01j  5.63785130e-18+2.34187669e-17j
#    7.39820249e-02+0.00000000e+00j  8.67361738e-18-3.46944695e-18j
#    2.38524478e-18+4.33680869e-18j -2.60208521e-18+0.00000000e+00j]
#  [-6.93889390e-18+1.38777878e-17j -8.67361738e-18+6.93889390e-18j
#    1.51788304e-17+1.30104261e-17j  5.10457348e-04-2.79337985e-02j
#    8.67361738e-18+3.46944695e-18j  1.83887781e-02+0.00000000e+00j
#    5.38259796e-04-2.73593264e-02j -4.98732999e-18-7.80625564e-18j]
#  [ 1.21430643e-17+0.00000000e+00j -2.21177243e-17+2.60208521e-18j
#    6.93889390e-18-1.21430643e-17j  1.45739737e-02-1.46078230e-04j
#    2.38524478e-18-4.33680869e-18j  5.38259796e-04+2.73593264e-02j
#    6.78092510e-02+0.00000000e+00j  1.04083409e-17-1.73472348e-17j]
#  [-2.64545330e-17-2.16840434e-17j -1.56125113e-17+0.00000000e+00j
#    1.04083409e-17-6.93889390e-18j  4.16333634e-17+2.25514052e-17j
#   -2.60208521e-18+0.00000000e+00j -4.98732999e-18+7.80625564e-18j
#    1.04083409e-17+1.73472348e-17j  7.00221027e-03+0.00000000e+00j]]
#
#  窗口 3 的 ρ_4...6 密度矩阵：
# [[ 7.00221027e-03+0.00000000e+00j -7.80625564e-18-7.80625564e-18j
#    0.00000000e+00-2.08166817e-17j  6.93889390e-18-2.77555756e-17j
#   -1.30104261e-17+1.04083409e-17j  1.38777878e-17+1.56125113e-17j
#   -2.77555756e-17-1.38777878e-17j  1.38777878e-17+1.43114687e-17j]
#  [-7.80625564e-18+7.80625564e-18j  6.95592086e-02+0.00000000e+00j
#    5.10457348e-04+2.79337985e-02j  0.00000000e+00+0.00000000e+00j
#    1.45739737e-02+1.46078230e-04j  1.82145965e-17-1.90819582e-17j
#   -3.46944695e-18+4.33680869e-19j  0.00000000e+00-2.08166817e-17j]
#  [ 0.00000000e+00+2.08166817e-17j  5.10457348e-04-2.79337985e-02j
#    1.83887781e-02+0.00000000e+00j -9.54097912e-18-6.07153217e-18j
#    5.38259796e-04-2.73593264e-02j -6.93889390e-18-2.12503626e-17j
#    6.07153217e-18-1.04083409e-17j  1.73472348e-18+2.25514052e-17j]
#  [ 6.93889390e-18+2.77555756e-17j  0.00000000e+00+0.00000000e+00j
#   -9.54097912e-18+6.07153217e-18j  7.40817924e-02+0.00000000e+00j
#   -1.73472348e-17-7.37257477e-18j -2.45455444e-02-2.23829769e-01j
#    7.38935922e-02-1.32117352e-04j  9.54097912e-18-8.67361738e-18j]
#  [-1.30104261e-17-1.04083409e-17j  1.45739737e-02-1.46078230e-04j
#    5.38259796e-04+2.73593264e-02j -1.73472348e-17+7.37257477e-18j
#    6.78092510e-02+0.00000000e+00j -2.51534904e-17+1.30104261e-17j
#    0.00000000e+00+1.38777878e-17j  0.00000000e+00+2.77555756e-17j]
#  [ 1.38777878e-17-1.56125113e-17j  1.82145965e-17+1.90819582e-17j
#   -6.93889390e-18+2.12503626e-17j -2.45455444e-02+2.23829769e-01j
#   -2.51534904e-17-1.30104261e-17j  6.86597341e-01+0.00000000e+00j
#   -2.41314776e-02+2.23724332e-01j  0.00000000e+00+6.93889390e-18j]
#  [-2.77555756e-17+1.38777878e-17j -3.46944695e-18-4.33680869e-19j
#    6.07153217e-18+1.04083409e-17j  7.38935922e-02+1.32117352e-04j
#    0.00000000e+00-1.38777878e-17j -2.41314776e-02-2.23724332e-01j
#    7.39820249e-02+0.00000000e+00j  8.67361738e-19-1.30104261e-17j]
#  [ 1.38777878e-17-1.43114687e-17j  0.00000000e+00+2.08166817e-17j
#    1.73472348e-18-2.25514052e-17j  9.54097912e-18+8.67361738e-18j
#    0.00000000e+00-2.77555756e-17j  0.00000000e+00-6.93889390e-18j
#    8.67361738e-19+1.30104261e-17j  2.57939398e-03+0.00000000e+00j]]
#
#  窗口 4 的 ρ_5...7 密度矩阵：
# [[ 1.51272001e-03+0.00000000e+00j  7.80625564e-18+0.00000000e+00j
#   -2.16840434e-18-2.21177243e-17j  1.73472348e-18+1.38777878e-17j
#    8.67361738e-19+6.93889390e-18j -1.38777878e-17-3.46944695e-18j
#   -2.34187669e-17+2.77555756e-17j -1.43114687e-17+6.07153217e-18j]
#  [ 7.80625564e-18+0.00000000e+00j  7.32987412e-02+0.00000000e+00j
#   -2.30600826e-02-2.22780826e-01j  4.77048956e-18-5.63785130e-18j
#    7.34523508e-02+3.46850202e-04j -1.47451495e-17-1.38777878e-17j
#    1.43114687e-17+1.47451495e-17j  3.46944695e-18+0.00000000e+00j]
#  [-2.16840434e-18+2.21177243e-17j -2.30600826e-02+2.22780826e-01j
#    6.85858199e-01+0.00000000e+00j  3.55618313e-17+0.00000000e+00j
#   -2.42410538e-02+2.23447918e-01j -7.37257477e-18-7.80625564e-18j
#   -8.67361738e-19+8.67361738e-18j -2.77555756e-17+2.42861287e-17j]
#  [ 1.73472348e-18-1.38777878e-17j  4.77048956e-18+5.63785130e-18j
#    3.55618313e-17+0.00000000e+00j  7.02983504e-02+0.00000000e+00j
#    2.12503626e-17+2.86229374e-17j  6.20033503e-04+2.82102128e-02j
#    1.48797184e-02-2.09589526e-04j  8.67361738e-19-1.73472348e-18j]
#  [ 8.67361738e-19-6.93889390e-18j  7.34523508e-02-3.46850202e-04j
#   -2.42410538e-02-2.23447918e-01j  2.12503626e-17-2.86229374e-17j
#    7.37781794e-02+0.00000000e+00j -7.80625564e-18-1.04083409e-17j
#   -2.16840434e-18-1.60461922e-17j  1.73472348e-18+4.16333634e-17j]
#  [-1.38777878e-17+3.46944695e-18j -1.47451495e-17+1.38777878e-17j
#   -7.37257477e-18+7.80625564e-18j  6.20033503e-04-2.82102128e-02j
#   -7.80625564e-18+1.04083409e-17j  1.85926236e-02+0.00000000e+00j
#    5.72259297e-04-2.78853032e-02j  9.97465999e-18-4.77048956e-18j]
#  [-2.34187669e-17-2.77555756e-17j  1.43114687e-17-1.47451495e-17j
#   -8.67361738e-19-8.67361738e-18j  1.48797184e-02+2.09589526e-04j
#   -2.16840434e-18+1.60461922e-17j  5.72259297e-04+2.78853032e-02j
#    6.93879117e-02+0.00000000e+00j -7.80625564e-18+1.73472348e-17j]
#  [-1.43114687e-17-6.07153217e-18j  3.46944695e-18+0.00000000e+00j
#   -2.77555756e-17-2.42861287e-17j  8.67361738e-19+1.73472348e-18j
#    1.73472348e-18-4.16333634e-17j  9.97465999e-18+4.77048956e-18j
#   -7.80625564e-18-1.73472348e-17j  7.27327464e-03+0.00000000e+00j]]
#
#  窗口 5 的 ρ_6...8 密度矩阵：
# [[ 4.99979393e-05+0.00000000e+00j -1.47451495e-17+1.12757026e-17j
#   -2.08166817e-17-1.73472348e-17j -1.73472348e-17+6.93889390e-18j
#   -9.54097912e-18-1.04083409e-17j  2.08166817e-17-6.93889390e-18j
#    0.00000000e+00-6.93889390e-18j  3.46944695e-18-1.73472348e-17j]
#  [-1.47451495e-17-1.12757026e-17j  7.52409015e-02+0.00000000e+00j
#   -4.87930065e-04+2.69141373e-02j  6.93889390e-18-1.04083409e-17j
#    8.62143896e-03+6.76730402e-03j -3.55618313e-17+1.90819582e-17j
#   -1.73472348e-17-3.46944695e-18j -1.38777878e-17+6.93889390e-18j]
#  [-2.08166817e-17+1.73472348e-17j -4.87930065e-04-2.69141373e-02j
#    9.64551242e-03+0.00000000e+00j  7.80625564e-18+2.60208521e-18j
#    2.37265641e-03-3.17072818e-03j  3.46944695e-18-3.46944695e-18j
#   -1.47451495e-17-1.04083409e-17j -1.38777878e-17+1.73472348e-17j]
#  [-1.73472348e-17-6.93889390e-18j  6.93889390e-18+1.04083409e-17j
#    7.80625564e-18-2.60208521e-18j  8.22458524e-02+0.00000000e+00j
#   -3.46944695e-18-3.46944695e-18j -2.48604797e-02-2.47495401e-01j
#    7.88839985e-02-3.31467168e-03j -9.54097912e-18-1.21430643e-17j]
#  [-9.54097912e-18+1.04083409e-17j  8.62143896e-03-6.76730402e-03j
#    2.37265641e-03+3.17072818e-03j -3.46944695e-18+3.46944695e-18j
#    1.72411111e-03+0.00000000e+00j -1.82145965e-17-9.54097912e-18j
#    2.08166817e-17-1.04083409e-17j  1.04083409e-17+2.08166817e-17j]
#  [ 2.08166817e-17+6.93889390e-18j -3.55618313e-17-1.90819582e-17j
#    3.46944695e-18+3.46944695e-18j -2.48604797e-02+2.47495401e-01j
#   -1.82145965e-17+9.54097912e-18j  7.53522000e-01+0.00000000e+00j
#   -1.38456007e-02+2.38688976e-01j -6.93889390e-18-3.46944695e-18j]
#  [ 0.00000000e+00+6.93889390e-18j -1.73472348e-17+3.46944695e-18j
#   -1.47451495e-17+1.04083409e-17j  7.88839985e-02+3.31467168e-03j
#    2.08166817e-17+1.04083409e-17j -1.38456007e-02-2.38688976e-01j
#    7.58703036e-02+0.00000000e+00j -2.34187669e-17-1.82145965e-17j]
#  [ 3.46944695e-18+1.73472348e-17j -1.38777878e-17-6.93889390e-18j
#   -1.38777878e-17-1.73472348e-17j -9.54097912e-18+1.21430643e-17j
#    1.04083409e-17-2.08166817e-17j -6.93889390e-18+3.46944695e-18j
#   -2.34187669e-17+1.82145965e-17j  1.70132144e-03+0.00000000e+00j]]

# %%
def construct_R_operator(pvec_dict, rho, k):
    """
    构造真实的 R 算符，用于 MLE 优化：
    R = ∑_l (f_l / p_l) * P_l
    正确处理：I位不区分、f_l合并、用本征态密度矩阵构造。
    """
    dim = 2 ** k
    all_bitstrings = generate_all_bitstrings(k)
    R = np.zeros((dim, dim), dtype=complex)

    for basis, prob_vector in pvec_dict.items():
        sum=0
        if prob_vector is None:
            continue

        # Step1: 先生成有效位索引（非I位）
        active_indices = [i for i, p in enumerate(basis) if p != 'I']
        # Step2: 合并频率
        f_eff = dict()
        for idx, bitstr in enumerate(all_bitstrings):
            eff_bitstr = ''.join(bitstr[i] for i in active_indices)
            if eff_bitstr not in f_eff:
                f_eff[eff_bitstr] = 0.0
            f_eff[eff_bitstr] += prob_vector[idx]
        # Step3: 遍历每个有效bitstring
        for eff_bitstr, f_l in f_eff.items():
            full_bitstr = list('0' * k)
            idx_eff = 0
            for i in range(k):
                if basis[i] != 'I':
                    full_bitstr[i] = eff_bitstr[idx_eff]
                    idx_eff += 1
            full_bitstr = ''.join(full_bitstr)
            # 构造对应的 P_l
            P_l = np.eye(1, dtype=np.complex128)
            eigen=1
            for i, pauli in enumerate(basis):
                
                if pauli == 'I':
                    op = np.eye(2, dtype=np.complex128)
                else:
                    bit = int(full_bitstr[i])
                    if pauli == 'X':
                        if bit == 0:
                            vec = (1/np.sqrt(2)) * np.array([1, 1], dtype=np.complex128)
                            eigen *= +1
                        else:
                            vec = (1/np.sqrt(2)) * np.array([1, -1], dtype=np.complex128)
                            eigen *= -1
                    elif pauli == 'Y':
                        if bit == 0:
                            vec = (1/np.sqrt(2)) * np.array([1, 1j], dtype=np.complex128)
                            eigen *= +1
                        else:
                            vec = (1/np.sqrt(2)) * np.array([1, -1j], dtype=np.complex128)
                            eigen *= -1
                    elif pauli == 'Z':
                        if bit == 0:
                            vec = np.array([1, 0], dtype=np.complex128)
                            eigen *= +1
                        else:
                            vec = np.array([0, 1], dtype=np.complex128)
                            eigen *= -1
                    else:
                        raise ValueError(f"未知Pauli符号: {pauli}")
                    op = np.outer(vec, vec.conj())  # 
                P_l = np.kron(P_l, op)
            # 计算预测概率
            p_l = np.trace(P_l @ (rho)).real
            if p_l > 1e-16:
                R += (f_l / p_l) * P_l
          
    return R

def random_positive_density_matrix(k):
    """生成随机半正定的2^k阶密度矩阵"""
    dim = 2 ** k
    A = np.ones((dim, dim), dtype=np.complex128)
    rho = A @ A.conj().T
    rho /= np.trace(rho)
    return rho

def mle_with_real_R_fixed_iter(rho_init, pvec_dict, k, max_iter, error):
    rho = rho_init.copy()
    for it in range(max_iter):
        print(f"第{it}轮迭代")
        R = construct_R_operator(pvec_dict, rho, k)
        R_rho = R @ rho @ R
        mu_raw = np.trace(R_rho)
        # print(np.trace(R))
        if mu_raw < error:
            print(f"第{it}步：mu太小，停止")
            break
        mu = np.sqrt(mu_raw)
        rho_new = R_rho / (mu**2)
        # 收敛判据
        if np.linalg.norm(rho_new - rho, ord='fro') < 1e-15:
            print(f"第{it}步：收敛停止")
            rho = rho_new
            break
        rho = rho_new
    return rho

def compute_rho_error(rho_mle, rho_raw):
    """计算两个密度矩阵的 Frobenius 范数差异"""
    delta = rho_mle - rho_raw
    return np.linalg.norm(delta, ord='fro')

def make_psd_density_matrix(rho):
    """
    将一个可能非物理（非半正定或概率为负）的密度矩阵 rho 变成一个合法的密度矩阵。
    方法是：谱分解后去掉负的本征值，再归一化。
    """
    # 谱分解
    eigvals, eigvecs = np.linalg.eigh(rho)

    # 将负本征值设为0（或设为极小正数）
    eigvals_clipped = np.clip(eigvals, 0, None)

    # 重构密度矩阵
    rho_psd = eigvecs @ np.diag(eigvals_clipped) @ eigvecs.conj().T

    # 归一化，使 Tr(rho) = 1
    rho_psd /= np.trace(rho_psd)

    return rho_psd

def mle_all_windows_with_error(local_rhos, completed_local_probs, k, max_iter,error):
    """
    对所有窗口进行 MLE 优化 + 误差评估
    返回：
        - mle_rhos: 优化后的密度矩阵
        - rho_errors: 每个窗口的 Frobenius 误差
    """
    mle_rhos = {}
    rho_errors = {}
    for i in local_rhos:
        rho0 = local_rhos[i]
        pvecs = completed_local_probs[i]
        # rho_init = random_positive_density_matrix(k)
        rho0 =make_psd_density_matrix(rho0)
        # rho0=rho0@rho0.conj().T
        # rho0/=np.trace(rho0)
        rho_mle = mle_with_real_R_fixed_iter(rho0, pvecs, k, max_iter=max_iter,error=error)
        mle_rhos[i] = rho_mle
        rho_errors[i] = compute_rho_error(rho_mle, rho0)
    return mle_rhos, rho_errors

# %%
max_iter =100
error=1e-15
# 执行 MLE 并计算误差
mle_rhos, rho_errors = mle_all_windows_with_error(local_density_matrices, completed_local_probs, k, max_iter,error=error)
# 显示误差
print(f"\n 每个窗口 MLE 与线性反演密度矩阵之间的误差（迭代 {max_iter} 次）:")
for i in sorted(rho_errors):
    print(f"窗口 {i}: ρ = {mle_rhos[i]}")
    print(f"窗口 {i}: 误差 = {rho_errors[i]}")
# Out:
# 第0轮迭代
# 第0步：收敛停止
# 第0轮迭代
# 第0步：收敛停止
# 第0轮迭代
# 第0步：收敛停止
# 第0轮迭代
# 第0步：收敛停止
# 第0轮迭代
# 第0步：收敛停止
# 第0轮迭代
# 第0步：收敛停止
#
#  每个窗口 MLE 与线性反演密度矩阵之间的误差（迭代 100 次）:
# 窗口 0: ρ = [[ 1.70132144e-03+9.46267693e-20j  6.02280766e-18+8.27220902e-18j
#    2.06443120e-17+1.59864855e-17j -3.93220376e-18-2.71063449e-18j
#    3.21320473e-17+5.31887991e-19j -2.66584471e-17-1.40460925e-17j
#    6.25421533e-18+3.43169485e-17j -1.43093434e-17+2.16949549e-17j]
#  [ 6.02280766e-18-8.27220902e-18j  8.22458524e-02+4.57447906e-18j
#   -2.48604797e-02-2.47495401e-01j -7.41212070e-18+2.35193349e-18j
#    7.88839985e-02-3.31467168e-03j -3.63960449e-18+2.50860332e-17j
#    6.66000610e-18-6.66423989e-18j  4.09495011e-18+6.64720271e-18j]
#  [ 2.06443120e-17-1.59864855e-17j -2.48604797e-02+2.47495401e-01j
#    7.53522000e-01-1.36005805e-17j  1.99411885e-17-2.87569514e-17j
#   -1.38456007e-02+2.38688976e-01j -2.86558587e-17-4.71534114e-18j
#   -2.50114634e-17+3.01484378e-17j -3.91136264e-17+6.22787152e-17j]
#  [-3.93220376e-18+2.71063449e-18j -7.41212070e-18-2.35193349e-18j
#    1.99411885e-17+2.87569514e-17j  7.52409015e-02+4.18486670e-18j
#   -1.44559192e-18+1.51445615e-17j -4.87930065e-04+2.69141373e-02j
#    8.62143896e-03+6.76730402e-03j -1.63328177e-17-1.21669337e-17j]
#  [ 3.21320473e-17-5.31887991e-19j  7.88839985e-02+3.31467168e-03j
#   -1.38456007e-02-2.38688976e-01j -1.44559192e-18-1.51445615e-17j
#    7.58703036e-02+4.21987377e-18j -1.21758869e-17+2.83625594e-18j
#   -9.42873550e-18-8.19893705e-18j  3.55403423e-20+3.24845706e-17j]
#  [-2.66584471e-17+1.40460925e-17j -3.63960449e-18-2.50860332e-17j
#   -2.86558587e-17+4.71534114e-18j -4.87930065e-04-2.69141373e-02j
#   -1.21758869e-17-2.83625594e-18j  9.64551242e-03+5.36479267e-19j
#    2.37265641e-03-3.17072818e-03j -2.56387695e-20-1.74666905e-17j]
#  [ 6.25421533e-18-3.43169485e-17j  6.66000610e-18+6.66423989e-18j
#   -2.50114634e-17-3.01484378e-17j  8.62143896e-03-6.76730402e-03j
#   -9.42873550e-18+8.19893705e-18j  2.37265641e-03+3.17072818e-03j
#    1.72411111e-03-1.25258965e-20j -2.95731401e-18-1.17082308e-17j]
#  [-1.43093434e-17-2.16949549e-17j  4.09495011e-18-6.64720271e-18j
#   -3.91136264e-17-6.22787152e-17j -1.63328177e-17+1.21669337e-17j
#    3.55403423e-20-3.24845706e-17j -2.56387695e-20+1.74666905e-17j
#   -2.95731401e-18+1.17082308e-17j  4.99979393e-05+2.78086396e-21j]]
# 窗口 0: 误差 = 1.3682301846338592e-16
# 窗口 1: ρ = [[ 7.27327464e-03-1.76639684e-19j  4.43950852e-18-1.33237207e-17j
#   -1.36969464e-17+7.50231306e-18j  2.23609222e-17-2.57841401e-17j
#   -2.55860877e-17-5.01351350e-18j  2.97908677e-19-5.59069280e-17j
#    2.23036588e-17-1.88728197e-17j -1.55250074e-17+2.61957142e-18j]
#  [ 4.43950852e-18+1.33237207e-17j  7.02983504e-02-3.44199826e-18j
#    6.20033503e-04+2.82102128e-02j -3.62771667e-17-1.64672679e-18j
#    1.48797184e-02-2.09589526e-04j -5.43543063e-18+9.37181382e-17j
#   -1.07753292e-17+3.02976947e-17j  1.91715087e-17-1.45217828e-17j]
#  [-1.36969464e-17-7.50231306e-18j  6.20033503e-04-2.82102128e-02j
#    1.85926236e-02+4.15818890e-19j  4.21331319e-17-4.59520367e-17j
#    5.72259297e-04-2.78853032e-02j  6.68858521e-17+4.18066020e-17j
#    2.03336591e-17-4.98151933e-17j -5.61489116e-17+3.66178365e-17j]
#  [ 2.23609222e-17+2.57841401e-17j -3.62771667e-17+1.64672679e-18j
#    4.21331319e-17+4.59520367e-17j  7.32987412e-02-1.78014266e-18j
#    1.56583691e-17+5.35231853e-17j -2.30600826e-02-2.22780826e-01j
#    7.34523508e-02+3.46850202e-04j  1.90760203e-17-6.54100682e-18j]
#  [-2.55860877e-17+5.01351350e-18j  1.48797184e-02+2.09589526e-04j
#    5.72259297e-04+2.78853032e-02j  1.56583691e-17-5.35231853e-17j
#    6.93879117e-02-4.28724896e-18j -2.40591474e-17-2.86190110e-17j
#    8.49545423e-18-3.95197860e-17j  1.35848934e-17+3.53432601e-17j]
#  [ 2.97908677e-19+5.59069280e-17j -5.43543063e-18-9.37181382e-17j
#    6.68858521e-17-4.18066020e-17j -2.30600826e-02+2.22780826e-01j
#   -2.40591474e-17+2.86190110e-17j  6.85858199e-01+1.10987351e-17j
#   -2.42410538e-02+2.23447918e-01j -1.83754281e-17+8.92710646e-18j]
#  [ 2.23036588e-17+1.88728197e-17j -1.07753292e-17-3.02976947e-17j
#    2.03336591e-17+4.98151933e-17j  7.34523508e-02-3.46850202e-04j
#    8.49545423e-18+3.95197860e-17j -2.42410538e-02-2.23447918e-01j
#    7.37781794e-02-1.79178636e-18j  2.89345290e-18+1.82011588e-17j]
#  [-1.55250074e-17-2.61957142e-18j  1.91715087e-17+1.45217828e-17j
#   -5.61489116e-17-3.66178365e-17j  1.90760203e-17+6.54100682e-18j
#    1.35848934e-17-3.53432601e-17j -1.83754281e-17-8.92710646e-18j
#    2.89345290e-18-1.82011588e-17j  1.51272001e-03-3.67381129e-20j]]
# 窗口 1: 误差 = 2.3302566735897593e-16
# 窗口 2: ρ = [[ 2.57939398e-03-3.91521838e-21j -6.50028903e-18-1.71577141e-17j
#    3.69655684e-18+2.14250169e-17j -4.04037952e-18-2.61693239e-17j
#   -1.66328959e-17-3.42307549e-18j -7.83348224e-18-1.36205146e-17j
#    1.24308485e-17+1.09316113e-18j -2.64088620e-17+2.16003883e-17j]
#  [-6.50028903e-18+1.71577141e-17j  7.40817924e-02-1.12447496e-19j
#   -2.45455444e-02-2.23829769e-01j  1.67002020e-17+2.11172805e-17j
#    7.38935922e-02-1.32117352e-04j  4.95700949e-18+2.43768830e-18j
#   -3.49144763e-17+8.69604466e-18j  6.49919026e-18-1.79086671e-17j]
#  [ 3.69655684e-18-2.14250169e-17j -2.45455444e-02+2.23829769e-01j
#    6.86597341e-01-1.04217446e-18j  3.47780645e-17-5.58693791e-18j
#   -2.41314776e-02+2.23724332e-01j  3.72306077e-17-1.02080169e-17j
#   -1.72824489e-17+4.43687439e-17j  6.60335004e-17-8.63386236e-18j]
#  [-4.04037952e-18+2.61693239e-17j  1.67002020e-17-2.11172805e-17j
#    3.47780645e-17+5.58693791e-18j  6.95592086e-02-1.05582743e-19j
#    1.74695989e-17-3.74953873e-17j  5.10457348e-04+2.79337985e-02j
#    1.45739737e-02+1.46078230e-04j  2.31902378e-17-3.83675814e-17j]
#  [-1.66328959e-17+3.42307549e-18j  7.38935922e-02+1.32117352e-04j
#   -2.41314776e-02-2.23724332e-01j  1.74695989e-17+3.74953873e-17j
#    7.39820249e-02-1.12296061e-19j  1.86218593e-17+6.85382193e-18j
#   -2.22789438e-18+3.96170137e-18j  1.90634020e-17-1.18536396e-17j]
#  [-7.83348224e-18+1.36205146e-17j  4.95700949e-18-2.43768830e-18j
#    3.72306077e-17+1.02080169e-17j  5.10457348e-04-2.79337985e-02j
#    1.86218593e-17-6.85382193e-18j  1.83887781e-02-2.44752449e-19j
#    5.38259796e-04-2.73593264e-02j -9.20804743e-18-1.77391835e-17j]
#  [ 1.24308485e-17-1.09316113e-18j -3.49144763e-17-8.69604466e-18j
#   -1.72824489e-17-4.43687439e-17j  1.45739737e-02-1.46078230e-04j
#   -2.22789438e-18-3.96170137e-18j  5.38259796e-04+2.73593264e-02j
#    6.78092510e-02+1.63179696e-18j -4.99175629e-18-3.80872139e-18j]
#  [-2.64088620e-17-2.16003883e-17j  6.49919026e-18+1.79086671e-17j
#    6.60335004e-17+8.63386236e-18j  2.31902378e-17+3.83675814e-17j
#    1.90634020e-17+1.18536396e-17j -9.20804743e-18+1.77391835e-17j
#   -4.99175629e-18+3.80872139e-18j  7.00221027e-03-1.06285362e-20j]]
# 窗口 2: 误差 = 1.840950596096793e-16
# 窗口 3: ρ = [[ 7.00221027e-03+4.55508695e-21j -1.04792898e-17+5.61290369e-18j
#   -5.58822038e-18-1.88536372e-17j -3.97922667e-17-3.41265493e-17j
#   -9.02111351e-18+1.78809793e-17j  9.88567116e-18+1.59485750e-16j
#   -7.44767417e-17-2.00047232e-17j  1.38043907e-17+1.43593998e-17j]
#  [-1.04792898e-17-5.61290369e-18j  6.95592086e-02-1.68947373e-18j
#    5.10457348e-04+2.79337985e-02j -7.03344150e-17-7.11860035e-17j
#    1.45739737e-02+1.46078230e-04j -2.07364714e-17-3.22083006e-17j
#   -4.36142153e-17+1.76007369e-17j  3.12672052e-17-4.72688636e-17j]
#  [-5.58822038e-18+1.88536372e-17j  5.10457348e-04-2.79337985e-02j
#    1.83887781e-02+2.28802726e-19j  7.60826064e-17-1.21112891e-16j
#    5.38259796e-04-2.73593264e-02j  9.90482759e-18-2.72824450e-16j
#    2.15984016e-17-1.20776038e-17j  5.97832494e-17+4.28675301e-17j]
#  [-3.97922667e-17+3.41265493e-17j -7.03344150e-17+7.11860035e-17j
#    7.60826064e-17+1.21112891e-16j  7.40817924e-02+4.81917841e-20j
#    2.94482961e-17+1.18152271e-17j -2.45455444e-02-2.23829769e-01j
#    7.38935922e-02-1.32117352e-04j  3.20453465e-17-7.08396710e-17j]
#  [-9.02111351e-18-1.78809793e-17j  1.45739737e-02-1.46078230e-04j
#    5.38259796e-04+2.73593264e-02j  2.94482961e-17-1.18152271e-17j
#    6.78092510e-02+4.41113623e-20j -1.66788233e-17+1.46291959e-17j
#   -9.21117084e-18-2.02145507e-17j  5.97669150e-18+5.58806064e-17j]
#  [ 9.88567116e-18-1.59485750e-16j -2.07364714e-17+3.22083006e-17j
#    9.90482759e-18+2.72824450e-16j -2.45455444e-02+2.23829769e-01j
#   -1.66788233e-17-1.46291959e-17j  6.86597341e-01+4.46646197e-19j
#   -2.41314776e-02+2.23724332e-01j  1.09981460e-17-1.63146058e-17j]
#  [-7.44767417e-17+2.00047232e-17j -4.36142153e-17-1.76007369e-17j
#    2.15984016e-17+1.20776038e-17j  7.38935922e-02+1.32117352e-04j
#   -9.21117084e-18+2.02145507e-17j -2.41314776e-02-2.23724332e-01j
#    7.39820249e-02+9.15488621e-19j  4.76272399e-17-1.05620127e-17j]
#  [ 1.38043907e-17-1.43593998e-17j  3.12672052e-17+4.72688636e-17j
#    5.97832494e-17-4.28675301e-17j  3.20453465e-17+7.08396710e-17j
#    5.97669150e-18-5.58806064e-17j  1.09981460e-17+1.63146058e-17j
#    4.76272399e-17+1.05620127e-17j  2.57939398e-03+1.67795074e-21j]]
# 窗口 3: 误差 = 3.2581992388688014e-16
# 窗口 4: ρ = [[ 1.51272001e-03-6.56037730e-21j  2.78332747e-17+1.63886247e-18j
#   -3.61225909e-18-8.37678184e-17j  8.85807524e-19+1.29799644e-17j
#    2.08590846e-17+8.51237181e-18j -1.37354520e-17-4.27403959e-18j
#   -2.48712114e-17+2.82551556e-17j -1.43128710e-17+6.09666323e-18j]
#  [ 2.78332747e-17-1.63886247e-18j  7.32987412e-02-3.17882618e-19j
#   -2.30600826e-02-2.22780826e-01j  7.76540429e-20+4.16601619e-19j
#    7.34523508e-02+3.46850202e-04j  2.98862528e-18-1.77514303e-17j
#   -2.37809608e-17+5.29169713e-17j  4.22262237e-17-3.98318713e-17j]
#  [-3.61225909e-18+8.37678184e-17j -2.30600826e-02+2.22780826e-01j
#    6.85858199e-01-2.97443580e-18j  2.63657662e-17+1.87488194e-17j
#   -2.42410538e-02+2.23447918e-01j -2.01546659e-17-1.21152141e-17j
#    2.99291814e-17+1.06872342e-16j -3.79868714e-18+8.50879231e-17j]
#  [ 8.85807524e-19-1.29799644e-17j  7.76540429e-20-4.16601619e-19j
#    2.63657662e-17-1.87488194e-17j  7.02983504e-02+3.16457646e-18j
#    9.85049889e-18+1.84782234e-17j  6.20033503e-04+2.82102128e-02j
#    1.48797184e-02-2.09589526e-04j -1.64253816e-17-1.18311943e-17j]
#  [ 2.08590846e-17-8.51237181e-18j  7.34523508e-02-3.46850202e-04j
#   -2.42410538e-02-2.23447918e-01j  9.85049889e-18-1.84782234e-17j
#    7.37781794e-02-3.19961850e-19j -8.25533917e-18-1.71177289e-17j
#   -8.01319081e-18+2.07513046e-17j -5.88780163e-18+2.01074666e-17j]
#  [-1.37354520e-17+4.27403959e-18j  2.98862528e-18+1.77514303e-17j
#   -2.01546659e-17+1.21152141e-17j  6.20033503e-04-2.82102128e-02j
#   -8.25533917e-18+1.71177289e-17j  1.85926236e-02+7.86729087e-19j
#    5.72259297e-04-2.78853032e-02j -4.01277950e-18+1.05012771e-17j]
#  [-2.48712114e-17-2.82551556e-17j -2.37809608e-17-5.29169713e-17j
#    2.99291814e-17-1.06872342e-16j  1.48797184e-02+2.09589526e-04j
#   -8.01319081e-18-2.07513046e-17j  5.72259297e-04+2.78853032e-02j
#    6.93879117e-02-3.00922098e-19j -2.08558988e-17-1.54945773e-17j]
#  [-1.43128710e-17-6.09666323e-18j  4.22262237e-17+3.98318713e-17j
#   -3.79868714e-18-8.50879231e-17j -1.64253816e-17+1.18311943e-17j
#   -5.88780163e-18-2.01074666e-17j -4.01277950e-18-1.05012771e-17j
#   -2.08558988e-17+1.54945773e-17j  7.27327464e-03-3.15428007e-20j]]
# 窗口 4: 误差 = 2.7614034209869983e-16
# 窗口 5: ρ = [[ 4.99979393e-05+1.69399608e-25j -1.10452297e-17+5.48535421e-18j
#   -1.87667538e-17-1.59689782e-17j -1.85846954e-17+9.67825782e-18j
#   -8.55472181e-18-1.07238896e-17j  2.94486578e-17-4.03635160e-18j
#   -1.07854585e-18-4.25796949e-18j  3.46341996e-18-1.73467208e-17j]
#  [-1.10452297e-17-5.48535421e-18j  7.52409015e-02+2.54926090e-22j
#   -4.87930065e-04+2.69141373e-02j -1.23212817e-17-2.15589217e-17j
#    8.62143896e-03+6.76730402e-03j -8.43844557e-18-2.31430605e-18j
#    2.37175182e-17-2.60211401e-17j  2.37942205e-17-1.72678517e-17j]
#  [-1.87667538e-17+1.59689782e-17j -4.87930065e-04-2.69141373e-02j
#    9.64551242e-03+3.26802672e-23j  2.07016998e-17+6.33258540e-17j
#    2.37265641e-03-3.17072818e-03j  3.90929216e-17-5.69174367e-17j
#   -2.61269532e-18+5.25313716e-17j -3.86994618e-17+9.36625672e-18j]
#  [-1.85846954e-17-9.67825782e-18j -1.23212817e-17+2.15589217e-17j
#    2.07016998e-17-6.33258540e-17j  8.22458524e-02+2.78659787e-22j
#   -1.29861604e-18-2.95416278e-17j -2.48604797e-02-2.47495401e-01j
#    7.88839985e-02-3.31467168e-03j  1.06950177e-17-3.67993858e-17j]
#  [-8.55472181e-18+1.07238896e-17j  8.62143896e-03-6.76730402e-03j
#    2.37265641e-03+3.17072818e-03j -1.29861604e-18+2.95416278e-17j
#    1.72411111e-03-3.38229027e-21j  9.79039278e-18-5.18356969e-17j
#    2.56946962e-17-9.30579441e-18j -2.29374235e-18+3.55429227e-18j]
#  [ 2.94486578e-17+4.03635160e-18j -8.43844557e-18+2.31430605e-18j
#    3.90929216e-17+5.69174367e-17j -2.48604797e-02+2.47495401e-01j
#    9.79039278e-18+5.18356969e-17j  7.53522000e-01+2.55303184e-21j
#   -1.38456007e-02+2.38688976e-01j  6.48956625e-19+4.51945681e-17j]
#  [-1.07854585e-18+4.25796949e-18j  2.37175182e-17+2.60211401e-17j
#   -2.61269532e-18-5.25313716e-17j  7.88839985e-02+3.31467168e-03j
#    2.56946962e-17+9.30579441e-18j -1.38456007e-02-2.38688976e-01j
#    7.58703036e-02+2.57058587e-22j -2.25203662e-17-2.31196593e-17j]
#  [ 3.46341996e-18+1.73467208e-17j  2.37942205e-17+1.72678517e-17j
#   -3.86994618e-17-9.36625672e-18j  1.06950177e-17+3.67993858e-17j
#   -2.29374235e-18-3.55429227e-18j  6.48956625e-19-4.51945681e-17j
#   -2.25203662e-17+2.31196593e-17j  1.70132144e-03+5.76430125e-24j]]
# 窗口 5: 误差 = 2.264489924440269e-16

# %%
def fidelity(rho, sigma):
    """
    计算两个密度矩阵之间的保真度
    """
    sqrt_rho = sqrtm(rho)
    inner = sqrtm(sqrt_rho @ sigma @ sqrt_rho)
    return np.real(np.trace(inner))**2

def compute_all_fidelities(true_rhos, mle_rhos):
    fidelities = {}
    for i in true_rhos:
        fidelities[i] = fidelity(true_rhos[i], mle_rhos[i])
    return fidelities
fidelities = compute_all_fidelities(local_density_matrices, mle_rhos)

print("\n 各窗口 MLE 密度矩阵与原始密度矩阵的保真度：")
for i in sorted(fidelities):
    print(f"窗口 {i}: 保真度 F = {np.round(fidelities[i], 15)}")
# Out:
#  各窗口 MLE 密度矩阵与原始密度矩阵的保真度：
# 窗口 0: 保真度 F = 1.000000000028729
# 窗口 1: 保真度 F = 0.999999999999868
# 窗口 2: 保真度 F = 0.999999999999777
# 窗口 3: 保真度 F = 0.99999999999998
# 窗口 4: 保真度 F = 0.999999999999977
# 窗口 5: 保真度 F = 0.999999999998332

# %%
def generate_pauli_basis(k):
    """
    返回：dict[tuple[str]] -> ndarray，Pauli 张量积及其对应的矩阵
    """
    basis = {}
    for label in product(['I', 'X', 'Y', 'Z'], repeat=k):
        op = pauli_ops[label[0]]
        for p in label[1:]:
            op = np.kron(op, pauli_ops[p])
        basis[label] = op
    return basis
def svt_single_window(rho_target, pauli_basis_dict, all_expectation_dict, max_iter=50, delta=0.1):
    """
    输入：
        pauli_basis_dict: dict[tuple[str]] -> np.ndarray
        all_expectation_dict: dict[tuple[str]] -> float
    """
    dim = rho_target.shape[0]
    diag_elements = np.zeros(dim, dtype=complex)
    diag_elements[0] = 0
    Y = np.diag(diag_elements)
    # Y=rho_target
    # Y=rho_target @ rho_target.conj().T
    # Y /= np.trace(Y)
    projection_errors = []
    min_error = float('inf')
    best_Y = None
    best_iter = 0

    for iteration in range(1,max_iter+1):
        print(f"第{iteration}轮迭代")
        eigvals, eigvecs = np.linalg.eigh(Y)
        max_idx = np.argmax(eigvals)
        psi = eigvecs[:, max_idx]  # 最大本征态
        # 估计密度矩阵
        X_n = eigvals[max_idx] * sum(np.vdot(psi, P @ psi) * P for P in pauli_basis_dict.values())
        Y += delta * (rho_target - X_n)
        eigvals, eigvecs = np.linalg.eigh(Y)
        # min_idx = np.argmin(eigvals)
        # psi = eigvecs[:, min_idx]  
        max_idx = np.argmax(eigvals)
        psi = eigvecs[:, max_idx]  # 最大本征态
        # 误差计算
        error = 0.0
        for label_tuple, P in pauli_basis_dict.items():
            ideal_val = all_expectation_dict.get(label_tuple, None)

            pred_val = np.vdot(psi, P @ psi)
            error += np.abs(ideal_val - pred_val)
        projection_errors.append(error)

        # 记录最小误差和对应的 Y
        if error < min_error:
            min_error = error
            best_Y = Y.copy()
            best_iter = iteration

    return best_Y, projection_errors, best_iter

def svt_all_windows(mle_rhos, all_expectations, k, max_iter=50, delta=0.1):
    """
    all_expectations[i] 是 dict[tuple[str]] -> float
    """
    pauli_basis_dict = generate_pauli_basis(k)
    svt_Ys = {}
    all_projection_errors = {}
    best_Ys = {}
    best_iters = {}

    for i, rho in mle_rhos.items():
        best_Y, proj_errors, best_iter = svt_single_window(
            rho_target=rho,
            pauli_basis_dict=pauli_basis_dict,
            all_expectation_dict=all_expectations[i],
            max_iter=max_iter,
            delta=delta
        )
        svt_Ys[i] = best_Y
        all_projection_errors[i] = proj_errors
        best_Ys[i] = best_Y
        best_iters[i] = best_iter

    return svt_Ys, all_projection_errors, best_Ys, best_iters

# %%
# 参数设置        
# 局部窗口大小
max_iter = 10000  # SVT 迭代轮数
delta = 0.005    # 步长

# 执行 SVT
svt_Y_rhos, all_projection_errors, best_Ys, best_iters = svt_all_windows(
    local_density_matrices,
    all_expectations, 
    k, 
    max_iter=max_iter, 
    delta=delta
)
# Out:
# 第1轮迭代
# 第2轮迭代
# 第3轮迭代
# 第4轮迭代
# 第5轮迭代
# 第6轮迭代
# 第7轮迭代
# 第8轮迭代
# 第9轮迭代
# 第10轮迭代
# 第11轮迭代
# 第12轮迭代
# 第13轮迭代
# 第14轮迭代
# 第15轮迭代
# 第16轮迭代
# 第17轮迭代
# 第18轮迭代
# 第19轮迭代
# 第20轮迭代
# 第21轮迭代
# 第22轮迭代
# 第23轮迭代
# 第24轮迭代
# 第25轮迭代
# 第26轮迭代
# 第27轮迭代
# 第28轮迭代
# 第29轮迭代
# 第30轮迭代
# 第31轮迭代
# 第32轮迭代
# 第33轮迭代
# 第34轮迭代
# 第35轮迭代
# 第36轮迭代
# 第37轮迭代
# 第38轮迭代
# 第39轮迭代
# 第40轮迭代
# 第41轮迭代
# 第42轮迭代
# 第43轮迭代
# 第44轮迭代
# 第45轮迭代
# 第46轮迭代
# 第47轮迭代
# 第48轮迭代
# 第49轮迭代
# 第50轮迭代
# 第51轮迭代
# 第52轮迭代
# 第53轮迭代
# 第54轮迭代
# 第55轮迭代
# 第56轮迭代
# 第57轮迭代
# 第58轮迭代
# 第59轮迭代
# 第60轮迭代
# 第61轮迭代
# 第62轮迭代
# 第63轮迭代
# 第64轮迭代
# 第65轮迭代
# 第66轮迭代
# 第67轮迭代
# 第68轮迭代
# 第69轮迭代
# 第70轮迭代
# 第71轮迭代
# 第72轮迭代
# 第73轮迭代
# 第74轮迭代
# 第75轮迭代
# 第76轮迭代
# 第77轮迭代
# 第78轮迭代
# 第79轮迭代
# 第80轮迭代
# 第81轮迭代
# 第82轮迭代
# 第83轮迭代
# 第84轮迭代
# 第85轮迭代
# 第86轮迭代
# 第87轮迭代
# 第88轮迭代
# 第89轮迭代
# 第90轮迭代
# 第91轮迭代
# 第92轮迭代
# 第93轮迭代
# 第94轮迭代
# 第95轮迭代
# 第96轮迭代
# 第97轮迭代
# 第98轮迭代
# 第99轮迭代
# 第100轮迭代
# 第101轮迭代
# 第102轮迭代
# 第103轮迭代
# 第104轮迭代
# 第105轮迭代
# 第106轮迭代
# 第107轮迭代
# 第108轮迭代
# 第109轮迭代
# 第110轮迭代
# 第111轮迭代
# 第112轮迭代
# 第113轮迭代
# 第114轮迭代
# 第115轮迭代
# 第116轮迭代
# 第117轮迭代
# 第118轮迭代
# 第119轮迭代
# 第120轮迭代
# 第121轮迭代
# 第122轮迭代
# 第123轮迭代
# 第124轮迭代
# 第125轮迭代
# 第126轮迭代
# 第127轮迭代
# 第128轮迭代
# 第129轮迭代
# 第130轮迭代
# 第131轮迭代
# 第132轮迭代
# 第133轮迭代
# 第134轮迭代
# 第135轮迭代
# 第136轮迭代
# 第137轮迭代
# 第138轮迭代
# 第139轮迭代
# 第140轮迭代
# 第141轮迭代
# 第142轮迭代
# 第143轮迭代
# 第144轮迭代
# 第145轮迭代
# 第146轮迭代
# 第147轮迭代
# 第148轮迭代
# 第149轮迭代
# 第150轮迭代
# 第151轮迭代
# 第152轮迭代
# 第153轮迭代
# 第154轮迭代
# 第155轮迭代
# 第156轮迭代
# 第157轮迭代
# 第158轮迭代
# 第159轮迭代
# 第160轮迭代
# 第161轮迭代
# 第162轮迭代
# 第163轮迭代
# 第164轮迭代
# 第165轮迭代
# 第166轮迭代
# 第167轮迭代
# 第168轮迭代
# 第169轮迭代
# 第170轮迭代
# 第171轮迭代
# 第172轮迭代
# 第173轮迭代
# 第174轮迭代
# 第175轮迭代
# 第176轮迭代
# 第177轮迭代
# 第178轮迭代
# 第179轮迭代
# 第180轮迭代
# 第181轮迭代
# 第182轮迭代
# 第183轮迭代
# 第184轮迭代
# 第185轮迭代
# 第186轮迭代
# 第187轮迭代
# 第188轮迭代
# 第189轮迭代
# 第190轮迭代
# 第191轮迭代
# 第192轮迭代
# 第193轮迭代
# 第194轮迭代
# 第195轮迭代
# 第196轮迭代
# 第197轮迭代
# 第198轮迭代
# 第199轮迭代
# 第200轮迭代
# 第201轮迭代
# 第202轮迭代
# 第203轮迭代
# 第204轮迭代
# 第205轮迭代
# 第206轮迭代
# 第207轮迭代
# 第208轮迭代
# 第209轮迭代
# 第210轮迭代
# 第211轮迭代
# 第212轮迭代
# 第213轮迭代
# 第214轮迭代
# 第215轮迭代
# 第216轮迭代
# 第217轮迭代
# 第218轮迭代
# 第219轮迭代
# 第220轮迭代
# 第221轮迭代
# 第222轮迭代
# 第223轮迭代
# 第224轮迭代
# 第225轮迭代
# 第226轮迭代
# 第227轮迭代
# 第228轮迭代
# 第229轮迭代
# 第230轮迭代
# 第231轮迭代
# 第232轮迭代
# 第233轮迭代
# 第234轮迭代
# 第235轮迭代
# 第236轮迭代
# 第237轮迭代
# 第238轮迭代
# 第239轮迭代
# 第240轮迭代
# 第241轮迭代
# 第242轮迭代
# 第243轮迭代
# 第244轮迭代
# 第245轮迭代
# 第246轮迭代
# 第247轮迭代
# 第248轮迭代
# 第249轮迭代
# 第250轮迭代
# 第251轮迭代
# 第252轮迭代
# 第253轮迭代
# 第254轮迭代
# 第255轮迭代
# 第256轮迭代
# 第257轮迭代
# 第258轮迭代
# 第259轮迭代
# 第260轮迭代
# 第261轮迭代
# 第262轮迭代
# 第263轮迭代
# 第264轮迭代
# 第265轮迭代
# 第266轮迭代
# 第267轮迭代
# 第268轮迭代
# 第269轮迭代
# 第270轮迭代
# 第271轮迭代
# 第272轮迭代
# 第273轮迭代
# 第274轮迭代
# 第275轮迭代
# 第276轮迭代
# 第277轮迭代
# 第278轮迭代
# 第279轮迭代
# 第280轮迭代
# 第281轮迭代
# 第282轮迭代
# 第283轮迭代
# 第284轮迭代
# 第285轮迭代
# 第286轮迭代
# 第287轮迭代
# 第288轮迭代
# 第289轮迭代
# 第290轮迭代
# 第291轮迭代
# 第292轮迭代
# 第293轮迭代
# 第294轮迭代
# 第295轮迭代
# 第296轮迭代
# 第297轮迭代
# 第298轮迭代
# 第299轮迭代
# 第300轮迭代
# 第301轮迭代
# 第302轮迭代
# 第303轮迭代
# 第304轮迭代
# 第305轮迭代
# 第306轮迭代
# 第307轮迭代
# 第308轮迭代
# 第309轮迭代
# 第310轮迭代
# 第311轮迭代
# 第312轮迭代
# 第313轮迭代
# 第314轮迭代
# 第315轮迭代
# 第316轮迭代
# 第317轮迭代
# 第318轮迭代
# 第319轮迭代
# 第320轮迭代
# 第321轮迭代
# 第322轮迭代
# 第323轮迭代
# 第324轮迭代
# 第325轮迭代
# 第326轮迭代
# 第327轮迭代
# 第328轮迭代
# 第329轮迭代
# 第330轮迭代
# 第331轮迭代
# 第332轮迭代
# 第333轮迭代
# 第334轮迭代
# 第335轮迭代
# 第336轮迭代
# 第337轮迭代
# 第338轮迭代
# 第339轮迭代
# 第340轮迭代
# 第341轮迭代
# 第342轮迭代
# 第343轮迭代
# 第344轮迭代
# 第345轮迭代
# 第346轮迭代
# 第347轮迭代
# 第348轮迭代
# 第349轮迭代
# 第350轮迭代
# 第351轮迭代
# 第352轮迭代
# 第353轮迭代
# 第354轮迭代
# 第355轮迭代
# 第356轮迭代
# 第357轮迭代
# 第358轮迭代
# 第359轮迭代
# 第360轮迭代
# 第361轮迭代
# 第362轮迭代
# 第363轮迭代
# 第364轮迭代
# 第365轮迭代
# 第366轮迭代
# 第367轮迭代
# 第368轮迭代
# 第369轮迭代
# 第370轮迭代
# 第371轮迭代
# 第372轮迭代
# 第373轮迭代
# 第374轮迭代
# 第375轮迭代
# 第376轮迭代
# 第377轮迭代
# 第378轮迭代
# 第379轮迭代
# 第380轮迭代
# 第381轮迭代
# 第382轮迭代
# 第383轮迭代
# 第384轮迭代
# 第385轮迭代
# 第386轮迭代
# 第387轮迭代
# 第388轮迭代
# 第389轮迭代
# 第390轮迭代
# 第391轮迭代
# 第392轮迭代
# 第393轮迭代
# 第394轮迭代
# 第395轮迭代
# 第396轮迭代
# 第397轮迭代
# 第398轮迭代
# 第399轮迭代
# 第400轮迭代
# 第401轮迭代
# 第402轮迭代
# 第403轮迭代
# 第404轮迭代
# 第405轮迭代
# 第406轮迭代
# 第407轮迭代
# 第408轮迭代
# 第409轮迭代
# 第410轮迭代
# 第411轮迭代
# 第412轮迭代
# 第413轮迭代
# 第414轮迭代
# 第415轮迭代
# 第416轮迭代
# 第417轮迭代
# 第418轮迭代
# 第419轮迭代
# 第420轮迭代
# 第421轮迭代
# 第422轮迭代
# 第423轮迭代
# 第424轮迭代
# 第425轮迭代
# 第426轮迭代
# 第427轮迭代
# 第428轮迭代
# 第429轮迭代
# 第430轮迭代
# 第431轮迭代
# 第432轮迭代
# 第433轮迭代
# 第434轮迭代
# 第435轮迭代
# 第436轮迭代
# 第437轮迭代
# 第438轮迭代
# 第439轮迭代
# 第440轮迭代
# 第441轮迭代
# 第442轮迭代
# 第443轮迭代
# 第444轮迭代
# 第445轮迭代
# 第446轮迭代
# 第447轮迭代
# 第448轮迭代
# 第449轮迭代
# 第450轮迭代
# 第451轮迭代
# 第452轮迭代
# 第453轮迭代
# 第454轮迭代
# 第455轮迭代
# 第456轮迭代
# 第457轮迭代
# 第458轮迭代
# 第459轮迭代
# 第460轮迭代
# 第461轮迭代
# 第462轮迭代
# 第463轮迭代
# 第464轮迭代
# 第465轮迭代
# 第466轮迭代
# 第467轮迭代
# 第468轮迭代
# 第469轮迭代
# 第470轮迭代
# 第471轮迭代
# 第472轮迭代
# 第473轮迭代
# 第474轮迭代
# 第475轮迭代
# 第476轮迭代
# 第477轮迭代
# 第478轮迭代
# 第479轮迭代
# 第480轮迭代
# 第481轮迭代
# 第482轮迭代
# 第483轮迭代
# 第484轮迭代
# 第485轮迭代
# 第486轮迭代
# 第487轮迭代
# 第488轮迭代
# 第489轮迭代
# 第490轮迭代
# 第491轮迭代
# 第492轮迭代
# 第493轮迭代
# 第494轮迭代
# 第495轮迭代
# 第496轮迭代
# 第497轮迭代
# 第498轮迭代
# 第499轮迭代
# 第500轮迭代
# 第501轮迭代
# 第502轮迭代
# 第503轮迭代
# 第504轮迭代
# 第505轮迭代
# 第506轮迭代
# 第507轮迭代
# 第508轮迭代
# 第509轮迭代
# 第510轮迭代
# 第511轮迭代
# 第512轮迭代
# 第513轮迭代
# 第514轮迭代
# 第515轮迭代
# 第516轮迭代
# 第517轮迭代
# 第518轮迭代
# 第519轮迭代
# 第520轮迭代
# 第521轮迭代
# 第522轮迭代
# 第523轮迭代
# 第524轮迭代
# 第525轮迭代
# 第526轮迭代
# 第527轮迭代
# 第528轮迭代
# 第529轮迭代
# 第530轮迭代
# 第531轮迭代
# 第532轮迭代
# 第533轮迭代
# 第534轮迭代
# 第535轮迭代
# 第536轮迭代
# 第537轮迭代
# 第538轮迭代
# 第539轮迭代
# 第540轮迭代
# 第541轮迭代
# 第542轮迭代
# 第543轮迭代
# 第544轮迭代
# 第545轮迭代
# 第546轮迭代
# 第547轮迭代
# 第548轮迭代
# 第549轮迭代
# 第550轮迭代
# 第551轮迭代
# 第552轮迭代
# 第553轮迭代
# 第554轮迭代
# 第555轮迭代
# 第556轮迭代
# 第557轮迭代
# 第558轮迭代
# 第559轮迭代
# 第560轮迭代
# 第561轮迭代
# 第562轮迭代
# 第563轮迭代
# 第564轮迭代
# 第565轮迭代
# 第566轮迭代
# 第567轮迭代
# 第568轮迭代
# 第569轮迭代
# 第570轮迭代
# 第571轮迭代
# 第572轮迭代
# 第573轮迭代
# 第574轮迭代
# 第575轮迭代
# 第576轮迭代
# 第577轮迭代
# 第578轮迭代
# 第579轮迭代
# 第580轮迭代
# 第581轮迭代
# 第582轮迭代
# 第583轮迭代
# 第584轮迭代
# 第585轮迭代
# 第586轮迭代
# 第587轮迭代
# 第588轮迭代
# 第589轮迭代
# 第590轮迭代
# 第591轮迭代
# 第592轮迭代
# 第593轮迭代
# 第594轮迭代
# 第595轮迭代
# 第596轮迭代
# 第597轮迭代
# 第598轮迭代
# 第599轮迭代
# 第600轮迭代
# 第601轮迭代
# 第602轮迭代
# 第603轮迭代
# 第604轮迭代
# 第605轮迭代
# 第606轮迭代
# 第607轮迭代
# 第608轮迭代
# 第609轮迭代
# 第610轮迭代
# 第611轮迭代
# 第612轮迭代
# 第613轮迭代
# 第614轮迭代
# 第615轮迭代
# 第616轮迭代
# 第617轮迭代
# 第618轮迭代
# 第619轮迭代
# 第620轮迭代
# 第621轮迭代
# 第622轮迭代
# 第623轮迭代
# 第624轮迭代
# 第625轮迭代
# 第626轮迭代
# 第627轮迭代
# 第628轮迭代
# 第629轮迭代
# 第630轮迭代
# 第631轮迭代
# 第632轮迭代
# 第633轮迭代
# 第634轮迭代
# 第635轮迭代
# 第636轮迭代
# 第637轮迭代
# 第638轮迭代
# 第639轮迭代
# 第640轮迭代
# 第641轮迭代
# 第642轮迭代
# 第643轮迭代
# 第644轮迭代
# 第645轮迭代
# 第646轮迭代
# 第647轮迭代
# 第648轮迭代
# 第649轮迭代
# 第650轮迭代
# 第651轮迭代
# 第652轮迭代
# 第653轮迭代
# 第654轮迭代
# 第655轮迭代
# 第656轮迭代
# 第657轮迭代
# 第658轮迭代
# 第659轮迭代
# 第660轮迭代
# 第661轮迭代
# 第662轮迭代
# 第663轮迭代
# 第664轮迭代
# 第665轮迭代
# 第666轮迭代
# 第667轮迭代
# 第668轮迭代
# 第669轮迭代
# 第670轮迭代
# 第671轮迭代
# 第672轮迭代
# 第673轮迭代
# 第674轮迭代
# 第675轮迭代
# 第676轮迭代
# 第677轮迭代
# 第678轮迭代
# 第679轮迭代
# 第680轮迭代
# 第681轮迭代
# 第682轮迭代
# 第683轮迭代
# 第684轮迭代
# 第685轮迭代
# 第686轮迭代
# 第687轮迭代
# 第688轮迭代
# 第689轮迭代
# 第690轮迭代
# 第691轮迭代
# 第692轮迭代
# 第693轮迭代
# 第694轮迭代
# 第695轮迭代
# 第696轮迭代
# 第697轮迭代
# 第698轮迭代
# 第699轮迭代
# 第700轮迭代
# 第701轮迭代
# 第702轮迭代
# 第703轮迭代
# 第704轮迭代
# 第705轮迭代
# 第706轮迭代
# 第707轮迭代
# 第708轮迭代
# 第709轮迭代
# 第710轮迭代
# 第711轮迭代
# 第712轮迭代
# 第713轮迭代
# 第714轮迭代
# 第715轮迭代
# 第716轮迭代
# 第717轮迭代
# 第718轮迭代
# 第719轮迭代
# 第720轮迭代
# 第721轮迭代
# 第722轮迭代
# 第723轮迭代
# 第724轮迭代
# 第725轮迭代
# 第726轮迭代
# 第727轮迭代
# 第728轮迭代
# 第729轮迭代
# 第730轮迭代
# 第731轮迭代
# 第732轮迭代
# 第733轮迭代
# 第734轮迭代
# 第735轮迭代
# 第736轮迭代
# 第737轮迭代
# 第738轮迭代
# 第739轮迭代
# 第740轮迭代
# 第741轮迭代
# 第742轮迭代
# 第743轮迭代
# 第744轮迭代
# 第745轮迭代
# 第746轮迭代
# 第747轮迭代
# 第748轮迭代
# 第749轮迭代
# 第750轮迭代
# 第751轮迭代
# 第752轮迭代
# 第753轮迭代
# 第754轮迭代
# 第755轮迭代
# 第756轮迭代
# 第757轮迭代
# 第758轮迭代
# 第759轮迭代
# 第760轮迭代
# 第761轮迭代
# 第762轮迭代
# 第763轮迭代
# 第764轮迭代
# 第765轮迭代
# 第766轮迭代
# 第767轮迭代
# 第768轮迭代
# 第769轮迭代
# 第770轮迭代
# 第771轮迭代
# 第772轮迭代
# 第773轮迭代
# 第774轮迭代
# 第775轮迭代
# 第776轮迭代
# 第777轮迭代
# 第778轮迭代
# 第779轮迭代
# 第780轮迭代
# 第781轮迭代
# 第782轮迭代
# 第783轮迭代
# 第784轮迭代
# 第785轮迭代
# 第786轮迭代
# 第787轮迭代
# 第788轮迭代
# 第789轮迭代
# 第790轮迭代
# 第791轮迭代
# 第792轮迭代
# 第793轮迭代
# 第794轮迭代
# 第795轮迭代
# 第796轮迭代
# 第797轮迭代
# 第798轮迭代
# 第799轮迭代
# 第800轮迭代
# 第801轮迭代
# 第802轮迭代
# 第803轮迭代
# 第804轮迭代
# 第805轮迭代
# 第806轮迭代
# 第807轮迭代
# 第808轮迭代
# 第809轮迭代
# 第810轮迭代
# 第811轮迭代
# 第812轮迭代
# 第813轮迭代
# 第814轮迭代
# 第815轮迭代
# 第816轮迭代
# 第817轮迭代
# 第818轮迭代
# 第819轮迭代
# 第820轮迭代
# 第821轮迭代
# 第822轮迭代
# 第823轮迭代
# 第824轮迭代
# 第825轮迭代
# 第826轮迭代
# 第827轮迭代
# 第828轮迭代
# 第829轮迭代
# 第830轮迭代
# 第831轮迭代
# 第832轮迭代
# 第833轮迭代
# 第834轮迭代
# 第835轮迭代
# 第836轮迭代
# 第837轮迭代
# 第838轮迭代
# 第839轮迭代
# 第840轮迭代
# 第841轮迭代
# 第842轮迭代
# 第843轮迭代
# 第844轮迭代
# 第845轮迭代
# 第846轮迭代
# 第847轮迭代
# 第848轮迭代
# 第849轮迭代
# 第850轮迭代
# 第851轮迭代
# 第852轮迭代
# 第853轮迭代
# 第854轮迭代
# 第855轮迭代
# 第856轮迭代
# 第857轮迭代
# 第858轮迭代
# 第859轮迭代
# 第860轮迭代
# 第861轮迭代
# 第862轮迭代
# 第863轮迭代
# 第864轮迭代
# 第865轮迭代
# 第866轮迭代
# 第867轮迭代
# 第868轮迭代
# 第869轮迭代
# 第870轮迭代
# 第871轮迭代
# 第872轮迭代
# 第873轮迭代
# 第874轮迭代
# 第875轮迭代
# 第876轮迭代
# 第877轮迭代
# 第878轮迭代
# 第879轮迭代
# 第880轮迭代
# 第881轮迭代
# 第882轮迭代
# 第883轮迭代
# 第884轮迭代
# 第885轮迭代
# 第886轮迭代
# 第887轮迭代
# 第888轮迭代
# 第889轮迭代
# 第890轮迭代
# 第891轮迭代
# 第892轮迭代
# 第893轮迭代
# 第894轮迭代
# 第895轮迭代
# 第896轮迭代
# 第897轮迭代
# 第898轮迭代
# 第899轮迭代
# 第900轮迭代
# 第901轮迭代
# 第902轮迭代
# 第903轮迭代
# 第904轮迭代
# 第905轮迭代
# 第906轮迭代
# 第907轮迭代
# 第908轮迭代
# 第909轮迭代
# 第910轮迭代
# 第911轮迭代
# 第912轮迭代
# 第913轮迭代
# 第914轮迭代
# 第915轮迭代
# 第916轮迭代
# 第917轮迭代
# 第918轮迭代
# 第919轮迭代
# 第920轮迭代
# 第921轮迭代
# 第922轮迭代
# 第923轮迭代
# 第924轮迭代
# 第925轮迭代
# 第926轮迭代
# 第927轮迭代
# 第928轮迭代
# 第929轮迭代
# 第930轮迭代
# 第931轮迭代
# 第932轮迭代
# 第933轮迭代
# 第934轮迭代
# 第935轮迭代
# 第936轮迭代
# 第937轮迭代
# 第938轮迭代
# 第939轮迭代
# 第940轮迭代
# 第941轮迭代
# 第942轮迭代
# 第943轮迭代
# 第944轮迭代
# 第945轮迭代
# 第946轮迭代
# 第947轮迭代
# 第948轮迭代
# 第949轮迭代
# 第950轮迭代
# 第951轮迭代
# 第952轮迭代
# 第953轮迭代
# 第954轮迭代
# 第955轮迭代
# 第956轮迭代
# 第957轮迭代
# 第958轮迭代
# 第959轮迭代
# 第960轮迭代
# 第961轮迭代
# 第962轮迭代
# 第963轮迭代
# 第964轮迭代
# 第965轮迭代
# 第966轮迭代
# 第967轮迭代
# 第968轮迭代
# 第969轮迭代
# 第970轮迭代
# 第971轮迭代
# 第972轮迭代
# 第973轮迭代
# 第974轮迭代
# 第975轮迭代
# 第976轮迭代
# 第977轮迭代
# 第978轮迭代
# 第979轮迭代
# 第980轮迭代
# 第981轮迭代
# 第982轮迭代
# 第983轮迭代
# 第984轮迭代
# 第985轮迭代
# 第986轮迭代
# 第987轮迭代
# 第988轮迭代
# 第989轮迭代
# 第990轮迭代
# 第991轮迭代
# 第992轮迭代
# 第993轮迭代
# 第994轮迭代
# 第995轮迭代
# 第996轮迭代
# 第997轮迭代
# 第998轮迭代
# 第999轮迭代
# 第1000轮迭代
# 第1001轮迭代
# 第1002轮迭代
# 第1003轮迭代
# 第1004轮迭代
# 第1005轮迭代
# 第1006轮迭代
# 第1007轮迭代
# 第1008轮迭代
# 第1009轮迭代
# 第1010轮迭代
# 第1011轮迭代
# 第1012轮迭代
# 第1013轮迭代
# 第1014轮迭代
# 第1015轮迭代
# 第1016轮迭代
# 第1017轮迭代
# 第1018轮迭代
# 第1019轮迭代
# 第1020轮迭代
# 第1021轮迭代
# 第1022轮迭代
# 第1023轮迭代
# 第1024轮迭代
# 第1025轮迭代
# 第1026轮迭代
# 第1027轮迭代
# 第1028轮迭代
# 第1029轮迭代
# 第1030轮迭代
# 第1031轮迭代
# 第1032轮迭代
# 第1033轮迭代
# 第1034轮迭代
# 第1035轮迭代
# 第1036轮迭代
# 第1037轮迭代
# 第1038轮迭代
# 第1039轮迭代
# 第1040轮迭代
# 第1041轮迭代
# 第1042轮迭代
# 第1043轮迭代
# 第1044轮迭代
# 第1045轮迭代
# 第1046轮迭代
# 第1047轮迭代
# 第1048轮迭代
# 第1049轮迭代
# 第1050轮迭代
# 第1051轮迭代
# 第1052轮迭代
# 第1053轮迭代
# 第1054轮迭代
# 第1055轮迭代
# 第1056轮迭代
# 第1057轮迭代
# 第1058轮迭代
# 第1059轮迭代
# 第1060轮迭代
# 第1061轮迭代
# 第1062轮迭代
# 第1063轮迭代
# 第1064轮迭代
# 第1065轮迭代
# 第1066轮迭代
# 第1067轮迭代
# 第1068轮迭代
# 第1069轮迭代
# 第1070轮迭代
# 第1071轮迭代
# 第1072轮迭代
# 第1073轮迭代
# 第1074轮迭代
# 第1075轮迭代
# 第1076轮迭代
# 第1077轮迭代
# 第1078轮迭代
# 第1079轮迭代
# 第1080轮迭代
# 第1081轮迭代
# 第1082轮迭代
# 第1083轮迭代
# 第1084轮迭代
# 第1085轮迭代
# 第1086轮迭代
# 第1087轮迭代
# 第1088轮迭代
# 第1089轮迭代
# 第1090轮迭代
# 第1091轮迭代
# 第1092轮迭代
# 第1093轮迭代
# 第1094轮迭代
# 第1095轮迭代
# 第1096轮迭代
# 第1097轮迭代
# 第1098轮迭代
# 第1099轮迭代
# 第1100轮迭代
# 第1101轮迭代
# 第1102轮迭代
# 第1103轮迭代
# 第1104轮迭代
# 第1105轮迭代
# 第1106轮迭代
# 第1107轮迭代
# 第1108轮迭代
# 第1109轮迭代
# 第1110轮迭代
# 第1111轮迭代
# 第1112轮迭代
# 第1113轮迭代
# 第1114轮迭代
# 第1115轮迭代
# 第1116轮迭代
# 第1117轮迭代
# 第1118轮迭代
# 第1119轮迭代
# 第1120轮迭代
# 第1121轮迭代
# 第1122轮迭代
# 第1123轮迭代
# 第1124轮迭代
# 第1125轮迭代
# 第1126轮迭代
# 第1127轮迭代
# 第1128轮迭代
# 第1129轮迭代
# 第1130轮迭代
# 第1131轮迭代
# 第1132轮迭代
# 第1133轮迭代
# 第1134轮迭代
# 第1135轮迭代
# 第1136轮迭代
# 第1137轮迭代
# 第1138轮迭代
# 第1139轮迭代
# 第1140轮迭代
# 第1141轮迭代
# 第1142轮迭代
# 第1143轮迭代
# 第1144轮迭代
# 第1145轮迭代
# 第1146轮迭代
# 第1147轮迭代
# 第1148轮迭代
# 第1149轮迭代
# 第1150轮迭代
# 第1151轮迭代
# 第1152轮迭代
# 第1153轮迭代
# 第1154轮迭代
# 第1155轮迭代
# 第1156轮迭代
# 第1157轮迭代
# 第1158轮迭代
# 第1159轮迭代
# 第1160轮迭代
# 第1161轮迭代
# 第1162轮迭代
# 第1163轮迭代
# 第1164轮迭代
# 第1165轮迭代
# 第1166轮迭代
# 第1167轮迭代
# 第1168轮迭代
# 第1169轮迭代
# 第1170轮迭代
# 第1171轮迭代
# 第1172轮迭代
# 第1173轮迭代
# 第1174轮迭代
# 第1175轮迭代
# 第1176轮迭代
# 第1177轮迭代
# 第1178轮迭代
# 第1179轮迭代
# 第1180轮迭代
# 第1181轮迭代
# 第1182轮迭代
# 第1183轮迭代
# 第1184轮迭代
# 第1185轮迭代
# 第1186轮迭代
# 第1187轮迭代
# 第1188轮迭代
# 第1189轮迭代
# 第1190轮迭代
# 第1191轮迭代
# 第1192轮迭代
# 第1193轮迭代
# 第1194轮迭代
# 第1195轮迭代
# 第1196轮迭代
# 第1197轮迭代
# 第1198轮迭代
# 第1199轮迭代
# 第1200轮迭代
# 第1201轮迭代
# 第1202轮迭代
# 第1203轮迭代
# 第1204轮迭代
# 第1205轮迭代
# 第1206轮迭代
# 第1207轮迭代
# 第1208轮迭代
# 第1209轮迭代
# 第1210轮迭代
# 第1211轮迭代
# 第1212轮迭代
# 第1213轮迭代
# 第1214轮迭代
# 第1215轮迭代
# 第1216轮迭代
# 第1217轮迭代
# 第1218轮迭代
# 第1219轮迭代
# 第1220轮迭代
# 第1221轮迭代
# 第1222轮迭代
# 第1223轮迭代
# 第1224轮迭代
# 第1225轮迭代
# 第1226轮迭代
# 第1227轮迭代
# 第1228轮迭代
# 第1229轮迭代
# 第1230轮迭代
# 第1231轮迭代
# 第1232轮迭代
# 第1233轮迭代
# 第1234轮迭代
# 第1235轮迭代
# 第1236轮迭代
# 第1237轮迭代
# 第1238轮迭代
# 第1239轮迭代
# 第1240轮迭代
# 第1241轮迭代
# 第1242轮迭代
# 第1243轮迭代
# 第1244轮迭代
# 第1245轮迭代
# 第1246轮迭代
# 第1247轮迭代
# 第1248轮迭代
# 第1249轮迭代
# 第1250轮迭代
# 第1251轮迭代
# 第1252轮迭代
# 第1253轮迭代
# 第1254轮迭代
# 第1255轮迭代
# 第1256轮迭代
# 第1257轮迭代
# 第1258轮迭代
# 第1259轮迭代
# 第1260轮迭代
# 第1261轮迭代
# 第1262轮迭代
# 第1263轮迭代
# 第1264轮迭代
# 第1265轮迭代
# 第1266轮迭代
# 第1267轮迭代
# 第1268轮迭代
# 第1269轮迭代
# 第1270轮迭代
# 第1271轮迭代
# 第1272轮迭代
# 第1273轮迭代
# 第1274轮迭代
# 第1275轮迭代
# 第1276轮迭代
# 第1277轮迭代
# 第1278轮迭代
# 第1279轮迭代
# 第1280轮迭代
# 第1281轮迭代
# 第1282轮迭代
# 第1283轮迭代
# 第1284轮迭代
# 第1285轮迭代
# 第1286轮迭代
# 第1287轮迭代
# 第1288轮迭代
# 第1289轮迭代
# 第1290轮迭代
# 第1291轮迭代
# 第1292轮迭代
# 第1293轮迭代
# 第1294轮迭代
# 第1295轮迭代
# 第1296轮迭代
# 第1297轮迭代
# 第1298轮迭代
# 第1299轮迭代
# 第1300轮迭代
# 第1301轮迭代
# 第1302轮迭代
# 第1303轮迭代
# 第1304轮迭代
# 第1305轮迭代
# 第1306轮迭代
# 第1307轮迭代
# 第1308轮迭代
# 第1309轮迭代
# 第1310轮迭代
# 第1311轮迭代
# 第1312轮迭代
# 第1313轮迭代
# 第1314轮迭代
# 第1315轮迭代
# 第1316轮迭代
# 第1317轮迭代
# 第1318轮迭代
# 第1319轮迭代
# 第1320轮迭代
# 第1321轮迭代
# 第1322轮迭代
# 第1323轮迭代
# 第1324轮迭代
# 第1325轮迭代
# 第1326轮迭代
# 第1327轮迭代
# 第1328轮迭代
# 第1329轮迭代
# 第1330轮迭代
# 第1331轮迭代
# 第1332轮迭代
# 第1333轮迭代
# 第1334轮迭代
# 第1335轮迭代
# 第1336轮迭代
# 第1337轮迭代
# 第1338轮迭代
# 第1339轮迭代
# 第1340轮迭代
# 第1341轮迭代
# 第1342轮迭代
# 第1343轮迭代
# 第1344轮迭代
# 第1345轮迭代
# 第1346轮迭代
# 第1347轮迭代
# 第1348轮迭代
# 第1349轮迭代
# 第1350轮迭代
# 第1351轮迭代
# 第1352轮迭代
# 第1353轮迭代
# 第1354轮迭代
# 第1355轮迭代
# 第1356轮迭代
# 第1357轮迭代
# 第1358轮迭代
# 第1359轮迭代
# 第1360轮迭代
# 第1361轮迭代
# 第1362轮迭代
# 第1363轮迭代
# 第1364轮迭代
# 第1365轮迭代
# 第1366轮迭代
# 第1367轮迭代
# 第1368轮迭代
# 第1369轮迭代
# 第1370轮迭代
# 第1371轮迭代
# 第1372轮迭代
# 第1373轮迭代
# 第1374轮迭代
# 第1375轮迭代
# 第1376轮迭代
# 第1377轮迭代
# 第1378轮迭代
# 第1379轮迭代
# 第1380轮迭代
# 第1381轮迭代
# 第1382轮迭代
# 第1383轮迭代
# 第1384轮迭代
# 第1385轮迭代
# 第1386轮迭代
# 第1387轮迭代
# 第1388轮迭代
# 第1389轮迭代
# 第1390轮迭代
# 第1391轮迭代
# 第1392轮迭代
# 第1393轮迭代
# 第1394轮迭代
# 第1395轮迭代
# 第1396轮迭代
# 第1397轮迭代
# 第1398轮迭代
# 第1399轮迭代
# 第1400轮迭代
# 第1401轮迭代
# 第1402轮迭代
# 第1403轮迭代
# 第1404轮迭代
# 第1405轮迭代
# 第1406轮迭代
# 第1407轮迭代
# 第1408轮迭代
# 第1409轮迭代
# 第1410轮迭代
# 第1411轮迭代
# 第1412轮迭代
# 第1413轮迭代
# 第1414轮迭代
# 第1415轮迭代
# 第1416轮迭代
# 第1417轮迭代
# 第1418轮迭代
# 第1419轮迭代
# 第1420轮迭代
# 第1421轮迭代
# 第1422轮迭代
# 第1423轮迭代
# 第1424轮迭代
# 第1425轮迭代
# 第1426轮迭代
# 第1427轮迭代
# 第1428轮迭代
# 第1429轮迭代
# 第1430轮迭代
# 第1431轮迭代
# 第1432轮迭代
# 第1433轮迭代
# 第1434轮迭代
# 第1435轮迭代
# 第1436轮迭代
# 第1437轮迭代
# 第1438轮迭代
# 第1439轮迭代
# 第1440轮迭代
# 第1441轮迭代
# 第1442轮迭代
# 第1443轮迭代
# 第1444轮迭代
# 第1445轮迭代
# 第1446轮迭代
# 第1447轮迭代
# 第1448轮迭代
# 第1449轮迭代
# 第1450轮迭代
# 第1451轮迭代
# 第1452轮迭代
# 第1453轮迭代
# 第1454轮迭代
# 第1455轮迭代
# 第1456轮迭代
# 第1457轮迭代
# 第1458轮迭代
# 第1459轮迭代
# 第1460轮迭代
# 第1461轮迭代
# 第1462轮迭代
# 第1463轮迭代
# 第1464轮迭代
# 第1465轮迭代
# 第1466轮迭代
# 第1467轮迭代
# 第1468轮迭代
# 第1469轮迭代
# 第1470轮迭代
# 第1471轮迭代
# 第1472轮迭代
# 第1473轮迭代
# 第1474轮迭代
# 第1475轮迭代
# 第1476轮迭代
# 第1477轮迭代
# 第1478轮迭代
# 第1479轮迭代
# 第1480轮迭代
# 第1481轮迭代
# 第1482轮迭代
# 第1483轮迭代
# 第1484轮迭代
# 第1485轮迭代
# 第1486轮迭代
# 第1487轮迭代
# 第1488轮迭代
# 第1489轮迭代
# 第1490轮迭代
# 第1491轮迭代
# 第1492轮迭代
# 第1493轮迭代
# 第1494轮迭代
# 第1495轮迭代
# 第1496轮迭代
# 第1497轮迭代
# 第1498轮迭代
# 第1499轮迭代
# 第1500轮迭代
# 第1501轮迭代
# 第1502轮迭代
# 第1503轮迭代
# 第1504轮迭代
# 第1505轮迭代
# 第1506轮迭代
# 第1507轮迭代
# 第1508轮迭代
# 第1509轮迭代
# 第1510轮迭代
# 第1511轮迭代
# 第1512轮迭代
# 第1513轮迭代
# 第1514轮迭代
# 第1515轮迭代
# 第1516轮迭代
# 第1517轮迭代
# 第1518轮迭代
# 第1519轮迭代
# 第1520轮迭代
# 第1521轮迭代
# 第1522轮迭代
# 第1523轮迭代
# 第1524轮迭代
# 第1525轮迭代
# 第1526轮迭代
# 第1527轮迭代
# 第1528轮迭代
# 第1529轮迭代
# 第1530轮迭代
# 第1531轮迭代
# 第1532轮迭代
# 第1533轮迭代
# 第1534轮迭代
# 第1535轮迭代
# 第1536轮迭代
# 第1537轮迭代
# 第1538轮迭代
# 第1539轮迭代
# 第1540轮迭代
# 第1541轮迭代
# 第1542轮迭代
# 第1543轮迭代
# 第1544轮迭代
# 第1545轮迭代
# 第1546轮迭代
# 第1547轮迭代
# 第1548轮迭代
# 第1549轮迭代
# 第1550轮迭代
# 第1551轮迭代
# 第1552轮迭代
# 第1553轮迭代
# 第1554轮迭代
# 第1555轮迭代
# 第1556轮迭代
# 第1557轮迭代
# 第1558轮迭代
# 第1559轮迭代
# 第1560轮迭代
# 第1561轮迭代
# 第1562轮迭代
# 第1563轮迭代
# 第1564轮迭代
# 第1565轮迭代
# 第1566轮迭代
# 第1567轮迭代
# 第1568轮迭代
# 第1569轮迭代
# 第1570轮迭代
# 第1571轮迭代
# 第1572轮迭代
# 第1573轮迭代
# 第1574轮迭代
# 第1575轮迭代
# 第1576轮迭代
# 第1577轮迭代
# 第1578轮迭代
# 第1579轮迭代
# 第1580轮迭代
# 第1581轮迭代
# 第1582轮迭代
# 第1583轮迭代
# 第1584轮迭代
# 第1585轮迭代
# 第1586轮迭代
# 第1587轮迭代
# 第1588轮迭代
# 第1589轮迭代
# 第1590轮迭代
# 第1591轮迭代
# 第1592轮迭代
# 第1593轮迭代
# 第1594轮迭代
# 第1595轮迭代
# 第1596轮迭代
# 第1597轮迭代
# 第1598轮迭代
# 第1599轮迭代
# 第1600轮迭代
# 第1601轮迭代
# 第1602轮迭代
# 第1603轮迭代
# 第1604轮迭代
# 第1605轮迭代
# 第1606轮迭代
# 第1607轮迭代
# 第1608轮迭代
# 第1609轮迭代
# 第1610轮迭代
# 第1611轮迭代
# 第1612轮迭代
# 第1613轮迭代
# 第1614轮迭代
# 第1615轮迭代
# 第1616轮迭代
# 第1617轮迭代
# 第1618轮迭代
# 第1619轮迭代
# 第1620轮迭代
# 第1621轮迭代
# 第1622轮迭代
# 第1623轮迭代
# 第1624轮迭代
# 第1625轮迭代
# 第1626轮迭代
# 第1627轮迭代
# 第1628轮迭代
# 第1629轮迭代
# 第1630轮迭代
# 第1631轮迭代
# 第1632轮迭代
# 第1633轮迭代
# 第1634轮迭代
# 第1635轮迭代
# 第1636轮迭代
# 第1637轮迭代
# 第1638轮迭代
# 第1639轮迭代
# 第1640轮迭代
# 第1641轮迭代
# 第1642轮迭代
# 第1643轮迭代
# 第1644轮迭代
# 第1645轮迭代
# 第1646轮迭代
# 第1647轮迭代
# 第1648轮迭代
# 第1649轮迭代
# 第1650轮迭代
# 第1651轮迭代
# 第1652轮迭代
# 第1653轮迭代
# 第1654轮迭代
# 第1655轮迭代
# 第1656轮迭代
# 第1657轮迭代
# 第1658轮迭代
# 第1659轮迭代
# 第1660轮迭代
# 第1661轮迭代
# 第1662轮迭代
# 第1663轮迭代
# 第1664轮迭代
# 第1665轮迭代
# 第1666轮迭代
# 第1667轮迭代
# 第1668轮迭代
# 第1669轮迭代
# 第1670轮迭代
# 第1671轮迭代
# 第1672轮迭代
# 第1673轮迭代
# 第1674轮迭代
# 第1675轮迭代
# 第1676轮迭代
# 第1677轮迭代
# 第1678轮迭代
# 第1679轮迭代
# 第1680轮迭代
# 第1681轮迭代
# 第1682轮迭代
# 第1683轮迭代
# 第1684轮迭代
# 第1685轮迭代
# 第1686轮迭代
# 第1687轮迭代
# 第1688轮迭代
# 第1689轮迭代
# 第1690轮迭代
# 第1691轮迭代
# 第1692轮迭代
# 第1693轮迭代
# 第1694轮迭代
# 第1695轮迭代
# 第1696轮迭代
# 第1697轮迭代
# 第1698轮迭代
# 第1699轮迭代
# 第1700轮迭代
# 第1701轮迭代
# 第1702轮迭代
# 第1703轮迭代
# 第1704轮迭代
# 第1705轮迭代
# 第1706轮迭代
# 第1707轮迭代
# 第1708轮迭代
# 第1709轮迭代
# 第1710轮迭代
# 第1711轮迭代
# 第1712轮迭代
# 第1713轮迭代
# 第1714轮迭代
# 第1715轮迭代
# 第1716轮迭代
# 第1717轮迭代
# 第1718轮迭代
# 第1719轮迭代
# 第1720轮迭代
# 第1721轮迭代
# 第1722轮迭代
# 第1723轮迭代
# 第1724轮迭代
# 第1725轮迭代
# 第1726轮迭代
# 第1727轮迭代
# 第1728轮迭代
# 第1729轮迭代
# 第1730轮迭代
# 第1731轮迭代
# 第1732轮迭代
# 第1733轮迭代
# 第1734轮迭代
# 第1735轮迭代
# 第1736轮迭代
# 第1737轮迭代
# 第1738轮迭代
# 第1739轮迭代
# 第1740轮迭代
# 第1741轮迭代
# 第1742轮迭代
# 第1743轮迭代
# 第1744轮迭代
# 第1745轮迭代
# 第1746轮迭代
# 第1747轮迭代
# 第1748轮迭代
# 第1749轮迭代
# 第1750轮迭代
# 第1751轮迭代
# 第1752轮迭代
# 第1753轮迭代
# 第1754轮迭代
# 第1755轮迭代
# 第1756轮迭代
# 第1757轮迭代
# 第1758轮迭代
# 第1759轮迭代
# 第1760轮迭代
# 第1761轮迭代
# 第1762轮迭代
# 第1763轮迭代
# 第1764轮迭代
# 第1765轮迭代
# 第1766轮迭代
# 第1767轮迭代
# 第1768轮迭代
# 第1769轮迭代
# 第1770轮迭代
# 第1771轮迭代
# 第1772轮迭代
# 第1773轮迭代
# 第1774轮迭代
# 第1775轮迭代
# 第1776轮迭代
# 第1777轮迭代
# 第1778轮迭代
# 第1779轮迭代
# 第1780轮迭代
# 第1781轮迭代
# 第1782轮迭代
# 第1783轮迭代
# 第1784轮迭代
# 第1785轮迭代
# 第1786轮迭代
# 第1787轮迭代
# 第1788轮迭代
# 第1789轮迭代
# 第1790轮迭代
# 第1791轮迭代
# 第1792轮迭代
# 第1793轮迭代
# 第1794轮迭代
# 第1795轮迭代
# 第1796轮迭代
# 第1797轮迭代
# 第1798轮迭代
# 第1799轮迭代
# 第1800轮迭代
# 第1801轮迭代
# 第1802轮迭代
# 第1803轮迭代
# 第1804轮迭代
# 第1805轮迭代
# 第1806轮迭代
# 第1807轮迭代
# 第1808轮迭代
# 第1809轮迭代
# 第1810轮迭代
# 第1811轮迭代
# 第1812轮迭代
# 第1813轮迭代
# 第1814轮迭代
# 第1815轮迭代
# 第1816轮迭代
# 第1817轮迭代
# 第1818轮迭代
# 第1819轮迭代
# 第1820轮迭代
# 第1821轮迭代
# 第1822轮迭代
# 第1823轮迭代
# 第1824轮迭代
# 第1825轮迭代
# 第1826轮迭代
# 第1827轮迭代
# 第1828轮迭代
# 第1829轮迭代
# 第1830轮迭代
# 第1831轮迭代
# 第1832轮迭代
# 第1833轮迭代
# 第1834轮迭代
# 第1835轮迭代
# 第1836轮迭代
# 第1837轮迭代
# 第1838轮迭代
# 第1839轮迭代
# 第1840轮迭代
# 第1841轮迭代
# 第1842轮迭代
# 第1843轮迭代
# 第1844轮迭代
# 第1845轮迭代
# 第1846轮迭代
# 第1847轮迭代
# 第1848轮迭代
# 第1849轮迭代
# 第1850轮迭代
# 第1851轮迭代
# 第1852轮迭代
# 第1853轮迭代
# 第1854轮迭代
# 第1855轮迭代
# 第1856轮迭代
# 第1857轮迭代
# 第1858轮迭代
# 第1859轮迭代
# 第1860轮迭代
# 第1861轮迭代
# 第1862轮迭代
# 第1863轮迭代
# 第1864轮迭代
# 第1865轮迭代
# 第1866轮迭代
# 第1867轮迭代
# 第1868轮迭代
# 第1869轮迭代
# 第1870轮迭代
# 第1871轮迭代
# 第1872轮迭代
# 第1873轮迭代
# 第1874轮迭代
# 第1875轮迭代
# 第1876轮迭代
# 第1877轮迭代
# 第1878轮迭代
# 第1879轮迭代
# 第1880轮迭代
# 第1881轮迭代
# 第1882轮迭代
# 第1883轮迭代
# 第1884轮迭代
# 第1885轮迭代
# 第1886轮迭代
# 第1887轮迭代
# 第1888轮迭代
# 第1889轮迭代
# 第1890轮迭代
# 第1891轮迭代
# 第1892轮迭代
# 第1893轮迭代
# 第1894轮迭代
# 第1895轮迭代
# 第1896轮迭代
# 第1897轮迭代
# 第1898轮迭代
# 第1899轮迭代
# 第1900轮迭代
# 第1901轮迭代
# 第1902轮迭代
# 第1903轮迭代
# 第1904轮迭代
# 第1905轮迭代
# 第1906轮迭代
# 第1907轮迭代
# 第1908轮迭代
# 第1909轮迭代
# 第1910轮迭代
# 第1911轮迭代
# 第1912轮迭代
# 第1913轮迭代
# 第1914轮迭代
# 第1915轮迭代
# 第1916轮迭代
# 第1917轮迭代
# 第1918轮迭代
# 第1919轮迭代
# 第1920轮迭代
# 第1921轮迭代
# 第1922轮迭代
# 第1923轮迭代
# 第1924轮迭代
# 第1925轮迭代
# 第1926轮迭代
# 第1927轮迭代
# 第1928轮迭代
# 第1929轮迭代
# 第1930轮迭代
# 第1931轮迭代
# 第1932轮迭代
# 第1933轮迭代
# 第1934轮迭代
# 第1935轮迭代
# 第1936轮迭代
# 第1937轮迭代
# 第1938轮迭代
# 第1939轮迭代
# 第1940轮迭代
# 第1941轮迭代
# 第1942轮迭代
# 第1943轮迭代
# 第1944轮迭代
# 第1945轮迭代
# 第1946轮迭代
# 第1947轮迭代
# 第1948轮迭代
# 第1949轮迭代
# 第1950轮迭代
# 第1951轮迭代
# 第1952轮迭代
# 第1953轮迭代
# 第1954轮迭代
# 第1955轮迭代
# 第1956轮迭代
# 第1957轮迭代
# 第1958轮迭代
# 第1959轮迭代
# 第1960轮迭代
# 第1961轮迭代
# 第1962轮迭代
# 第1963轮迭代
# 第1964轮迭代
# 第1965轮迭代
# 第1966轮迭代
# 第1967轮迭代
# 第1968轮迭代
# 第1969轮迭代
# 第1970轮迭代
# 第1971轮迭代
# 第1972轮迭代
# 第1973轮迭代
# 第1974轮迭代
# 第1975轮迭代
# 第1976轮迭代
# 第1977轮迭代
# 第1978轮迭代
# 第1979轮迭代
# 第1980轮迭代
# 第1981轮迭代
# 第1982轮迭代
# 第1983轮迭代
# 第1984轮迭代
# 第1985轮迭代
# 第1986轮迭代
# 第1987轮迭代
# 第1988轮迭代
# 第1989轮迭代
# 第1990轮迭代
# 第1991轮迭代
# 第1992轮迭代
# 第1993轮迭代
# 第1994轮迭代
# 第1995轮迭代
# 第1996轮迭代
# 第1997轮迭代
# 第1998轮迭代
# 第1999轮迭代
# 第2000轮迭代
# 第2001轮迭代
# 第2002轮迭代
# 第2003轮迭代
# 第2004轮迭代
# 第2005轮迭代
# 第2006轮迭代
# 第2007轮迭代
# 第2008轮迭代
# 第2009轮迭代
# 第2010轮迭代
# 第2011轮迭代
# 第2012轮迭代
# 第2013轮迭代
# 第2014轮迭代
# 第2015轮迭代
# 第2016轮迭代
# 第2017轮迭代
# 第2018轮迭代
# 第2019轮迭代
# 第2020轮迭代
# 第2021轮迭代
# 第2022轮迭代
# 第2023轮迭代
# 第2024轮迭代
# 第2025轮迭代
# 第2026轮迭代
# 第2027轮迭代
# 第2028轮迭代
# 第2029轮迭代
# 第2030轮迭代
# 第2031轮迭代
# 第2032轮迭代
# 第2033轮迭代
# 第2034轮迭代
# 第2035轮迭代
# 第2036轮迭代
# 第2037轮迭代
# 第2038轮迭代
# 第2039轮迭代
# 第2040轮迭代
# 第2041轮迭代
# 第2042轮迭代
# 第2043轮迭代
# 第2044轮迭代
# 第2045轮迭代
# 第2046轮迭代
# 第2047轮迭代
# 第2048轮迭代
# 第2049轮迭代
# 第2050轮迭代
# 第2051轮迭代
# 第2052轮迭代
# 第2053轮迭代
# 第2054轮迭代
# 第2055轮迭代
# 第2056轮迭代
# 第2057轮迭代
# 第2058轮迭代
# 第2059轮迭代
# 第2060轮迭代
# 第2061轮迭代
# 第2062轮迭代
# 第2063轮迭代
# 第2064轮迭代
# 第2065轮迭代
# 第2066轮迭代
# 第2067轮迭代
# 第2068轮迭代
# 第2069轮迭代
# 第2070轮迭代
# 第2071轮迭代
# 第2072轮迭代
# 第2073轮迭代
# 第2074轮迭代
# 第2075轮迭代
# 第2076轮迭代
# 第2077轮迭代
# 第2078轮迭代
# 第2079轮迭代
# 第2080轮迭代
# 第2081轮迭代
# 第2082轮迭代
# 第2083轮迭代
# 第2084轮迭代
# 第2085轮迭代
# 第2086轮迭代
# 第2087轮迭代
# 第2088轮迭代
# 第2089轮迭代
# 第2090轮迭代
# 第2091轮迭代
# 第2092轮迭代
# 第2093轮迭代
# 第2094轮迭代
# 第2095轮迭代
# 第2096轮迭代
# 第2097轮迭代
# 第2098轮迭代
# 第2099轮迭代
# 第2100轮迭代
# 第2101轮迭代
# 第2102轮迭代
# 第2103轮迭代
# 第2104轮迭代
# 第2105轮迭代
# 第2106轮迭代
# 第2107轮迭代
# 第2108轮迭代
# 第2109轮迭代
# 第2110轮迭代
# 第2111轮迭代
# 第2112轮迭代
# 第2113轮迭代
# 第2114轮迭代
# 第2115轮迭代
# 第2116轮迭代
# 第2117轮迭代
# 第2118轮迭代
# 第2119轮迭代
# 第2120轮迭代
# 第2121轮迭代
# 第2122轮迭代
# 第2123轮迭代
# 第2124轮迭代
# 第2125轮迭代
# 第2126轮迭代
# 第2127轮迭代
# 第2128轮迭代
# 第2129轮迭代
# 第2130轮迭代
# 第2131轮迭代
# 第2132轮迭代
# 第2133轮迭代
# 第2134轮迭代
# 第2135轮迭代
# 第2136轮迭代
# 第2137轮迭代
# 第2138轮迭代
# 第2139轮迭代
# 第2140轮迭代
# 第2141轮迭代
# 第2142轮迭代
# 第2143轮迭代
# 第2144轮迭代
# 第2145轮迭代
# 第2146轮迭代
# 第2147轮迭代
# 第2148轮迭代
# 第2149轮迭代
# 第2150轮迭代
# 第2151轮迭代
# 第2152轮迭代
# 第2153轮迭代
# 第2154轮迭代
# 第2155轮迭代
# 第2156轮迭代
# 第2157轮迭代
# 第2158轮迭代
# 第2159轮迭代
# 第2160轮迭代
# 第2161轮迭代
# 第2162轮迭代
# 第2163轮迭代
# 第2164轮迭代
# 第2165轮迭代
# 第2166轮迭代
# 第2167轮迭代
# 第2168轮迭代
# 第2169轮迭代
# 第2170轮迭代
# 第2171轮迭代
# 第2172轮迭代
# 第2173轮迭代
# 第2174轮迭代
# 第2175轮迭代
# 第2176轮迭代
# 第2177轮迭代
# 第2178轮迭代
# 第2179轮迭代
# 第2180轮迭代
# 第2181轮迭代
# 第2182轮迭代
# 第2183轮迭代
# 第2184轮迭代
# 第2185轮迭代
# 第2186轮迭代
# 第2187轮迭代
# 第2188轮迭代
# 第2189轮迭代
# 第2190轮迭代
# 第2191轮迭代
# 第2192轮迭代
# 第2193轮迭代
# 第2194轮迭代
# 第2195轮迭代
# 第2196轮迭代
# 第2197轮迭代
# 第2198轮迭代
# 第2199轮迭代
# 第2200轮迭代
# 第2201轮迭代
# 第2202轮迭代
# 第2203轮迭代
# 第2204轮迭代
# 第2205轮迭代
# 第2206轮迭代
# 第2207轮迭代
# 第2208轮迭代
# 第2209轮迭代
# 第2210轮迭代
# 第2211轮迭代
# 第2212轮迭代
# 第2213轮迭代
# 第2214轮迭代
# 第2215轮迭代
# 第2216轮迭代
# 第2217轮迭代
# 第2218轮迭代
# 第2219轮迭代
# 第2220轮迭代
# 第2221轮迭代
# 第2222轮迭代
# 第2223轮迭代
# 第2224轮迭代
# 第2225轮迭代
# 第2226轮迭代
# 第2227轮迭代
# 第2228轮迭代
# 第2229轮迭代
# 第2230轮迭代
# 第2231轮迭代
# 第2232轮迭代
# 第2233轮迭代
# 第2234轮迭代
# 第2235轮迭代
# 第2236轮迭代
# 第2237轮迭代
# 第2238轮迭代
# 第2239轮迭代
# 第2240轮迭代
# 第2241轮迭代
# 第2242轮迭代
# 第2243轮迭代
# 第2244轮迭代
# 第2245轮迭代
# 第2246轮迭代
# 第2247轮迭代
# 第2248轮迭代
# 第2249轮迭代
# 第2250轮迭代
# 第2251轮迭代
# 第2252轮迭代
# 第2253轮迭代
# 第2254轮迭代
# 第2255轮迭代
# 第2256轮迭代
# 第2257轮迭代
# 第2258轮迭代
# 第2259轮迭代
# 第2260轮迭代
# 第2261轮迭代
# 第2262轮迭代
# 第2263轮迭代
# 第2264轮迭代
# 第2265轮迭代
# 第2266轮迭代
# 第2267轮迭代
# 第2268轮迭代
# 第2269轮迭代
# 第2270轮迭代
# 第2271轮迭代
# 第2272轮迭代
# 第2273轮迭代
# 第2274轮迭代
# 第2275轮迭代
# 第2276轮迭代
# 第2277轮迭代
# 第2278轮迭代
# 第2279轮迭代
# 第2280轮迭代
# 第2281轮迭代
# 第2282轮迭代
# 第2283轮迭代
# 第2284轮迭代
# 第2285轮迭代
# 第2286轮迭代
# 第2287轮迭代
# 第2288轮迭代
# 第2289轮迭代
# 第2290轮迭代
# 第2291轮迭代
# 第2292轮迭代
# 第2293轮迭代
# 第2294轮迭代
# 第2295轮迭代
# 第2296轮迭代
# 第2297轮迭代
# 第2298轮迭代
# 第2299轮迭代
# 第2300轮迭代
# 第2301轮迭代
# 第2302轮迭代
# 第2303轮迭代
# 第2304轮迭代
# 第2305轮迭代
# 第2306轮迭代
# 第2307轮迭代
# 第2308轮迭代
# 第2309轮迭代
# 第2310轮迭代
# 第2311轮迭代
# 第2312轮迭代
# 第2313轮迭代
# 第2314轮迭代
# 第2315轮迭代
# 第2316轮迭代
# 第2317轮迭代
# 第2318轮迭代
# 第2319轮迭代
# 第2320轮迭代
# 第2321轮迭代
# 第2322轮迭代
# 第2323轮迭代
# 第2324轮迭代
# 第2325轮迭代
# 第2326轮迭代
# 第2327轮迭代
# 第2328轮迭代
# 第2329轮迭代
# 第2330轮迭代
# 第2331轮迭代
# 第2332轮迭代
# 第2333轮迭代
# 第2334轮迭代
# 第2335轮迭代
# 第2336轮迭代
# 第2337轮迭代
# 第2338轮迭代
# 第2339轮迭代
# 第2340轮迭代
# 第2341轮迭代
# 第2342轮迭代
# 第2343轮迭代
# 第2344轮迭代
# 第2345轮迭代
# 第2346轮迭代
# 第2347轮迭代
# 第2348轮迭代
# 第2349轮迭代
# 第2350轮迭代
# 第2351轮迭代
# 第2352轮迭代
# 第2353轮迭代
# 第2354轮迭代
# 第2355轮迭代
# 第2356轮迭代
# 第2357轮迭代
# 第2358轮迭代
# 第2359轮迭代
# 第2360轮迭代
# 第2361轮迭代
# 第2362轮迭代
# 第2363轮迭代
# 第2364轮迭代
# 第2365轮迭代
# 第2366轮迭代
# 第2367轮迭代
# 第2368轮迭代
# 第2369轮迭代
# 第2370轮迭代
# 第2371轮迭代
# 第2372轮迭代
# 第2373轮迭代
# 第2374轮迭代
# 第2375轮迭代
# 第2376轮迭代
# 第2377轮迭代
# 第2378轮迭代
# 第2379轮迭代
# 第2380轮迭代
# 第2381轮迭代
# 第2382轮迭代
# 第2383轮迭代
# 第2384轮迭代
# 第2385轮迭代
# 第2386轮迭代
# 第2387轮迭代
# 第2388轮迭代
# 第2389轮迭代
# 第2390轮迭代
# 第2391轮迭代
# 第2392轮迭代
# 第2393轮迭代
# 第2394轮迭代
# 第2395轮迭代
# 第2396轮迭代
# 第2397轮迭代
# 第2398轮迭代
# 第2399轮迭代
# 第2400轮迭代
# 第2401轮迭代
# 第2402轮迭代
# 第2403轮迭代
# 第2404轮迭代
# 第2405轮迭代
# 第2406轮迭代
# 第2407轮迭代
# 第2408轮迭代
# 第2409轮迭代
# 第2410轮迭代
# 第2411轮迭代
# 第2412轮迭代
# 第2413轮迭代
# 第2414轮迭代
# 第2415轮迭代
# 第2416轮迭代
# 第2417轮迭代
# 第2418轮迭代
# 第2419轮迭代
# 第2420轮迭代
# 第2421轮迭代
# 第2422轮迭代
# 第2423轮迭代
# 第2424轮迭代
# 第2425轮迭代
# 第2426轮迭代
# 第2427轮迭代
# 第2428轮迭代
# 第2429轮迭代
# 第2430轮迭代
# 第2431轮迭代
# 第2432轮迭代
# 第2433轮迭代
# 第2434轮迭代
# 第2435轮迭代
# 第2436轮迭代
# 第2437轮迭代
# 第2438轮迭代
# 第2439轮迭代
# 第2440轮迭代
# 第2441轮迭代
# 第2442轮迭代
# 第2443轮迭代
# 第2444轮迭代
# 第2445轮迭代
# 第2446轮迭代
# 第2447轮迭代
# 第2448轮迭代
# 第2449轮迭代
# 第2450轮迭代
# 第2451轮迭代
# 第2452轮迭代
# 第2453轮迭代
# 第2454轮迭代
# 第2455轮迭代
# 第2456轮迭代
# 第2457轮迭代
# 第2458轮迭代
# 第2459轮迭代
# 第2460轮迭代
# 第2461轮迭代
# 第2462轮迭代
# 第2463轮迭代
# 第2464轮迭代
# 第2465轮迭代
# 第2466轮迭代
# 第2467轮迭代
# 第2468轮迭代
# 第2469轮迭代
# 第2470轮迭代
# 第2471轮迭代
# 第2472轮迭代
# 第2473轮迭代
# 第2474轮迭代
# 第2475轮迭代
# 第2476轮迭代
# 第2477轮迭代
# 第2478轮迭代
# 第2479轮迭代
# 第2480轮迭代
# 第2481轮迭代
# 第2482轮迭代
# 第2483轮迭代
# 第2484轮迭代
# 第2485轮迭代
# 第2486轮迭代
# 第2487轮迭代
# 第2488轮迭代
# 第2489轮迭代
# 第2490轮迭代
# 第2491轮迭代
# 第2492轮迭代
# 第2493轮迭代
# 第2494轮迭代
# 第2495轮迭代
# 第2496轮迭代
# 第2497轮迭代
# 第2498轮迭代
# 第2499轮迭代
# 第2500轮迭代
# 第2501轮迭代
# 第2502轮迭代
# 第2503轮迭代
# 第2504轮迭代
# 第2505轮迭代
# 第2506轮迭代
# 第2507轮迭代
# 第2508轮迭代
# 第2509轮迭代
# 第2510轮迭代
# 第2511轮迭代
# 第2512轮迭代
# 第2513轮迭代
# 第2514轮迭代
# 第2515轮迭代
# 第2516轮迭代
# 第2517轮迭代
# 第2518轮迭代
# 第2519轮迭代
# 第2520轮迭代
# 第2521轮迭代
# 第2522轮迭代
# 第2523轮迭代
# 第2524轮迭代
# 第2525轮迭代
# 第2526轮迭代
# 第2527轮迭代
# 第2528轮迭代
# 第2529轮迭代
# 第2530轮迭代
# 第2531轮迭代
# 第2532轮迭代
# 第2533轮迭代
# 第2534轮迭代
# 第2535轮迭代
# 第2536轮迭代
# 第2537轮迭代
# 第2538轮迭代
# 第2539轮迭代
# 第2540轮迭代
# 第2541轮迭代
# 第2542轮迭代
# 第2543轮迭代
# 第2544轮迭代
# 第2545轮迭代
# 第2546轮迭代
# 第2547轮迭代
# 第2548轮迭代
# 第2549轮迭代
# 第2550轮迭代
# 第2551轮迭代
# 第2552轮迭代
# 第2553轮迭代
# 第2554轮迭代
# 第2555轮迭代
# 第2556轮迭代
# 第2557轮迭代
# 第2558轮迭代
# 第2559轮迭代
# 第2560轮迭代
# 第2561轮迭代
# 第2562轮迭代
# 第2563轮迭代
# 第2564轮迭代
# 第2565轮迭代
# 第2566轮迭代
# 第2567轮迭代
# 第2568轮迭代
# 第2569轮迭代
# 第2570轮迭代
# 第2571轮迭代
# 第2572轮迭代
# 第2573轮迭代
# 第2574轮迭代
# 第2575轮迭代
# 第2576轮迭代
# 第2577轮迭代
# 第2578轮迭代
# 第2579轮迭代
# 第2580轮迭代
# 第2581轮迭代
# 第2582轮迭代
# 第2583轮迭代
# 第2584轮迭代
# 第2585轮迭代
# 第2586轮迭代
# 第2587轮迭代
# 第2588轮迭代
# 第2589轮迭代
# 第2590轮迭代
# 第2591轮迭代
# 第2592轮迭代
# 第2593轮迭代
# 第2594轮迭代
# 第2595轮迭代
# 第2596轮迭代
# 第2597轮迭代
# 第2598轮迭代
# 第2599轮迭代
# 第2600轮迭代
# 第2601轮迭代
# 第2602轮迭代
# 第2603轮迭代
# 第2604轮迭代
# 第2605轮迭代
# 第2606轮迭代
# 第2607轮迭代
# 第2608轮迭代
# 第2609轮迭代
# 第2610轮迭代
# 第2611轮迭代
# 第2612轮迭代
# 第2613轮迭代
# 第2614轮迭代
# 第2615轮迭代
# 第2616轮迭代
# 第2617轮迭代
# 第2618轮迭代
# 第2619轮迭代
# 第2620轮迭代
# 第2621轮迭代
# 第2622轮迭代
# 第2623轮迭代
# 第2624轮迭代
# 第2625轮迭代
# 第2626轮迭代
# 第2627轮迭代
# 第2628轮迭代
# 第2629轮迭代
# 第2630轮迭代
# 第2631轮迭代
# 第2632轮迭代
# 第2633轮迭代
# 第2634轮迭代
# 第2635轮迭代
# 第2636轮迭代
# 第2637轮迭代
# 第2638轮迭代
# 第2639轮迭代
# 第2640轮迭代
# 第2641轮迭代
# 第2642轮迭代
# 第2643轮迭代
# 第2644轮迭代
# 第2645轮迭代
# 第2646轮迭代
# 第2647轮迭代
# 第2648轮迭代
# 第2649轮迭代
# 第2650轮迭代
# 第2651轮迭代
# 第2652轮迭代
# 第2653轮迭代
# 第2654轮迭代
# 第2655轮迭代
# 第2656轮迭代
# 第2657轮迭代
# 第2658轮迭代
# 第2659轮迭代
# 第2660轮迭代
# 第2661轮迭代
# 第2662轮迭代
# 第2663轮迭代
# 第2664轮迭代
# 第2665轮迭代
# 第2666轮迭代
# 第2667轮迭代
# 第2668轮迭代
# 第2669轮迭代
# 第2670轮迭代
# 第2671轮迭代
# 第2672轮迭代
# 第2673轮迭代
# 第2674轮迭代
# 第2675轮迭代
# 第2676轮迭代
# 第2677轮迭代
# 第2678轮迭代
# 第2679轮迭代
# 第2680轮迭代
# 第2681轮迭代
# 第2682轮迭代
# 第2683轮迭代
# 第2684轮迭代
# 第2685轮迭代
# 第2686轮迭代
# 第2687轮迭代
# 第2688轮迭代
# 第2689轮迭代
# 第2690轮迭代
# 第2691轮迭代
# 第2692轮迭代
# 第2693轮迭代
# 第2694轮迭代
# 第2695轮迭代
# 第2696轮迭代
# 第2697轮迭代
# 第2698轮迭代
# 第2699轮迭代
# 第2700轮迭代
# 第2701轮迭代
# 第2702轮迭代
# 第2703轮迭代
# 第2704轮迭代
# 第2705轮迭代
# 第2706轮迭代
# 第2707轮迭代
# 第2708轮迭代
# 第2709轮迭代
# 第2710轮迭代
# 第2711轮迭代
# 第2712轮迭代
# 第2713轮迭代
# 第2714轮迭代
# 第2715轮迭代
# 第2716轮迭代
# 第2717轮迭代
# 第2718轮迭代
# 第2719轮迭代
# 第2720轮迭代
# 第2721轮迭代
# 第2722轮迭代
# 第2723轮迭代
# 第2724轮迭代
# 第2725轮迭代
# 第2726轮迭代
# 第2727轮迭代
# 第2728轮迭代
# 第2729轮迭代
# 第2730轮迭代
# 第2731轮迭代
# 第2732轮迭代
# 第2733轮迭代
# 第2734轮迭代
# 第2735轮迭代
# 第2736轮迭代
# 第2737轮迭代
# 第2738轮迭代
# 第2739轮迭代
# 第2740轮迭代
# 第2741轮迭代
# 第2742轮迭代
# 第2743轮迭代
# 第2744轮迭代
# 第2745轮迭代
# 第2746轮迭代
# 第2747轮迭代
# 第2748轮迭代
# 第2749轮迭代
# 第2750轮迭代
# 第2751轮迭代
# 第2752轮迭代
# 第2753轮迭代
# 第2754轮迭代
# 第2755轮迭代
# 第2756轮迭代
# 第2757轮迭代
# 第2758轮迭代
# 第2759轮迭代
# 第2760轮迭代
# 第2761轮迭代
# 第2762轮迭代
# 第2763轮迭代
# 第2764轮迭代
# 第2765轮迭代
# 第2766轮迭代
# 第2767轮迭代
# 第2768轮迭代
# 第2769轮迭代
# 第2770轮迭代
# 第2771轮迭代
# 第2772轮迭代
# 第2773轮迭代
# 第2774轮迭代
# 第2775轮迭代
# 第2776轮迭代
# 第2777轮迭代
# 第2778轮迭代
# 第2779轮迭代
# 第2780轮迭代
# 第2781轮迭代
# 第2782轮迭代
# 第2783轮迭代
# 第2784轮迭代
# 第2785轮迭代
# 第2786轮迭代
# 第2787轮迭代
# 第2788轮迭代
# 第2789轮迭代
# 第2790轮迭代
# 第2791轮迭代
# 第2792轮迭代
# 第2793轮迭代
# 第2794轮迭代
# 第2795轮迭代
# 第2796轮迭代
# 第2797轮迭代
# 第2798轮迭代
# 第2799轮迭代
# 第2800轮迭代
# 第2801轮迭代
# 第2802轮迭代
# 第2803轮迭代
# 第2804轮迭代
# 第2805轮迭代
# 第2806轮迭代
# 第2807轮迭代
# 第2808轮迭代
# 第2809轮迭代
# 第2810轮迭代
# 第2811轮迭代
# 第2812轮迭代
# 第2813轮迭代
# 第2814轮迭代
# 第2815轮迭代
# 第2816轮迭代
# 第2817轮迭代
# 第2818轮迭代
# 第2819轮迭代
# 第2820轮迭代
# 第2821轮迭代
# 第2822轮迭代
# 第2823轮迭代
# 第2824轮迭代
# 第2825轮迭代
# 第2826轮迭代
# 第2827轮迭代
# 第2828轮迭代
# 第2829轮迭代
# 第2830轮迭代
# 第2831轮迭代
# 第2832轮迭代
# 第2833轮迭代
# 第2834轮迭代
# 第2835轮迭代
# 第2836轮迭代
# 第2837轮迭代
# 第2838轮迭代
# 第2839轮迭代
# 第2840轮迭代
# 第2841轮迭代
# 第2842轮迭代
# 第2843轮迭代
# 第2844轮迭代
# 第2845轮迭代
# 第2846轮迭代
# 第2847轮迭代
# 第2848轮迭代
# 第2849轮迭代
# 第2850轮迭代
# 第2851轮迭代
# 第2852轮迭代
# 第2853轮迭代
# 第2854轮迭代
# 第2855轮迭代
# 第2856轮迭代
# 第2857轮迭代
# 第2858轮迭代
# 第2859轮迭代
# 第2860轮迭代
# 第2861轮迭代
# 第2862轮迭代
# 第2863轮迭代
# 第2864轮迭代
# 第2865轮迭代
# 第2866轮迭代
# 第2867轮迭代
# 第2868轮迭代
# 第2869轮迭代
# 第2870轮迭代
# 第2871轮迭代
# 第2872轮迭代
# 第2873轮迭代
# 第2874轮迭代
# 第2875轮迭代
# 第2876轮迭代
# 第2877轮迭代
# 第2878轮迭代
# 第2879轮迭代
# 第2880轮迭代
# 第2881轮迭代
# 第2882轮迭代
# 第2883轮迭代
# 第2884轮迭代
# 第2885轮迭代
# 第2886轮迭代
# 第2887轮迭代
# 第2888轮迭代
# 第2889轮迭代
# 第2890轮迭代
# 第2891轮迭代
# 第2892轮迭代
# 第2893轮迭代
# 第2894轮迭代
# 第2895轮迭代
# 第2896轮迭代
# 第2897轮迭代
# 第2898轮迭代
# 第2899轮迭代
# 第2900轮迭代
# 第2901轮迭代
# 第2902轮迭代
# 第2903轮迭代
# 第2904轮迭代
# 第2905轮迭代
# 第2906轮迭代
# 第2907轮迭代
# 第2908轮迭代
# 第2909轮迭代
# 第2910轮迭代
# 第2911轮迭代
# 第2912轮迭代
# 第2913轮迭代
# 第2914轮迭代
# 第2915轮迭代
# 第2916轮迭代
# 第2917轮迭代
# 第2918轮迭代
# 第2919轮迭代
# 第2920轮迭代
# 第2921轮迭代
# 第2922轮迭代
# 第2923轮迭代
# 第2924轮迭代
# 第2925轮迭代
# 第2926轮迭代
# 第2927轮迭代
# 第2928轮迭代
# 第2929轮迭代
# 第2930轮迭代
# 第2931轮迭代
# 第2932轮迭代
# 第2933轮迭代
# 第2934轮迭代
# 第2935轮迭代
# 第2936轮迭代
# 第2937轮迭代
# 第2938轮迭代
# 第2939轮迭代
# 第2940轮迭代
# 第2941轮迭代
# 第2942轮迭代
# 第2943轮迭代
# 第2944轮迭代
# 第2945轮迭代
# 第2946轮迭代
# 第2947轮迭代
# 第2948轮迭代
# 第2949轮迭代
# 第2950轮迭代
# 第2951轮迭代
# 第2952轮迭代
# 第2953轮迭代
# 第2954轮迭代
# 第2955轮迭代
# 第2956轮迭代
# 第2957轮迭代
# 第2958轮迭代
# 第2959轮迭代
# 第2960轮迭代
# 第2961轮迭代
# 第2962轮迭代
# 第2963轮迭代
# 第2964轮迭代
# 第2965轮迭代
# 第2966轮迭代
# 第2967轮迭代
# 第2968轮迭代
# 第2969轮迭代
# 第2970轮迭代
# 第2971轮迭代
# 第2972轮迭代
# 第2973轮迭代
# 第2974轮迭代
# 第2975轮迭代
# 第2976轮迭代
# 第2977轮迭代
# 第2978轮迭代
# 第2979轮迭代
# 第2980轮迭代
# 第2981轮迭代
# 第2982轮迭代
# 第2983轮迭代
# 第2984轮迭代
# 第2985轮迭代
# 第2986轮迭代
# 第2987轮迭代
# 第2988轮迭代
# 第2989轮迭代
# 第2990轮迭代
# 第2991轮迭代
# 第2992轮迭代
# 第2993轮迭代
# 第2994轮迭代
# 第2995轮迭代
# 第2996轮迭代
# 第2997轮迭代
# 第2998轮迭代
# 第2999轮迭代
# 第3000轮迭代
# 第3001轮迭代
# 第3002轮迭代
# 第3003轮迭代
# 第3004轮迭代
# 第3005轮迭代
# 第3006轮迭代
# 第3007轮迭代
# 第3008轮迭代
# 第3009轮迭代
# 第3010轮迭代
# 第3011轮迭代
# 第3012轮迭代
# 第3013轮迭代
# 第3014轮迭代
# 第3015轮迭代
# 第3016轮迭代
# 第3017轮迭代
# 第3018轮迭代
# 第3019轮迭代
# 第3020轮迭代
# 第3021轮迭代
# 第3022轮迭代
# 第3023轮迭代
# 第3024轮迭代
# 第3025轮迭代
# 第3026轮迭代
# 第3027轮迭代
# 第3028轮迭代
# 第3029轮迭代
# 第3030轮迭代
# 第3031轮迭代
# 第3032轮迭代
# 第3033轮迭代
# 第3034轮迭代
# 第3035轮迭代
# 第3036轮迭代
# 第3037轮迭代
# 第3038轮迭代
# 第3039轮迭代
# 第3040轮迭代
# 第3041轮迭代
# 第3042轮迭代
# 第3043轮迭代
# 第3044轮迭代
# 第3045轮迭代
# 第3046轮迭代
# 第3047轮迭代
# 第3048轮迭代
# 第3049轮迭代
# 第3050轮迭代
# 第3051轮迭代
# 第3052轮迭代
# 第3053轮迭代
# 第3054轮迭代
# 第3055轮迭代
# 第3056轮迭代
# 第3057轮迭代
# 第3058轮迭代
# 第3059轮迭代
# 第3060轮迭代
# 第3061轮迭代
# 第3062轮迭代
# 第3063轮迭代
# 第3064轮迭代
# 第3065轮迭代
# 第3066轮迭代
# 第3067轮迭代
# 第3068轮迭代
# 第3069轮迭代
# 第3070轮迭代
# 第3071轮迭代
# 第3072轮迭代
# 第3073轮迭代
# 第3074轮迭代
# 第3075轮迭代
# 第3076轮迭代
# 第3077轮迭代
# 第3078轮迭代
# 第3079轮迭代
# 第3080轮迭代
# 第3081轮迭代
# 第3082轮迭代
# 第3083轮迭代
# 第3084轮迭代
# 第3085轮迭代
# 第3086轮迭代
# 第3087轮迭代
# 第3088轮迭代
# 第3089轮迭代
# 第3090轮迭代
# 第3091轮迭代
# 第3092轮迭代
# 第3093轮迭代
# 第3094轮迭代
# 第3095轮迭代
# 第3096轮迭代
# 第3097轮迭代
# 第3098轮迭代
# 第3099轮迭代
# 第3100轮迭代
# 第3101轮迭代
# 第3102轮迭代
# 第3103轮迭代
# 第3104轮迭代
# 第3105轮迭代
# 第3106轮迭代
# 第3107轮迭代
# 第3108轮迭代
# 第3109轮迭代
# 第3110轮迭代
# 第3111轮迭代
# 第3112轮迭代
# 第3113轮迭代
# 第3114轮迭代
# 第3115轮迭代
# 第3116轮迭代
# 第3117轮迭代
# 第3118轮迭代
# 第3119轮迭代
# 第3120轮迭代
# 第3121轮迭代
# 第3122轮迭代
# 第3123轮迭代
# 第3124轮迭代
# 第3125轮迭代
# 第3126轮迭代
# 第3127轮迭代
# 第3128轮迭代
# 第3129轮迭代
# 第3130轮迭代
# 第3131轮迭代
# 第3132轮迭代
# 第3133轮迭代
# 第3134轮迭代
# 第3135轮迭代
# 第3136轮迭代
# 第3137轮迭代
# 第3138轮迭代
# 第3139轮迭代
# 第3140轮迭代
# 第3141轮迭代
# 第3142轮迭代
# 第3143轮迭代
# 第3144轮迭代
# 第3145轮迭代
# 第3146轮迭代
# 第3147轮迭代
# 第3148轮迭代
# 第3149轮迭代
# 第3150轮迭代
# 第3151轮迭代
# 第3152轮迭代
# 第3153轮迭代
# 第3154轮迭代
# 第3155轮迭代
# 第3156轮迭代
# 第3157轮迭代
# 第3158轮迭代
# 第3159轮迭代
# 第3160轮迭代
# 第3161轮迭代
# 第3162轮迭代
# 第3163轮迭代
# 第3164轮迭代
# 第3165轮迭代
# 第3166轮迭代
# 第3167轮迭代
# 第3168轮迭代
# 第3169轮迭代
# 第3170轮迭代
# 第3171轮迭代
# 第3172轮迭代
# 第3173轮迭代
# 第3174轮迭代
# 第3175轮迭代
# 第3176轮迭代
# 第3177轮迭代
# 第3178轮迭代
# 第3179轮迭代
# 第3180轮迭代
# 第3181轮迭代
# 第3182轮迭代
# 第3183轮迭代
# 第3184轮迭代
# 第3185轮迭代
# 第3186轮迭代
# 第3187轮迭代
# 第3188轮迭代
# 第3189轮迭代
# 第3190轮迭代
# 第3191轮迭代
# 第3192轮迭代
# 第3193轮迭代
# 第3194轮迭代
# 第3195轮迭代
# 第3196轮迭代
# 第3197轮迭代
# 第3198轮迭代
# 第3199轮迭代
# 第3200轮迭代
# 第3201轮迭代
# 第3202轮迭代
# 第3203轮迭代
# 第3204轮迭代
# 第3205轮迭代
# 第3206轮迭代
# 第3207轮迭代
# 第3208轮迭代
# 第3209轮迭代
# 第3210轮迭代
# 第3211轮迭代
# 第3212轮迭代
# 第3213轮迭代
# 第3214轮迭代
# 第3215轮迭代
# 第3216轮迭代
# 第3217轮迭代
# 第3218轮迭代
# 第3219轮迭代
# 第3220轮迭代
# 第3221轮迭代
# 第3222轮迭代
# 第3223轮迭代
# 第3224轮迭代
# 第3225轮迭代
# 第3226轮迭代
# 第3227轮迭代
# 第3228轮迭代
# 第3229轮迭代
# 第3230轮迭代
# 第3231轮迭代
# 第3232轮迭代
# 第3233轮迭代
# 第3234轮迭代
# 第3235轮迭代
# 第3236轮迭代
# 第3237轮迭代
# 第3238轮迭代
# 第3239轮迭代
# 第3240轮迭代
# 第3241轮迭代
# 第3242轮迭代
# 第3243轮迭代
# 第3244轮迭代
# 第3245轮迭代
# 第3246轮迭代
# 第3247轮迭代
# 第3248轮迭代
# 第3249轮迭代
# 第3250轮迭代
# 第3251轮迭代
# 第3252轮迭代
# 第3253轮迭代
# 第3254轮迭代
# 第3255轮迭代
# 第3256轮迭代
# 第3257轮迭代
# 第3258轮迭代
# 第3259轮迭代
# 第3260轮迭代
# 第3261轮迭代
# 第3262轮迭代
# 第3263轮迭代
# 第3264轮迭代
# 第3265轮迭代
# 第3266轮迭代
# 第3267轮迭代
# 第3268轮迭代
# 第3269轮迭代
# 第3270轮迭代
# 第3271轮迭代
# 第3272轮迭代
# 第3273轮迭代
# 第3274轮迭代
# 第3275轮迭代
# 第3276轮迭代
# 第3277轮迭代
# 第3278轮迭代
# 第3279轮迭代
# 第3280轮迭代
# 第3281轮迭代
# 第3282轮迭代
# 第3283轮迭代
# 第3284轮迭代
# 第3285轮迭代
# 第3286轮迭代
# 第3287轮迭代
# 第3288轮迭代
# 第3289轮迭代
# 第3290轮迭代
# 第3291轮迭代
# 第3292轮迭代
# 第3293轮迭代
# 第3294轮迭代
# 第3295轮迭代
# 第3296轮迭代
# 第3297轮迭代
# 第3298轮迭代
# 第3299轮迭代
# 第3300轮迭代
# 第3301轮迭代
# 第3302轮迭代
# 第3303轮迭代
# 第3304轮迭代
# 第3305轮迭代
# 第3306轮迭代
# 第3307轮迭代
# 第3308轮迭代
# 第3309轮迭代
# 第3310轮迭代
# 第3311轮迭代
# 第3312轮迭代
# 第3313轮迭代
# 第3314轮迭代
# 第3315轮迭代
# 第3316轮迭代
# 第3317轮迭代
# 第3318轮迭代
# 第3319轮迭代
# 第3320轮迭代
# 第3321轮迭代
# 第3322轮迭代
# 第3323轮迭代
# 第3324轮迭代
# 第3325轮迭代
# 第3326轮迭代
# 第3327轮迭代
# 第3328轮迭代
# 第3329轮迭代
# 第3330轮迭代
# 第3331轮迭代
# 第3332轮迭代
# 第3333轮迭代
# 第3334轮迭代
# 第3335轮迭代
# 第3336轮迭代
# 第3337轮迭代
# 第3338轮迭代
# 第3339轮迭代
# 第3340轮迭代
# 第3341轮迭代
# 第3342轮迭代
# 第3343轮迭代
# 第3344轮迭代
# 第3345轮迭代
# 第3346轮迭代
# 第3347轮迭代
# 第3348轮迭代
# 第3349轮迭代
# 第3350轮迭代
# 第3351轮迭代
# 第3352轮迭代
# 第3353轮迭代
# 第3354轮迭代
# 第3355轮迭代
# 第3356轮迭代
# 第3357轮迭代
# 第3358轮迭代
# 第3359轮迭代
# 第3360轮迭代
# 第3361轮迭代
# 第3362轮迭代
# 第3363轮迭代
# 第3364轮迭代
# 第3365轮迭代
# 第3366轮迭代
# 第3367轮迭代
# 第3368轮迭代
# 第3369轮迭代
# 第3370轮迭代
# 第3371轮迭代
# 第3372轮迭代
# 第3373轮迭代
# 第3374轮迭代
# 第3375轮迭代
# 第3376轮迭代
# 第3377轮迭代
# 第3378轮迭代
# 第3379轮迭代
# 第3380轮迭代
# 第3381轮迭代
# 第3382轮迭代
# 第3383轮迭代
# 第3384轮迭代
# 第3385轮迭代
# 第3386轮迭代
# 第3387轮迭代
# 第3388轮迭代
# 第3389轮迭代
# 第3390轮迭代
# 第3391轮迭代
# 第3392轮迭代
# 第3393轮迭代
# 第3394轮迭代
# 第3395轮迭代
# 第3396轮迭代
# 第3397轮迭代
# 第3398轮迭代
# 第3399轮迭代
# 第3400轮迭代
# 第3401轮迭代
# 第3402轮迭代
# 第3403轮迭代
# 第3404轮迭代
# 第3405轮迭代
# 第3406轮迭代
# 第3407轮迭代
# 第3408轮迭代
# 第3409轮迭代
# 第3410轮迭代
# 第3411轮迭代
# 第3412轮迭代
# 第3413轮迭代
# 第3414轮迭代
# 第3415轮迭代
# 第3416轮迭代
# 第3417轮迭代
# 第3418轮迭代
# 第3419轮迭代
# 第3420轮迭代
# 第3421轮迭代
# 第3422轮迭代
# 第3423轮迭代
# 第3424轮迭代
# 第3425轮迭代
# 第3426轮迭代
# 第3427轮迭代
# 第3428轮迭代
# 第3429轮迭代
# 第3430轮迭代
# 第3431轮迭代
# 第3432轮迭代
# 第3433轮迭代
# 第3434轮迭代
# 第3435轮迭代
# 第3436轮迭代
# 第3437轮迭代
# 第3438轮迭代
# 第3439轮迭代
# 第3440轮迭代
# 第3441轮迭代
# 第3442轮迭代
# 第3443轮迭代
# 第3444轮迭代
# 第3445轮迭代
# 第3446轮迭代
# 第3447轮迭代
# 第3448轮迭代
# 第3449轮迭代
# 第3450轮迭代
# 第3451轮迭代
# 第3452轮迭代
# 第3453轮迭代
# 第3454轮迭代
# 第3455轮迭代
# 第3456轮迭代
# 第3457轮迭代
# 第3458轮迭代
# 第3459轮迭代
# 第3460轮迭代
# 第3461轮迭代
# 第3462轮迭代
# 第3463轮迭代
# 第3464轮迭代
# 第3465轮迭代
# 第3466轮迭代
# 第3467轮迭代
# 第3468轮迭代
# 第3469轮迭代
# 第3470轮迭代
# 第3471轮迭代
# 第3472轮迭代
# 第3473轮迭代
# 第3474轮迭代
# 第3475轮迭代
# 第3476轮迭代
# 第3477轮迭代
# 第3478轮迭代
# 第3479轮迭代
# 第3480轮迭代
# 第3481轮迭代
# 第3482轮迭代
# 第3483轮迭代
# 第3484轮迭代
# 第3485轮迭代
# 第3486轮迭代
# 第3487轮迭代
# 第3488轮迭代
# 第3489轮迭代
# 第3490轮迭代
# 第3491轮迭代
# 第3492轮迭代
# 第3493轮迭代
# 第3494轮迭代
# 第3495轮迭代
# 第3496轮迭代
# 第3497轮迭代
# 第3498轮迭代
# 第3499轮迭代
# 第3500轮迭代
# 第3501轮迭代
# 第3502轮迭代
# 第3503轮迭代
# 第3504轮迭代
# 第3505轮迭代
# 第3506轮迭代
# 第3507轮迭代
# 第3508轮迭代
# 第3509轮迭代
# 第3510轮迭代
# 第3511轮迭代
# 第3512轮迭代
# 第3513轮迭代
# 第3514轮迭代
# 第3515轮迭代
# 第3516轮迭代
# 第3517轮迭代
# 第3518轮迭代
# 第3519轮迭代
# 第3520轮迭代
# 第3521轮迭代
# 第3522轮迭代
# 第3523轮迭代
# 第3524轮迭代
# 第3525轮迭代
# 第3526轮迭代
# 第3527轮迭代
# 第3528轮迭代
# 第3529轮迭代
# 第3530轮迭代
# 第3531轮迭代
# 第3532轮迭代
# 第3533轮迭代
# 第3534轮迭代
# 第3535轮迭代
# 第3536轮迭代
# 第3537轮迭代
# 第3538轮迭代
# 第3539轮迭代
# 第3540轮迭代
# 第3541轮迭代
# 第3542轮迭代
# 第3543轮迭代
# 第3544轮迭代
# 第3545轮迭代
# 第3546轮迭代
# 第3547轮迭代
# 第3548轮迭代
# 第3549轮迭代
# 第3550轮迭代
# 第3551轮迭代
# 第3552轮迭代
# 第3553轮迭代
# 第3554轮迭代
# 第3555轮迭代
# 第3556轮迭代
# 第3557轮迭代
# 第3558轮迭代
# 第3559轮迭代
# 第3560轮迭代
# 第3561轮迭代
# 第3562轮迭代
# 第3563轮迭代
# 第3564轮迭代
# 第3565轮迭代
# 第3566轮迭代
# 第3567轮迭代
# 第3568轮迭代
# 第3569轮迭代
# 第3570轮迭代
# 第3571轮迭代
# 第3572轮迭代
# 第3573轮迭代
# 第3574轮迭代
# 第3575轮迭代
# 第3576轮迭代
# 第3577轮迭代
# 第3578轮迭代
# 第3579轮迭代
# 第3580轮迭代
# 第3581轮迭代
# 第3582轮迭代
# 第3583轮迭代
# 第3584轮迭代
# 第3585轮迭代
# 第3586轮迭代
# 第3587轮迭代
# 第3588轮迭代
# 第3589轮迭代
# 第3590轮迭代
# 第3591轮迭代
# 第3592轮迭代
# 第3593轮迭代
# 第3594轮迭代
# 第3595轮迭代
# 第3596轮迭代
# 第3597轮迭代
# 第3598轮迭代
# 第3599轮迭代
# 第3600轮迭代
# 第3601轮迭代
# 第3602轮迭代
# 第3603轮迭代
# 第3604轮迭代
# 第3605轮迭代
# 第3606轮迭代
# 第3607轮迭代
# 第3608轮迭代
# 第3609轮迭代
# 第3610轮迭代
# 第3611轮迭代
# 第3612轮迭代
# 第3613轮迭代
# 第3614轮迭代
# 第3615轮迭代
# 第3616轮迭代
# 第3617轮迭代
# 第3618轮迭代
# 第3619轮迭代
# 第3620轮迭代
# 第3621轮迭代
# 第3622轮迭代
# 第3623轮迭代
# 第3624轮迭代
# 第3625轮迭代
# 第3626轮迭代
# 第3627轮迭代
# 第3628轮迭代
# 第3629轮迭代
# 第3630轮迭代
# 第3631轮迭代
# 第3632轮迭代
# 第3633轮迭代
# 第3634轮迭代
# 第3635轮迭代
# 第3636轮迭代
# 第3637轮迭代
# 第3638轮迭代
# 第3639轮迭代
# 第3640轮迭代
# 第3641轮迭代
# 第3642轮迭代
# 第3643轮迭代
# 第3644轮迭代
# 第3645轮迭代
# 第3646轮迭代
# 第3647轮迭代
# 第3648轮迭代
# 第3649轮迭代
# 第3650轮迭代
# 第3651轮迭代
# 第3652轮迭代
# 第3653轮迭代
# 第3654轮迭代
# 第3655轮迭代
# 第3656轮迭代
# 第3657轮迭代
# 第3658轮迭代
# 第3659轮迭代
# 第3660轮迭代
# 第3661轮迭代
# 第3662轮迭代
# 第3663轮迭代
# 第3664轮迭代
# 第3665轮迭代
# 第3666轮迭代
# 第3667轮迭代
# 第3668轮迭代
# 第3669轮迭代
# 第3670轮迭代
# 第3671轮迭代
# 第3672轮迭代
# 第3673轮迭代
# 第3674轮迭代
# 第3675轮迭代
# 第3676轮迭代
# 第3677轮迭代
# 第3678轮迭代
# 第3679轮迭代
# 第3680轮迭代
# 第3681轮迭代
# 第3682轮迭代
# 第3683轮迭代
# 第3684轮迭代
# 第3685轮迭代
# 第3686轮迭代
# 第3687轮迭代
# 第3688轮迭代
# 第3689轮迭代
# 第3690轮迭代
# 第3691轮迭代
# 第3692轮迭代
# 第3693轮迭代
# 第3694轮迭代
# 第3695轮迭代
# 第3696轮迭代
# 第3697轮迭代
# 第3698轮迭代
# 第3699轮迭代
# 第3700轮迭代
# 第3701轮迭代
# 第3702轮迭代
# 第3703轮迭代
# 第3704轮迭代
# 第3705轮迭代
# 第3706轮迭代
# 第3707轮迭代
# 第3708轮迭代
# 第3709轮迭代
# 第3710轮迭代
# 第3711轮迭代
# 第3712轮迭代
# 第3713轮迭代
# 第3714轮迭代
# 第3715轮迭代
# 第3716轮迭代
# 第3717轮迭代
# 第3718轮迭代
# 第3719轮迭代
# 第3720轮迭代
# 第3721轮迭代
# 第3722轮迭代
# 第3723轮迭代
# 第3724轮迭代
# 第3725轮迭代
# 第3726轮迭代
# 第3727轮迭代
# 第3728轮迭代
# 第3729轮迭代
# 第3730轮迭代
# 第3731轮迭代
# 第3732轮迭代
# 第3733轮迭代
# 第3734轮迭代
# 第3735轮迭代
# 第3736轮迭代
# 第3737轮迭代
# 第3738轮迭代
# 第3739轮迭代
# 第3740轮迭代
# 第3741轮迭代
# 第3742轮迭代
# 第3743轮迭代
# 第3744轮迭代
# 第3745轮迭代
# 第3746轮迭代
# 第3747轮迭代
# 第3748轮迭代
# 第3749轮迭代
# 第3750轮迭代
# 第3751轮迭代
# 第3752轮迭代
# 第3753轮迭代
# 第3754轮迭代
# 第3755轮迭代
# 第3756轮迭代
# 第3757轮迭代
# 第3758轮迭代
# 第3759轮迭代
# 第3760轮迭代
# 第3761轮迭代
# 第3762轮迭代
# 第3763轮迭代
# 第3764轮迭代
# 第3765轮迭代
# 第3766轮迭代
# 第3767轮迭代
# 第3768轮迭代
# 第3769轮迭代
# 第3770轮迭代
# 第3771轮迭代
# 第3772轮迭代
# 第3773轮迭代
# 第3774轮迭代
# 第3775轮迭代
# 第3776轮迭代
# 第3777轮迭代
# 第3778轮迭代
# 第3779轮迭代
# 第3780轮迭代
# 第3781轮迭代
# 第3782轮迭代
# 第3783轮迭代
# 第3784轮迭代
# 第3785轮迭代
# 第3786轮迭代
# 第3787轮迭代
# 第3788轮迭代
# 第3789轮迭代
# 第3790轮迭代
# 第3791轮迭代
# 第3792轮迭代
# 第3793轮迭代
# 第3794轮迭代
# 第3795轮迭代
# 第3796轮迭代
# 第3797轮迭代
# 第3798轮迭代
# 第3799轮迭代
# 第3800轮迭代
# 第3801轮迭代
# 第3802轮迭代
# 第3803轮迭代
# 第3804轮迭代
# 第3805轮迭代
# 第3806轮迭代
# 第3807轮迭代
# 第3808轮迭代
# 第3809轮迭代
# 第3810轮迭代
# 第3811轮迭代
# 第3812轮迭代
# 第3813轮迭代
# 第3814轮迭代
# 第3815轮迭代
# 第3816轮迭代
# 第3817轮迭代
# 第3818轮迭代
# 第3819轮迭代
# 第3820轮迭代
# 第3821轮迭代
# 第3822轮迭代
# 第3823轮迭代
# 第3824轮迭代
# 第3825轮迭代
# 第3826轮迭代
# 第3827轮迭代
# 第3828轮迭代
# 第3829轮迭代
# 第3830轮迭代
# 第3831轮迭代
# 第3832轮迭代
# 第3833轮迭代
# 第3834轮迭代
# 第3835轮迭代
# 第3836轮迭代
# 第3837轮迭代
# 第3838轮迭代
# 第3839轮迭代
# 第3840轮迭代
# 第3841轮迭代
# 第3842轮迭代
# 第3843轮迭代
# 第3844轮迭代
# 第3845轮迭代
# 第3846轮迭代
# 第3847轮迭代
# 第3848轮迭代
# 第3849轮迭代
# 第3850轮迭代
# 第3851轮迭代
# 第3852轮迭代
# 第3853轮迭代
# 第3854轮迭代
# 第3855轮迭代
# 第3856轮迭代
# 第3857轮迭代
# 第3858轮迭代
# 第3859轮迭代
# 第3860轮迭代
# 第3861轮迭代
# 第3862轮迭代
# 第3863轮迭代
# 第3864轮迭代
# 第3865轮迭代
# 第3866轮迭代
# 第3867轮迭代
# 第3868轮迭代
# 第3869轮迭代
# 第3870轮迭代
# 第3871轮迭代
# 第3872轮迭代
# 第3873轮迭代
# 第3874轮迭代
# 第3875轮迭代
# 第3876轮迭代
# 第3877轮迭代
# 第3878轮迭代
# 第3879轮迭代
# 第3880轮迭代
# 第3881轮迭代
# 第3882轮迭代
# 第3883轮迭代
# 第3884轮迭代
# 第3885轮迭代
# 第3886轮迭代
# 第3887轮迭代
# 第3888轮迭代
# 第3889轮迭代
# 第3890轮迭代
# 第3891轮迭代
# 第3892轮迭代
# 第3893轮迭代
# 第3894轮迭代
# 第3895轮迭代
# 第3896轮迭代
# 第3897轮迭代
# 第3898轮迭代
# 第3899轮迭代
# 第3900轮迭代
# 第3901轮迭代
# 第3902轮迭代
# 第3903轮迭代
# 第3904轮迭代
# 第3905轮迭代
# 第3906轮迭代
# 第3907轮迭代
# 第3908轮迭代
# 第3909轮迭代
# 第3910轮迭代
# 第3911轮迭代
# 第3912轮迭代
# 第3913轮迭代
# 第3914轮迭代
# 第3915轮迭代
# 第3916轮迭代
# 第3917轮迭代
# 第3918轮迭代
# 第3919轮迭代
# 第3920轮迭代
# 第3921轮迭代
# 第3922轮迭代
# 第3923轮迭代
# 第3924轮迭代
# 第3925轮迭代
# 第3926轮迭代
# 第3927轮迭代
# 第3928轮迭代
# 第3929轮迭代
# 第3930轮迭代
# 第3931轮迭代
# 第3932轮迭代
# 第3933轮迭代
# 第3934轮迭代
# 第3935轮迭代
# 第3936轮迭代
# 第3937轮迭代
# 第3938轮迭代
# 第3939轮迭代
# 第3940轮迭代
# 第3941轮迭代
# 第3942轮迭代
# 第3943轮迭代
# 第3944轮迭代
# 第3945轮迭代
# 第3946轮迭代
# 第3947轮迭代
# 第3948轮迭代
# 第3949轮迭代
# 第3950轮迭代
# 第3951轮迭代
# 第3952轮迭代
# 第3953轮迭代
# 第3954轮迭代
# 第3955轮迭代
# 第3956轮迭代
# 第3957轮迭代
# 第3958轮迭代
# 第3959轮迭代
# 第3960轮迭代
# 第3961轮迭代
# 第3962轮迭代
# 第3963轮迭代
# 第3964轮迭代
# 第3965轮迭代
# 第3966轮迭代
# 第3967轮迭代
# 第3968轮迭代
# 第3969轮迭代
# 第3970轮迭代
# 第3971轮迭代
# 第3972轮迭代
# 第3973轮迭代
# 第3974轮迭代
# 第3975轮迭代
# 第3976轮迭代
# 第3977轮迭代
# 第3978轮迭代
# 第3979轮迭代
# 第3980轮迭代
# 第3981轮迭代
# 第3982轮迭代
# 第3983轮迭代
# 第3984轮迭代
# 第3985轮迭代
# 第3986轮迭代
# 第3987轮迭代
# 第3988轮迭代
# 第3989轮迭代
# 第3990轮迭代
# 第3991轮迭代
# 第3992轮迭代
# 第3993轮迭代
# 第3994轮迭代
# 第3995轮迭代
# 第3996轮迭代
# 第3997轮迭代
# 第3998轮迭代
# 第3999轮迭代
# 第4000轮迭代
# 第4001轮迭代
# 第4002轮迭代
# 第4003轮迭代
# 第4004轮迭代
# 第4005轮迭代
# 第4006轮迭代
# 第4007轮迭代
# 第4008轮迭代
# 第4009轮迭代
# 第4010轮迭代
# 第4011轮迭代
# 第4012轮迭代
# 第4013轮迭代
# 第4014轮迭代
# 第4015轮迭代
# 第4016轮迭代
# 第4017轮迭代
# 第4018轮迭代
# 第4019轮迭代
# 第4020轮迭代
# 第4021轮迭代
# 第4022轮迭代
# 第4023轮迭代
# 第4024轮迭代
# 第4025轮迭代
# 第4026轮迭代
# 第4027轮迭代
# 第4028轮迭代
# 第4029轮迭代
# 第4030轮迭代
# 第4031轮迭代
# 第4032轮迭代
# 第4033轮迭代
# 第4034轮迭代
# 第4035轮迭代
# 第4036轮迭代
# 第4037轮迭代
# 第4038轮迭代
# 第4039轮迭代
# 第4040轮迭代
# 第4041轮迭代
# 第4042轮迭代
# 第4043轮迭代
# 第4044轮迭代
# 第4045轮迭代
# 第4046轮迭代
# 第4047轮迭代
# 第4048轮迭代
# 第4049轮迭代
# 第4050轮迭代
# 第4051轮迭代
# 第4052轮迭代
# 第4053轮迭代
# 第4054轮迭代
# 第4055轮迭代
# 第4056轮迭代
# 第4057轮迭代
# 第4058轮迭代
# 第4059轮迭代
# 第4060轮迭代
# 第4061轮迭代
# 第4062轮迭代
# 第4063轮迭代
# 第4064轮迭代
# 第4065轮迭代
# 第4066轮迭代
# 第4067轮迭代
# 第4068轮迭代
# 第4069轮迭代
# 第4070轮迭代
# 第4071轮迭代
# 第4072轮迭代
# 第4073轮迭代
# 第4074轮迭代
# 第4075轮迭代
# 第4076轮迭代
# 第4077轮迭代
# 第4078轮迭代
# 第4079轮迭代
# 第4080轮迭代
# 第4081轮迭代
# 第4082轮迭代
# 第4083轮迭代
# 第4084轮迭代
# 第4085轮迭代
# 第4086轮迭代
# 第4087轮迭代
# 第4088轮迭代
# 第4089轮迭代
# 第4090轮迭代
# 第4091轮迭代
# 第4092轮迭代
# 第4093轮迭代
# 第4094轮迭代
# 第4095轮迭代
# 第4096轮迭代
# 第4097轮迭代
# 第4098轮迭代
# 第4099轮迭代
# 第4100轮迭代
# 第4101轮迭代
# 第4102轮迭代
# 第4103轮迭代
# 第4104轮迭代
# 第4105轮迭代
# 第4106轮迭代
# 第4107轮迭代
# 第4108轮迭代
# 第4109轮迭代
# 第4110轮迭代
# 第4111轮迭代
# 第4112轮迭代
# 第4113轮迭代
# 第4114轮迭代
# 第4115轮迭代
# 第4116轮迭代
# 第4117轮迭代
# 第4118轮迭代
# 第4119轮迭代
# 第4120轮迭代
# 第4121轮迭代
# 第4122轮迭代
# 第4123轮迭代
# 第4124轮迭代
# 第4125轮迭代
# 第4126轮迭代
# 第4127轮迭代
# 第4128轮迭代
# 第4129轮迭代
# 第4130轮迭代
# 第4131轮迭代
# 第4132轮迭代
# 第4133轮迭代
# 第4134轮迭代
# 第4135轮迭代
# 第4136轮迭代
# 第4137轮迭代
# 第4138轮迭代
# 第4139轮迭代
# 第4140轮迭代
# 第4141轮迭代
# 第4142轮迭代
# 第4143轮迭代
# 第4144轮迭代
# 第4145轮迭代
# 第4146轮迭代
# 第4147轮迭代
# 第4148轮迭代
# 第4149轮迭代
# 第4150轮迭代
# 第4151轮迭代
# 第4152轮迭代
# 第4153轮迭代
# 第4154轮迭代
# 第4155轮迭代
# 第4156轮迭代
# 第4157轮迭代
# 第4158轮迭代
# 第4159轮迭代
# 第4160轮迭代
# 第4161轮迭代
# 第4162轮迭代
# 第4163轮迭代
# 第4164轮迭代
# 第4165轮迭代
# 第4166轮迭代
# 第4167轮迭代
# 第4168轮迭代
# 第4169轮迭代
# 第4170轮迭代
# 第4171轮迭代
# 第4172轮迭代
# 第4173轮迭代
# 第4174轮迭代
# 第4175轮迭代
# 第4176轮迭代
# 第4177轮迭代
# 第4178轮迭代
# 第4179轮迭代
# 第4180轮迭代
# 第4181轮迭代
# 第4182轮迭代
# 第4183轮迭代
# 第4184轮迭代
# 第4185轮迭代
# 第4186轮迭代
# 第4187轮迭代
# 第4188轮迭代
# 第4189轮迭代
# 第4190轮迭代
# 第4191轮迭代
# 第4192轮迭代
# 第4193轮迭代
# 第4194轮迭代
# 第4195轮迭代
# 第4196轮迭代
# 第4197轮迭代
# 第4198轮迭代
# 第4199轮迭代
# 第4200轮迭代
# 第4201轮迭代
# 第4202轮迭代
# 第4203轮迭代
# 第4204轮迭代
# 第4205轮迭代
# 第4206轮迭代
# 第4207轮迭代
# 第4208轮迭代
# 第4209轮迭代
# 第4210轮迭代
# 第4211轮迭代
# 第4212轮迭代
# 第4213轮迭代
# 第4214轮迭代
# 第4215轮迭代
# 第4216轮迭代
# 第4217轮迭代
# 第4218轮迭代
# 第4219轮迭代
# 第4220轮迭代
# 第4221轮迭代
# 第4222轮迭代
# 第4223轮迭代
# 第4224轮迭代
# 第4225轮迭代
# 第4226轮迭代
# 第4227轮迭代
# 第4228轮迭代
# 第4229轮迭代
# 第4230轮迭代
# 第4231轮迭代
# 第4232轮迭代
# 第4233轮迭代
# 第4234轮迭代
# 第4235轮迭代
# 第4236轮迭代
# 第4237轮迭代
# 第4238轮迭代
# 第4239轮迭代
# 第4240轮迭代
# 第4241轮迭代
# 第4242轮迭代
# 第4243轮迭代
# 第4244轮迭代
# 第4245轮迭代
# 第4246轮迭代
# 第4247轮迭代
# 第4248轮迭代
# 第4249轮迭代
# 第4250轮迭代
# 第4251轮迭代
# 第4252轮迭代
# 第4253轮迭代
# 第4254轮迭代
# 第4255轮迭代
# 第4256轮迭代
# 第4257轮迭代
# 第4258轮迭代
# 第4259轮迭代
# 第4260轮迭代
# 第4261轮迭代
# 第4262轮迭代
# 第4263轮迭代
# 第4264轮迭代
# 第4265轮迭代
# 第4266轮迭代
# 第4267轮迭代
# 第4268轮迭代
# 第4269轮迭代
# 第4270轮迭代
# 第4271轮迭代
# 第4272轮迭代
# 第4273轮迭代
# 第4274轮迭代
# 第4275轮迭代
# 第4276轮迭代
# 第4277轮迭代
# 第4278轮迭代
# 第4279轮迭代
# 第4280轮迭代
# 第4281轮迭代
# 第4282轮迭代
# 第4283轮迭代
# 第4284轮迭代
# 第4285轮迭代
# 第4286轮迭代
# 第4287轮迭代
# 第4288轮迭代
# 第4289轮迭代
# 第4290轮迭代
# 第4291轮迭代
# 第4292轮迭代
# 第4293轮迭代
# 第4294轮迭代
# 第4295轮迭代
# 第4296轮迭代
# 第4297轮迭代
# 第4298轮迭代
# 第4299轮迭代
# 第4300轮迭代
# 第4301轮迭代
# 第4302轮迭代
# 第4303轮迭代
# 第4304轮迭代
# 第4305轮迭代
# 第4306轮迭代
# 第4307轮迭代
# 第4308轮迭代
# 第4309轮迭代
# 第4310轮迭代
# 第4311轮迭代
# 第4312轮迭代
# 第4313轮迭代
# 第4314轮迭代
# 第4315轮迭代
# 第4316轮迭代
# 第4317轮迭代
# 第4318轮迭代
# 第4319轮迭代
# 第4320轮迭代
# 第4321轮迭代
# 第4322轮迭代
# 第4323轮迭代
# 第4324轮迭代
# 第4325轮迭代
# 第4326轮迭代
# 第4327轮迭代
# 第4328轮迭代
# 第4329轮迭代
# 第4330轮迭代
# 第4331轮迭代
# 第4332轮迭代
# 第4333轮迭代
# 第4334轮迭代
# 第4335轮迭代
# 第4336轮迭代
# 第4337轮迭代
# 第4338轮迭代
# 第4339轮迭代
# 第4340轮迭代
# 第4341轮迭代
# 第4342轮迭代
# 第4343轮迭代
# 第4344轮迭代
# 第4345轮迭代
# 第4346轮迭代
# 第4347轮迭代
# 第4348轮迭代
# 第4349轮迭代
# 第4350轮迭代
# 第4351轮迭代
# 第4352轮迭代
# 第4353轮迭代
# 第4354轮迭代
# 第4355轮迭代
# 第4356轮迭代
# 第4357轮迭代
# 第4358轮迭代
# 第4359轮迭代
# 第4360轮迭代
# 第4361轮迭代
# 第4362轮迭代
# 第4363轮迭代
# 第4364轮迭代
# 第4365轮迭代
# 第4366轮迭代
# 第4367轮迭代
# 第4368轮迭代
# 第4369轮迭代
# 第4370轮迭代
# 第4371轮迭代
# 第4372轮迭代
# 第4373轮迭代
# 第4374轮迭代
# 第4375轮迭代
# 第4376轮迭代
# 第4377轮迭代
# 第4378轮迭代
# 第4379轮迭代
# 第4380轮迭代
# 第4381轮迭代
# 第4382轮迭代
# 第4383轮迭代
# 第4384轮迭代
# 第4385轮迭代
# 第4386轮迭代
# 第4387轮迭代
# 第4388轮迭代
# 第4389轮迭代
# 第4390轮迭代
# 第4391轮迭代
# 第4392轮迭代
# 第4393轮迭代
# 第4394轮迭代
# 第4395轮迭代
# 第4396轮迭代
# 第4397轮迭代
# 第4398轮迭代
# 第4399轮迭代
# 第4400轮迭代
# 第4401轮迭代
# 第4402轮迭代
# 第4403轮迭代
# 第4404轮迭代
# 第4405轮迭代
# 第4406轮迭代
# 第4407轮迭代
# 第4408轮迭代
# 第4409轮迭代
# 第4410轮迭代
# 第4411轮迭代
# 第4412轮迭代
# 第4413轮迭代
# 第4414轮迭代
# 第4415轮迭代
# 第4416轮迭代
# 第4417轮迭代
# 第4418轮迭代
# 第4419轮迭代
# 第4420轮迭代
# 第4421轮迭代
# 第4422轮迭代
# 第4423轮迭代
# 第4424轮迭代
# 第4425轮迭代
# 第4426轮迭代
# 第4427轮迭代
# 第4428轮迭代
# 第4429轮迭代
# 第4430轮迭代
# 第4431轮迭代
# 第4432轮迭代
# 第4433轮迭代
# 第4434轮迭代
# 第4435轮迭代
# 第4436轮迭代
# 第4437轮迭代
# 第4438轮迭代
# 第4439轮迭代
# 第4440轮迭代
# 第4441轮迭代
# 第4442轮迭代
# 第4443轮迭代
# 第4444轮迭代
# 第4445轮迭代
# 第4446轮迭代
# 第4447轮迭代
# 第4448轮迭代
# 第4449轮迭代
# 第4450轮迭代
# 第4451轮迭代
# 第4452轮迭代
# 第4453轮迭代
# 第4454轮迭代
# 第4455轮迭代
# 第4456轮迭代
# 第4457轮迭代
# 第4458轮迭代
# 第4459轮迭代
# 第4460轮迭代
# 第4461轮迭代
# 第4462轮迭代
# 第4463轮迭代
# 第4464轮迭代
# 第4465轮迭代
# 第4466轮迭代
# 第4467轮迭代
# 第4468轮迭代
# 第4469轮迭代
# 第4470轮迭代
# 第4471轮迭代
# 第4472轮迭代
# 第4473轮迭代
# 第4474轮迭代
# 第4475轮迭代
# 第4476轮迭代
# 第4477轮迭代
# 第4478轮迭代
# 第4479轮迭代
# 第4480轮迭代
# 第4481轮迭代
# 第4482轮迭代
# 第4483轮迭代
# 第4484轮迭代
# 第4485轮迭代
# 第4486轮迭代
# 第4487轮迭代
# 第4488轮迭代
# 第4489轮迭代
# 第4490轮迭代
# 第4491轮迭代
# 第4492轮迭代
# 第4493轮迭代
# 第4494轮迭代
# 第4495轮迭代
# 第4496轮迭代
# 第4497轮迭代
# 第4498轮迭代
# 第4499轮迭代
# 第4500轮迭代
# 第4501轮迭代
# 第4502轮迭代
# 第4503轮迭代
# 第4504轮迭代
# 第4505轮迭代
# 第4506轮迭代
# 第4507轮迭代
# 第4508轮迭代
# 第4509轮迭代
# 第4510轮迭代
# 第4511轮迭代
# 第4512轮迭代
# 第4513轮迭代
# 第4514轮迭代
# 第4515轮迭代
# 第4516轮迭代
# 第4517轮迭代
# 第4518轮迭代
# 第4519轮迭代
# 第4520轮迭代
# 第4521轮迭代
# 第4522轮迭代
# 第4523轮迭代
# 第4524轮迭代
# 第4525轮迭代
# 第4526轮迭代
# 第4527轮迭代
# 第4528轮迭代
# 第4529轮迭代
# 第4530轮迭代
# 第4531轮迭代
# 第4532轮迭代
# 第4533轮迭代
# 第4534轮迭代
# 第4535轮迭代
# 第4536轮迭代
# 第4537轮迭代
# 第4538轮迭代
# 第4539轮迭代
# 第4540轮迭代
# 第4541轮迭代
# 第4542轮迭代
# 第4543轮迭代
# 第4544轮迭代
# 第4545轮迭代
# 第4546轮迭代
# 第4547轮迭代
# 第4548轮迭代
# 第4549轮迭代
# 第4550轮迭代
# 第4551轮迭代
# 第4552轮迭代
# 第4553轮迭代
# 第4554轮迭代
# 第4555轮迭代
# 第4556轮迭代
# 第4557轮迭代
# 第4558轮迭代
# 第4559轮迭代
# 第4560轮迭代
# 第4561轮迭代
# 第4562轮迭代
# 第4563轮迭代
# 第4564轮迭代
# 第4565轮迭代
# 第4566轮迭代
# 第4567轮迭代
# 第4568轮迭代
# 第4569轮迭代
# 第4570轮迭代
# 第4571轮迭代
# 第4572轮迭代
# 第4573轮迭代
# 第4574轮迭代
# 第4575轮迭代
# 第4576轮迭代
# 第4577轮迭代
# 第4578轮迭代
# 第4579轮迭代
# 第4580轮迭代
# 第4581轮迭代
# 第4582轮迭代
# 第4583轮迭代
# 第4584轮迭代
# 第4585轮迭代
# 第4586轮迭代
# 第4587轮迭代
# 第4588轮迭代
# 第4589轮迭代
# 第4590轮迭代
# 第4591轮迭代
# 第4592轮迭代
# 第4593轮迭代
# 第4594轮迭代
# 第4595轮迭代
# 第4596轮迭代
# 第4597轮迭代
# 第4598轮迭代
# 第4599轮迭代
# 第4600轮迭代
# 第4601轮迭代
# 第4602轮迭代
# 第4603轮迭代
# 第4604轮迭代
# 第4605轮迭代
# 第4606轮迭代
# 第4607轮迭代
# 第4608轮迭代
# 第4609轮迭代
# 第4610轮迭代
# 第4611轮迭代
# 第4612轮迭代
# 第4613轮迭代
# 第4614轮迭代
# 第4615轮迭代
# 第4616轮迭代
# 第4617轮迭代
# 第4618轮迭代
# 第4619轮迭代
# 第4620轮迭代
# 第4621轮迭代
# 第4622轮迭代
# 第4623轮迭代
# 第4624轮迭代
# 第4625轮迭代
# 第4626轮迭代
# 第4627轮迭代
# 第4628轮迭代
# 第4629轮迭代
# 第4630轮迭代
# 第4631轮迭代
# 第4632轮迭代
# 第4633轮迭代
# 第4634轮迭代
# 第4635轮迭代
# 第4636轮迭代
# 第4637轮迭代
# 第4638轮迭代
# 第4639轮迭代
# 第4640轮迭代
# 第4641轮迭代
# 第4642轮迭代
# 第4643轮迭代
# 第4644轮迭代
# 第4645轮迭代
# 第4646轮迭代
# 第4647轮迭代
# 第4648轮迭代
# 第4649轮迭代
# 第4650轮迭代
# 第4651轮迭代
# 第4652轮迭代
# 第4653轮迭代
# 第4654轮迭代
# 第4655轮迭代
# 第4656轮迭代
# 第4657轮迭代
# 第4658轮迭代
# 第4659轮迭代
# 第4660轮迭代
# 第4661轮迭代
# 第4662轮迭代
# 第4663轮迭代
# 第4664轮迭代
# 第4665轮迭代
# 第4666轮迭代
# 第4667轮迭代
# 第4668轮迭代
# 第4669轮迭代
# 第4670轮迭代
# 第4671轮迭代
# 第4672轮迭代
# 第4673轮迭代
# 第4674轮迭代
# 第4675轮迭代
# 第4676轮迭代
# 第4677轮迭代
# 第4678轮迭代
# 第4679轮迭代
# 第4680轮迭代
# 第4681轮迭代
# 第4682轮迭代
# 第4683轮迭代
# 第4684轮迭代
# 第4685轮迭代
# 第4686轮迭代
# 第4687轮迭代
# 第4688轮迭代
# 第4689轮迭代
# 第4690轮迭代
# 第4691轮迭代
# 第4692轮迭代
# 第4693轮迭代
# 第4694轮迭代
# 第4695轮迭代
# 第4696轮迭代
# 第4697轮迭代
# 第4698轮迭代
# 第4699轮迭代
# 第4700轮迭代
# 第4701轮迭代
# 第4702轮迭代
# 第4703轮迭代
# 第4704轮迭代
# 第4705轮迭代
# 第4706轮迭代
# 第4707轮迭代
# 第4708轮迭代
# 第4709轮迭代
# 第4710轮迭代
# 第4711轮迭代
# 第4712轮迭代
# 第4713轮迭代
# 第4714轮迭代
# 第4715轮迭代
# 第4716轮迭代
# 第4717轮迭代
# 第4718轮迭代
# 第4719轮迭代
# 第4720轮迭代
# 第4721轮迭代
# 第4722轮迭代
# 第4723轮迭代
# 第4724轮迭代
# 第4725轮迭代
# 第4726轮迭代
# 第4727轮迭代
# 第4728轮迭代
# 第4729轮迭代
# 第4730轮迭代
# 第4731轮迭代
# 第4732轮迭代
# 第4733轮迭代
# 第4734轮迭代
# 第4735轮迭代
# 第4736轮迭代
# 第4737轮迭代
# 第4738轮迭代
# 第4739轮迭代
# 第4740轮迭代
# 第4741轮迭代
# 第4742轮迭代
# 第4743轮迭代
# 第4744轮迭代
# 第4745轮迭代
# 第4746轮迭代
# 第4747轮迭代
# 第4748轮迭代
# 第4749轮迭代
# 第4750轮迭代
# 第4751轮迭代
# 第4752轮迭代
# 第4753轮迭代
# 第4754轮迭代
# 第4755轮迭代
# 第4756轮迭代
# 第4757轮迭代
# 第4758轮迭代
# 第4759轮迭代
# 第4760轮迭代
# 第4761轮迭代
# 第4762轮迭代
# 第4763轮迭代
# 第4764轮迭代
# 第4765轮迭代
# 第4766轮迭代
# 第4767轮迭代
# 第4768轮迭代
# 第4769轮迭代
# 第4770轮迭代
# 第4771轮迭代
# 第4772轮迭代
# 第4773轮迭代
# 第4774轮迭代
# 第4775轮迭代
# 第4776轮迭代
# 第4777轮迭代
# 第4778轮迭代
# 第4779轮迭代
# 第4780轮迭代
# 第4781轮迭代
# 第4782轮迭代
# 第4783轮迭代
# 第4784轮迭代
# 第4785轮迭代
# 第4786轮迭代
# 第4787轮迭代
# 第4788轮迭代
# 第4789轮迭代
# 第4790轮迭代
# 第4791轮迭代
# 第4792轮迭代
# 第4793轮迭代
# 第4794轮迭代
# 第4795轮迭代
# 第4796轮迭代
# 第4797轮迭代
# 第4798轮迭代
# 第4799轮迭代
# 第4800轮迭代
# 第4801轮迭代
# 第4802轮迭代
# 第4803轮迭代
# 第4804轮迭代
# 第4805轮迭代
# 第4806轮迭代
# 第4807轮迭代
# 第4808轮迭代
# 第4809轮迭代
# 第4810轮迭代
# 第4811轮迭代
# 第4812轮迭代
# 第4813轮迭代
# 第4814轮迭代
# 第4815轮迭代
# 第4816轮迭代
# 第4817轮迭代
# 第4818轮迭代
# 第4819轮迭代
# 第4820轮迭代
# 第4821轮迭代
# 第4822轮迭代
# 第4823轮迭代
# 第4824轮迭代
# 第4825轮迭代
# 第4826轮迭代
# 第4827轮迭代
# 第4828轮迭代
# 第4829轮迭代
# 第4830轮迭代
# 第4831轮迭代
# 第4832轮迭代
# 第4833轮迭代
# 第4834轮迭代
# 第4835轮迭代
# 第4836轮迭代
# 第4837轮迭代
# 第4838轮迭代
# 第4839轮迭代
# 第4840轮迭代
# 第4841轮迭代
# 第4842轮迭代
# 第4843轮迭代
# 第4844轮迭代
# 第4845轮迭代
# 第4846轮迭代
# 第4847轮迭代
# 第4848轮迭代
# 第4849轮迭代
# 第4850轮迭代
# 第4851轮迭代
# 第4852轮迭代
# 第4853轮迭代
# 第4854轮迭代
# 第4855轮迭代
# 第4856轮迭代
# 第4857轮迭代
# 第4858轮迭代
# 第4859轮迭代
# 第4860轮迭代
# 第4861轮迭代
# 第4862轮迭代
# 第4863轮迭代
# 第4864轮迭代
# 第4865轮迭代
# 第4866轮迭代
# 第4867轮迭代
# 第4868轮迭代
# 第4869轮迭代
# 第4870轮迭代
# 第4871轮迭代
# 第4872轮迭代
# 第4873轮迭代
# 第4874轮迭代
# 第4875轮迭代
# 第4876轮迭代
# 第4877轮迭代
# 第4878轮迭代
# 第4879轮迭代
# 第4880轮迭代
# 第4881轮迭代
# 第4882轮迭代
# 第4883轮迭代
# 第4884轮迭代
# 第4885轮迭代
# 第4886轮迭代
# 第4887轮迭代
# 第4888轮迭代
# 第4889轮迭代
# 第4890轮迭代
# 第4891轮迭代
# 第4892轮迭代
# 第4893轮迭代
# 第4894轮迭代
# 第4895轮迭代
# 第4896轮迭代
# 第4897轮迭代
# 第4898轮迭代
# 第4899轮迭代
# 第4900轮迭代
# 第4901轮迭代
# 第4902轮迭代
# 第4903轮迭代
# 第4904轮迭代
# 第4905轮迭代
# 第4906轮迭代
# 第4907轮迭代
# 第4908轮迭代
# 第4909轮迭代
# 第4910轮迭代
# 第4911轮迭代
# 第4912轮迭代
# 第4913轮迭代
# 第4914轮迭代
# 第4915轮迭代
# 第4916轮迭代
# 第4917轮迭代
# 第4918轮迭代
# 第4919轮迭代
# 第4920轮迭代
# 第4921轮迭代
# 第4922轮迭代
# 第4923轮迭代
# 第4924轮迭代
# 第4925轮迭代
# 第4926轮迭代
# 第4927轮迭代
# 第4928轮迭代
# 第4929轮迭代
# 第4930轮迭代
# 第4931轮迭代
# 第4932轮迭代
# 第4933轮迭代
# 第4934轮迭代
# 第4935轮迭代
# 第4936轮迭代
# 第4937轮迭代
# 第4938轮迭代
# 第4939轮迭代
# 第4940轮迭代
# 第4941轮迭代
# 第4942轮迭代
# 第4943轮迭代
# 第4944轮迭代
# 第4945轮迭代
# 第4946轮迭代
# 第4947轮迭代
# 第4948轮迭代
# 第4949轮迭代
# 第4950轮迭代
# 第4951轮迭代
# 第4952轮迭代
# 第4953轮迭代
# 第4954轮迭代
# 第4955轮迭代
# 第4956轮迭代
# 第4957轮迭代
# 第4958轮迭代
# 第4959轮迭代
# 第4960轮迭代
# 第4961轮迭代
# 第4962轮迭代
# 第4963轮迭代
# 第4964轮迭代
# 第4965轮迭代
# 第4966轮迭代
# 第4967轮迭代
# 第4968轮迭代
# 第4969轮迭代
# 第4970轮迭代
# 第4971轮迭代
# 第4972轮迭代
# 第4973轮迭代
# 第4974轮迭代
# 第4975轮迭代
# 第4976轮迭代
# 第4977轮迭代
# 第4978轮迭代
# 第4979轮迭代
# 第4980轮迭代
# 第4981轮迭代
# 第4982轮迭代
# 第4983轮迭代
# 第4984轮迭代
# 第4985轮迭代
# 第4986轮迭代
# 第4987轮迭代
# 第4988轮迭代
# 第4989轮迭代
# 第4990轮迭代
# 第4991轮迭代
# 第4992轮迭代
# 第4993轮迭代
# 第4994轮迭代
# 第4995轮迭代
# 第4996轮迭代
# 第4997轮迭代
# 第4998轮迭代
# 第4999轮迭代
# 第5000轮迭代
# 第5001轮迭代
# 第5002轮迭代
# 第5003轮迭代
# 第5004轮迭代
# 第5005轮迭代
# 第5006轮迭代
# 第5007轮迭代
# 第5008轮迭代
# 第5009轮迭代
# 第5010轮迭代
# 第5011轮迭代
# 第5012轮迭代
# 第5013轮迭代
# 第5014轮迭代
# 第5015轮迭代
# 第5016轮迭代
# 第5017轮迭代
# 第5018轮迭代
# 第5019轮迭代
# 第5020轮迭代
# 第5021轮迭代
# 第5022轮迭代
# 第5023轮迭代
# 第5024轮迭代
# 第5025轮迭代
# 第5026轮迭代
# 第5027轮迭代
# 第5028轮迭代
# 第5029轮迭代
# 第5030轮迭代
# 第5031轮迭代
# 第5032轮迭代
# 第5033轮迭代
# 第5034轮迭代
# 第5035轮迭代
# 第5036轮迭代
# 第5037轮迭代
# 第5038轮迭代
# 第5039轮迭代
# 第5040轮迭代
# 第5041轮迭代
# 第5042轮迭代
# 第5043轮迭代
# 第5044轮迭代
# 第5045轮迭代
# 第5046轮迭代
# 第5047轮迭代
# 第5048轮迭代
# 第5049轮迭代
# 第5050轮迭代
# 第5051轮迭代
# 第5052轮迭代
# 第5053轮迭代
# 第5054轮迭代
# 第5055轮迭代
# 第5056轮迭代
# 第5057轮迭代
# 第5058轮迭代
# 第5059轮迭代
# 第5060轮迭代
# 第5061轮迭代
# 第5062轮迭代
# 第5063轮迭代
# 第5064轮迭代
# 第5065轮迭代
# 第5066轮迭代
# 第5067轮迭代
# 第5068轮迭代
# 第5069轮迭代
# 第5070轮迭代
# 第5071轮迭代
# 第5072轮迭代
# 第5073轮迭代
# 第5074轮迭代
# 第5075轮迭代
# 第5076轮迭代
# 第5077轮迭代
# 第5078轮迭代
# 第5079轮迭代
# 第5080轮迭代
# 第5081轮迭代
# 第5082轮迭代
# 第5083轮迭代
# 第5084轮迭代
# 第5085轮迭代
# 第5086轮迭代
# 第5087轮迭代
# 第5088轮迭代
# 第5089轮迭代
# 第5090轮迭代
# 第5091轮迭代
# 第5092轮迭代
# 第5093轮迭代
# 第5094轮迭代
# 第5095轮迭代
# 第5096轮迭代
# 第5097轮迭代
# 第5098轮迭代
# 第5099轮迭代
# 第5100轮迭代
# 第5101轮迭代
# 第5102轮迭代
# 第5103轮迭代
# 第5104轮迭代
# 第5105轮迭代
# 第5106轮迭代
# 第5107轮迭代
# 第5108轮迭代
# 第5109轮迭代
# 第5110轮迭代
# 第5111轮迭代
# 第5112轮迭代
# 第5113轮迭代
# 第5114轮迭代
# 第5115轮迭代
# 第5116轮迭代
# 第5117轮迭代
# 第5118轮迭代
# 第5119轮迭代
# 第5120轮迭代
# 第5121轮迭代
# 第5122轮迭代
# 第5123轮迭代
# 第5124轮迭代
# 第5125轮迭代
# 第5126轮迭代
# 第5127轮迭代
# 第5128轮迭代
# 第5129轮迭代
# 第5130轮迭代
# 第5131轮迭代
# 第5132轮迭代
# 第5133轮迭代
# 第5134轮迭代
# 第5135轮迭代
# 第5136轮迭代
# 第5137轮迭代
# 第5138轮迭代
# 第5139轮迭代
# 第5140轮迭代
# 第5141轮迭代
# 第5142轮迭代
# 第5143轮迭代
# 第5144轮迭代
# 第5145轮迭代
# 第5146轮迭代
# 第5147轮迭代
# 第5148轮迭代
# 第5149轮迭代
# 第5150轮迭代
# 第5151轮迭代
# 第5152轮迭代
# 第5153轮迭代
# 第5154轮迭代
# 第5155轮迭代
# 第5156轮迭代
# 第5157轮迭代
# 第5158轮迭代
# 第5159轮迭代
# 第5160轮迭代
# 第5161轮迭代
# 第5162轮迭代
# 第5163轮迭代
# 第5164轮迭代
# 第5165轮迭代
# 第5166轮迭代
# 第5167轮迭代
# 第5168轮迭代
# 第5169轮迭代
# 第5170轮迭代
# 第5171轮迭代
# 第5172轮迭代
# 第5173轮迭代
# 第5174轮迭代
# 第5175轮迭代
# 第5176轮迭代
# 第5177轮迭代
# 第5178轮迭代
# 第5179轮迭代
# 第5180轮迭代
# 第5181轮迭代
# 第5182轮迭代
# 第5183轮迭代
# 第5184轮迭代
# 第5185轮迭代
# 第5186轮迭代
# 第5187轮迭代
# 第5188轮迭代
# 第5189轮迭代
# 第5190轮迭代
# 第5191轮迭代
# 第5192轮迭代
# 第5193轮迭代
# 第5194轮迭代
# 第5195轮迭代
# 第5196轮迭代
# 第5197轮迭代
# 第5198轮迭代
# 第5199轮迭代
# 第5200轮迭代
# 第5201轮迭代
# 第5202轮迭代
# 第5203轮迭代
# 第5204轮迭代
# 第5205轮迭代
# 第5206轮迭代
# 第5207轮迭代
# 第5208轮迭代
# 第5209轮迭代
# 第5210轮迭代
# 第5211轮迭代
# 第5212轮迭代
# 第5213轮迭代
# 第5214轮迭代
# 第5215轮迭代
# 第5216轮迭代
# 第5217轮迭代
# 第5218轮迭代
# 第5219轮迭代
# 第5220轮迭代
# 第5221轮迭代
# 第5222轮迭代
# 第5223轮迭代
# 第5224轮迭代
# 第5225轮迭代
# 第5226轮迭代
# 第5227轮迭代
# 第5228轮迭代
# 第5229轮迭代
# 第5230轮迭代
# 第5231轮迭代
# 第5232轮迭代
# 第5233轮迭代
# 第5234轮迭代
# 第5235轮迭代
# 第5236轮迭代
# 第5237轮迭代
# 第5238轮迭代
# 第5239轮迭代
# 第5240轮迭代
# 第5241轮迭代
# 第5242轮迭代
# 第5243轮迭代
# 第5244轮迭代
# 第5245轮迭代
# 第5246轮迭代
# 第5247轮迭代
# 第5248轮迭代
# 第5249轮迭代
# 第5250轮迭代
# 第5251轮迭代
# 第5252轮迭代
# 第5253轮迭代
# 第5254轮迭代
# 第5255轮迭代
# 第5256轮迭代
# 第5257轮迭代
# 第5258轮迭代
# 第5259轮迭代
# 第5260轮迭代
# 第5261轮迭代
# 第5262轮迭代
# 第5263轮迭代
# 第5264轮迭代
# 第5265轮迭代
# 第5266轮迭代
# 第5267轮迭代
# 第5268轮迭代
# 第5269轮迭代
# 第5270轮迭代
# 第5271轮迭代
# 第5272轮迭代
# 第5273轮迭代
# 第5274轮迭代
# 第5275轮迭代
# 第5276轮迭代
# 第5277轮迭代
# 第5278轮迭代
# 第5279轮迭代
# 第5280轮迭代
# 第5281轮迭代
# 第5282轮迭代
# 第5283轮迭代
# 第5284轮迭代
# 第5285轮迭代
# 第5286轮迭代
# 第5287轮迭代
# 第5288轮迭代
# 第5289轮迭代
# 第5290轮迭代
# 第5291轮迭代
# 第5292轮迭代
# 第5293轮迭代
# 第5294轮迭代
# 第5295轮迭代
# 第5296轮迭代
# 第5297轮迭代
# 第5298轮迭代
# 第5299轮迭代
# 第5300轮迭代
# 第5301轮迭代
# 第5302轮迭代
# 第5303轮迭代
# 第5304轮迭代
# 第5305轮迭代
# 第5306轮迭代
# 第5307轮迭代
# 第5308轮迭代
# 第5309轮迭代
# 第5310轮迭代
# 第5311轮迭代
# 第5312轮迭代
# 第5313轮迭代
# 第5314轮迭代
# 第5315轮迭代
# 第5316轮迭代
# 第5317轮迭代
# 第5318轮迭代
# 第5319轮迭代
# 第5320轮迭代
# 第5321轮迭代
# 第5322轮迭代
# 第5323轮迭代
# 第5324轮迭代
# 第5325轮迭代
# 第5326轮迭代
# 第5327轮迭代
# 第5328轮迭代
# 第5329轮迭代
# 第5330轮迭代
# 第5331轮迭代
# 第5332轮迭代
# 第5333轮迭代
# 第5334轮迭代
# 第5335轮迭代
# 第5336轮迭代
# 第5337轮迭代
# 第5338轮迭代
# 第5339轮迭代
# 第5340轮迭代
# 第5341轮迭代
# 第5342轮迭代
# 第5343轮迭代
# 第5344轮迭代
# 第5345轮迭代
# 第5346轮迭代
# 第5347轮迭代
# 第5348轮迭代
# 第5349轮迭代
# 第5350轮迭代
# 第5351轮迭代
# 第5352轮迭代
# 第5353轮迭代
# 第5354轮迭代
# 第5355轮迭代
# 第5356轮迭代
# 第5357轮迭代
# 第5358轮迭代
# 第5359轮迭代
# 第5360轮迭代
# 第5361轮迭代
# 第5362轮迭代
# 第5363轮迭代
# 第5364轮迭代
# 第5365轮迭代
# 第5366轮迭代
# 第5367轮迭代
# 第5368轮迭代
# 第5369轮迭代
# 第5370轮迭代
# 第5371轮迭代
# 第5372轮迭代
# 第5373轮迭代
# 第5374轮迭代
# 第5375轮迭代
# 第5376轮迭代
# 第5377轮迭代
# 第5378轮迭代
# 第5379轮迭代
# 第5380轮迭代
# 第5381轮迭代
# 第5382轮迭代
# 第5383轮迭代
# 第5384轮迭代
# 第5385轮迭代
# 第5386轮迭代
# 第5387轮迭代
# 第5388轮迭代
# 第5389轮迭代
# 第5390轮迭代
# 第5391轮迭代
# 第5392轮迭代
# 第5393轮迭代
# 第5394轮迭代
# 第5395轮迭代
# 第5396轮迭代
# 第5397轮迭代
# 第5398轮迭代
# 第5399轮迭代
# 第5400轮迭代
# 第5401轮迭代
# 第5402轮迭代
# 第5403轮迭代
# 第5404轮迭代
# 第5405轮迭代
# 第5406轮迭代
# 第5407轮迭代
# 第5408轮迭代
# 第5409轮迭代
# 第5410轮迭代
# 第5411轮迭代
# 第5412轮迭代
# 第5413轮迭代
# 第5414轮迭代
# 第5415轮迭代
# 第5416轮迭代
# 第5417轮迭代
# 第5418轮迭代
# 第5419轮迭代
# 第5420轮迭代
# 第5421轮迭代
# 第5422轮迭代
# 第5423轮迭代
# 第5424轮迭代
# 第5425轮迭代
# 第5426轮迭代
# 第5427轮迭代
# 第5428轮迭代
# 第5429轮迭代
# 第5430轮迭代
# 第5431轮迭代
# 第5432轮迭代
# 第5433轮迭代
# 第5434轮迭代
# 第5435轮迭代
# 第5436轮迭代
# 第5437轮迭代
# 第5438轮迭代
# 第5439轮迭代
# 第5440轮迭代
# 第5441轮迭代
# 第5442轮迭代
# 第5443轮迭代
# 第5444轮迭代
# 第5445轮迭代
# 第5446轮迭代
# 第5447轮迭代
# 第5448轮迭代
# 第5449轮迭代
# 第5450轮迭代
# 第5451轮迭代
# 第5452轮迭代
# 第5453轮迭代
# 第5454轮迭代
# 第5455轮迭代
# 第5456轮迭代
# ...
# 第8224轮迭代
# 第8225轮迭代
# 第8226轮迭代
# 第8227轮迭代
# 第8228轮迭代
# 第8229轮迭代
# 第8230轮迭代
# 第8231轮迭代
# 第8232轮迭代
# 第8233轮迭代
# 第8234轮迭代
# 第8235轮迭代
# 第8236轮迭代
# 第8237轮迭代
# 第8238轮迭代
# 第8239轮迭代
# 第8240轮迭代
# 第8241轮迭代
# 第8242轮迭代
# 第8243轮迭代
# 第8244轮迭代
# 第8245轮迭代
# 第8246轮迭代
# 第8247轮迭代
# 第8248轮迭代
# 第8249轮迭代
# 第8250轮迭代
# 第8251轮迭代
# 第8252轮迭代
# 第8253轮迭代
# 第8254轮迭代
# 第8255轮迭代
# 第8256轮迭代
# 第8257轮迭代
# 第8258轮迭代
# 第8259轮迭代
# 第8260轮迭代
# 第8261轮迭代
# 第8262轮迭代
# 第8263轮迭代
# 第8264轮迭代
# 第8265轮迭代
# 第8266轮迭代
# 第8267轮迭代
# 第8268轮迭代
# 第8269轮迭代
# 第8270轮迭代
# 第8271轮迭代
# 第8272轮迭代
# 第8273轮迭代
# 第8274轮迭代
# 第8275轮迭代
# 第8276轮迭代
# 第8277轮迭代
# 第8278轮迭代
# 第8279轮迭代
# 第8280轮迭代
# 第8281轮迭代
# 第8282轮迭代
# 第8283轮迭代
# 第8284轮迭代
# 第8285轮迭代
# 第8286轮迭代
# 第8287轮迭代
# 第8288轮迭代
# 第8289轮迭代
# 第8290轮迭代
# 第8291轮迭代
# 第8292轮迭代
# 第8293轮迭代
# 第8294轮迭代
# 第8295轮迭代
# 第8296轮迭代
# 第8297轮迭代
# 第8298轮迭代
# 第8299轮迭代
# 第8300轮迭代
# 第8301轮迭代
# 第8302轮迭代
# 第8303轮迭代
# 第8304轮迭代
# 第8305轮迭代
# 第8306轮迭代
# 第8307轮迭代
# 第8308轮迭代
# 第8309轮迭代
# 第8310轮迭代
# 第8311轮迭代
# 第8312轮迭代
# 第8313轮迭代
# 第8314轮迭代
# 第8315轮迭代
# 第8316轮迭代
# 第8317轮迭代
# 第8318轮迭代
# 第8319轮迭代
# 第8320轮迭代
# 第8321轮迭代
# 第8322轮迭代
# 第8323轮迭代
# 第8324轮迭代
# 第8325轮迭代
# 第8326轮迭代
# 第8327轮迭代
# 第8328轮迭代
# 第8329轮迭代
# 第8330轮迭代
# 第8331轮迭代
# 第8332轮迭代
# 第8333轮迭代
# 第8334轮迭代
# 第8335轮迭代
# 第8336轮迭代
# 第8337轮迭代
# 第8338轮迭代
# 第8339轮迭代
# 第8340轮迭代
# 第8341轮迭代
# 第8342轮迭代
# 第8343轮迭代
# 第8344轮迭代
# 第8345轮迭代
# 第8346轮迭代
# 第8347轮迭代
# 第8348轮迭代
# 第8349轮迭代
# 第8350轮迭代
# 第8351轮迭代
# 第8352轮迭代
# 第8353轮迭代
# 第8354轮迭代
# 第8355轮迭代
# 第8356轮迭代
# 第8357轮迭代
# 第8358轮迭代
# 第8359轮迭代
# 第8360轮迭代
# 第8361轮迭代
# 第8362轮迭代
# 第8363轮迭代
# 第8364轮迭代
# 第8365轮迭代
# 第8366轮迭代
# 第8367轮迭代
# 第8368轮迭代
# 第8369轮迭代
# 第8370轮迭代
# 第8371轮迭代
# 第8372轮迭代
# 第8373轮迭代
# 第8374轮迭代
# 第8375轮迭代
# 第8376轮迭代
# 第8377轮迭代
# 第8378轮迭代
# 第8379轮迭代
# 第8380轮迭代
# 第8381轮迭代
# 第8382轮迭代
# 第8383轮迭代
# 第8384轮迭代
# 第8385轮迭代
# 第8386轮迭代
# 第8387轮迭代
# 第8388轮迭代
# 第8389轮迭代
# 第8390轮迭代
# 第8391轮迭代
# 第8392轮迭代
# 第8393轮迭代
# 第8394轮迭代
# 第8395轮迭代
# 第8396轮迭代
# 第8397轮迭代
# 第8398轮迭代
# 第8399轮迭代
# 第8400轮迭代
# 第8401轮迭代
# 第8402轮迭代
# 第8403轮迭代
# 第8404轮迭代
# 第8405轮迭代
# 第8406轮迭代
# 第8407轮迭代
# 第8408轮迭代
# 第8409轮迭代
# 第8410轮迭代
# 第8411轮迭代
# 第8412轮迭代
# 第8413轮迭代
# 第8414轮迭代
# 第8415轮迭代
# 第8416轮迭代
# 第8417轮迭代
# 第8418轮迭代
# 第8419轮迭代
# 第8420轮迭代
# 第8421轮迭代
# 第8422轮迭代
# 第8423轮迭代
# 第8424轮迭代
# 第8425轮迭代
# 第8426轮迭代
# 第8427轮迭代
# 第8428轮迭代
# 第8429轮迭代
# 第8430轮迭代
# 第8431轮迭代
# 第8432轮迭代
# 第8433轮迭代
# 第8434轮迭代
# 第8435轮迭代
# 第8436轮迭代
# 第8437轮迭代
# 第8438轮迭代
# 第8439轮迭代
# 第8440轮迭代
# 第8441轮迭代
# 第8442轮迭代
# 第8443轮迭代
# 第8444轮迭代
# 第8445轮迭代
# 第8446轮迭代
# 第8447轮迭代
# 第8448轮迭代
# 第8449轮迭代
# 第8450轮迭代
# 第8451轮迭代
# 第8452轮迭代
# 第8453轮迭代
# 第8454轮迭代
# 第8455轮迭代
# 第8456轮迭代
# 第8457轮迭代
# 第8458轮迭代
# 第8459轮迭代
# 第8460轮迭代
# 第8461轮迭代
# 第8462轮迭代
# 第8463轮迭代
# 第8464轮迭代
# 第8465轮迭代
# 第8466轮迭代
# 第8467轮迭代
# 第8468轮迭代
# 第8469轮迭代
# 第8470轮迭代
# 第8471轮迭代
# 第8472轮迭代
# 第8473轮迭代
# 第8474轮迭代
# 第8475轮迭代
# 第8476轮迭代
# 第8477轮迭代
# 第8478轮迭代
# 第8479轮迭代
# 第8480轮迭代
# 第8481轮迭代
# 第8482轮迭代
# 第8483轮迭代
# 第8484轮迭代
# 第8485轮迭代
# 第8486轮迭代
# 第8487轮迭代
# 第8488轮迭代
# 第8489轮迭代
# 第8490轮迭代
# 第8491轮迭代
# 第8492轮迭代
# 第8493轮迭代
# 第8494轮迭代
# 第8495轮迭代
# 第8496轮迭代
# 第8497轮迭代
# 第8498轮迭代
# 第8499轮迭代
# 第8500轮迭代
# 第8501轮迭代
# 第8502轮迭代
# 第8503轮迭代
# 第8504轮迭代
# 第8505轮迭代
# 第8506轮迭代
# 第8507轮迭代
# 第8508轮迭代
# 第8509轮迭代
# 第8510轮迭代
# 第8511轮迭代
# 第8512轮迭代
# 第8513轮迭代
# 第8514轮迭代
# 第8515轮迭代
# 第8516轮迭代
# 第8517轮迭代
# 第8518轮迭代
# 第8519轮迭代
# 第8520轮迭代
# 第8521轮迭代
# 第8522轮迭代
# 第8523轮迭代
# 第8524轮迭代
# 第8525轮迭代
# 第8526轮迭代
# 第8527轮迭代
# 第8528轮迭代
# 第8529轮迭代
# 第8530轮迭代
# 第8531轮迭代
# 第8532轮迭代
# 第8533轮迭代
# 第8534轮迭代
# 第8535轮迭代
# 第8536轮迭代
# 第8537轮迭代
# 第8538轮迭代
# 第8539轮迭代
# 第8540轮迭代
# 第8541轮迭代
# 第8542轮迭代
# 第8543轮迭代
# 第8544轮迭代
# 第8545轮迭代
# 第8546轮迭代
# 第8547轮迭代
# 第8548轮迭代
# 第8549轮迭代
# 第8550轮迭代
# 第8551轮迭代
# 第8552轮迭代
# 第8553轮迭代
# 第8554轮迭代
# 第8555轮迭代
# 第8556轮迭代
# 第8557轮迭代
# 第8558轮迭代
# 第8559轮迭代
# 第8560轮迭代
# 第8561轮迭代
# 第8562轮迭代
# 第8563轮迭代
# 第8564轮迭代
# 第8565轮迭代
# 第8566轮迭代
# 第8567轮迭代
# 第8568轮迭代
# 第8569轮迭代
# 第8570轮迭代
# 第8571轮迭代
# 第8572轮迭代
# 第8573轮迭代
# 第8574轮迭代
# 第8575轮迭代
# 第8576轮迭代
# 第8577轮迭代
# 第8578轮迭代
# 第8579轮迭代
# 第8580轮迭代
# 第8581轮迭代
# 第8582轮迭代
# 第8583轮迭代
# 第8584轮迭代
# 第8585轮迭代
# 第8586轮迭代
# 第8587轮迭代
# 第8588轮迭代
# 第8589轮迭代
# 第8590轮迭代
# 第8591轮迭代
# 第8592轮迭代
# 第8593轮迭代
# 第8594轮迭代
# 第8595轮迭代
# 第8596轮迭代
# 第8597轮迭代
# 第8598轮迭代
# 第8599轮迭代
# 第8600轮迭代
# 第8601轮迭代
# 第8602轮迭代
# 第8603轮迭代
# 第8604轮迭代
# 第8605轮迭代
# 第8606轮迭代
# 第8607轮迭代
# 第8608轮迭代
# 第8609轮迭代
# 第8610轮迭代
# 第8611轮迭代
# 第8612轮迭代
# 第8613轮迭代
# 第8614轮迭代
# 第8615轮迭代
# 第8616轮迭代
# 第8617轮迭代
# 第8618轮迭代
# 第8619轮迭代
# 第8620轮迭代
# 第8621轮迭代
# 第8622轮迭代
# 第8623轮迭代
# 第8624轮迭代
# 第8625轮迭代
# 第8626轮迭代
# 第8627轮迭代
# 第8628轮迭代
# 第8629轮迭代
# 第8630轮迭代
# 第8631轮迭代
# 第8632轮迭代
# 第8633轮迭代
# 第8634轮迭代
# 第8635轮迭代
# 第8636轮迭代
# 第8637轮迭代
# 第8638轮迭代
# 第8639轮迭代
# 第8640轮迭代
# 第8641轮迭代
# 第8642轮迭代
# 第8643轮迭代
# 第8644轮迭代
# 第8645轮迭代
# 第8646轮迭代
# 第8647轮迭代
# 第8648轮迭代
# 第8649轮迭代
# 第8650轮迭代
# 第8651轮迭代
# 第8652轮迭代
# 第8653轮迭代
# 第8654轮迭代
# 第8655轮迭代
# 第8656轮迭代
# 第8657轮迭代
# 第8658轮迭代
# 第8659轮迭代
# 第8660轮迭代
# 第8661轮迭代
# 第8662轮迭代
# 第8663轮迭代
# 第8664轮迭代
# 第8665轮迭代
# 第8666轮迭代
# 第8667轮迭代
# 第8668轮迭代
# 第8669轮迭代
# 第8670轮迭代
# 第8671轮迭代
# 第8672轮迭代
# 第8673轮迭代
# 第8674轮迭代
# 第8675轮迭代
# 第8676轮迭代
# 第8677轮迭代
# 第8678轮迭代
# 第8679轮迭代
# 第8680轮迭代
# 第8681轮迭代
# 第8682轮迭代
# 第8683轮迭代
# 第8684轮迭代
# 第8685轮迭代
# 第8686轮迭代
# 第8687轮迭代
# 第8688轮迭代
# 第8689轮迭代
# 第8690轮迭代
# 第8691轮迭代
# 第8692轮迭代
# 第8693轮迭代
# 第8694轮迭代
# 第8695轮迭代
# 第8696轮迭代
# 第8697轮迭代
# 第8698轮迭代
# 第8699轮迭代
# 第8700轮迭代
# 第8701轮迭代
# 第8702轮迭代
# 第8703轮迭代
# 第8704轮迭代
# 第8705轮迭代
# 第8706轮迭代
# 第8707轮迭代
# 第8708轮迭代
# 第8709轮迭代
# 第8710轮迭代
# 第8711轮迭代
# 第8712轮迭代
# 第8713轮迭代
# 第8714轮迭代
# 第8715轮迭代
# 第8716轮迭代
# 第8717轮迭代
# 第8718轮迭代
# 第8719轮迭代
# 第8720轮迭代
# 第8721轮迭代
# 第8722轮迭代
# 第8723轮迭代
# 第8724轮迭代
# 第8725轮迭代
# 第8726轮迭代
# 第8727轮迭代
# 第8728轮迭代
# 第8729轮迭代
# 第8730轮迭代
# 第8731轮迭代
# 第8732轮迭代
# 第8733轮迭代
# 第8734轮迭代
# 第8735轮迭代
# 第8736轮迭代
# 第8737轮迭代
# 第8738轮迭代
# 第8739轮迭代
# 第8740轮迭代
# 第8741轮迭代
# 第8742轮迭代
# 第8743轮迭代
# 第8744轮迭代
# 第8745轮迭代
# 第8746轮迭代
# 第8747轮迭代
# 第8748轮迭代
# 第8749轮迭代
# 第8750轮迭代
# 第8751轮迭代
# 第8752轮迭代
# 第8753轮迭代
# 第8754轮迭代
# 第8755轮迭代
# 第8756轮迭代
# 第8757轮迭代
# 第8758轮迭代
# 第8759轮迭代
# 第8760轮迭代
# 第8761轮迭代
# 第8762轮迭代
# 第8763轮迭代
# 第8764轮迭代
# 第8765轮迭代
# 第8766轮迭代
# 第8767轮迭代
# 第8768轮迭代
# 第8769轮迭代
# 第8770轮迭代
# 第8771轮迭代
# 第8772轮迭代
# 第8773轮迭代
# 第8774轮迭代
# 第8775轮迭代
# 第8776轮迭代
# 第8777轮迭代
# 第8778轮迭代
# 第8779轮迭代
# 第8780轮迭代
# 第8781轮迭代
# 第8782轮迭代
# 第8783轮迭代
# 第8784轮迭代
# 第8785轮迭代
# 第8786轮迭代
# 第8787轮迭代
# 第8788轮迭代
# 第8789轮迭代
# 第8790轮迭代
# 第8791轮迭代
# 第8792轮迭代
# 第8793轮迭代
# 第8794轮迭代
# 第8795轮迭代
# 第8796轮迭代
# 第8797轮迭代
# 第8798轮迭代
# 第8799轮迭代
# 第8800轮迭代
# 第8801轮迭代
# 第8802轮迭代
# 第8803轮迭代
# 第8804轮迭代
# 第8805轮迭代
# 第8806轮迭代
# 第8807轮迭代
# 第8808轮迭代
# 第8809轮迭代
# 第8810轮迭代
# 第8811轮迭代
# 第8812轮迭代
# 第8813轮迭代
# 第8814轮迭代
# 第8815轮迭代
# 第8816轮迭代
# 第8817轮迭代
# 第8818轮迭代
# 第8819轮迭代
# 第8820轮迭代
# 第8821轮迭代
# 第8822轮迭代
# 第8823轮迭代
# 第8824轮迭代
# 第8825轮迭代
# 第8826轮迭代
# 第8827轮迭代
# 第8828轮迭代
# 第8829轮迭代
# 第8830轮迭代
# 第8831轮迭代
# 第8832轮迭代
# 第8833轮迭代
# 第8834轮迭代
# 第8835轮迭代
# 第8836轮迭代
# 第8837轮迭代
# 第8838轮迭代
# 第8839轮迭代
# 第8840轮迭代
# 第8841轮迭代
# 第8842轮迭代
# 第8843轮迭代
# 第8844轮迭代
# 第8845轮迭代
# 第8846轮迭代
# 第8847轮迭代
# 第8848轮迭代
# 第8849轮迭代
# 第8850轮迭代
# 第8851轮迭代
# 第8852轮迭代
# 第8853轮迭代
# 第8854轮迭代
# 第8855轮迭代
# 第8856轮迭代
# 第8857轮迭代
# 第8858轮迭代
# 第8859轮迭代
# 第8860轮迭代
# 第8861轮迭代
# 第8862轮迭代
# 第8863轮迭代
# 第8864轮迭代
# 第8865轮迭代
# 第8866轮迭代
# 第8867轮迭代
# 第8868轮迭代
# 第8869轮迭代
# 第8870轮迭代
# 第8871轮迭代
# 第8872轮迭代
# 第8873轮迭代
# 第8874轮迭代
# 第8875轮迭代
# 第8876轮迭代
# 第8877轮迭代
# 第8878轮迭代
# 第8879轮迭代
# 第8880轮迭代
# 第8881轮迭代
# 第8882轮迭代
# 第8883轮迭代
# 第8884轮迭代
# 第8885轮迭代
# 第8886轮迭代
# 第8887轮迭代
# 第8888轮迭代
# 第8889轮迭代
# 第8890轮迭代
# 第8891轮迭代
# 第8892轮迭代
# 第8893轮迭代
# 第8894轮迭代
# 第8895轮迭代
# 第8896轮迭代
# 第8897轮迭代
# 第8898轮迭代
# 第8899轮迭代
# 第8900轮迭代
# 第8901轮迭代
# 第8902轮迭代
# 第8903轮迭代
# 第8904轮迭代
# 第8905轮迭代
# 第8906轮迭代
# 第8907轮迭代
# 第8908轮迭代
# 第8909轮迭代
# 第8910轮迭代
# 第8911轮迭代
# 第8912轮迭代
# 第8913轮迭代
# 第8914轮迭代
# 第8915轮迭代
# 第8916轮迭代
# 第8917轮迭代
# 第8918轮迭代
# 第8919轮迭代
# 第8920轮迭代
# 第8921轮迭代
# 第8922轮迭代
# 第8923轮迭代
# 第8924轮迭代
# 第8925轮迭代
# 第8926轮迭代
# 第8927轮迭代
# 第8928轮迭代
# 第8929轮迭代
# 第8930轮迭代
# 第8931轮迭代
# 第8932轮迭代
# 第8933轮迭代
# 第8934轮迭代
# 第8935轮迭代
# 第8936轮迭代
# 第8937轮迭代
# 第8938轮迭代
# 第8939轮迭代
# 第8940轮迭代
# 第8941轮迭代
# 第8942轮迭代
# 第8943轮迭代
# 第8944轮迭代
# 第8945轮迭代
# 第8946轮迭代
# 第8947轮迭代
# 第8948轮迭代
# 第8949轮迭代
# 第8950轮迭代
# 第8951轮迭代
# 第8952轮迭代
# 第8953轮迭代
# 第8954轮迭代
# 第8955轮迭代
# 第8956轮迭代
# 第8957轮迭代
# 第8958轮迭代
# 第8959轮迭代
# 第8960轮迭代
# 第8961轮迭代
# 第8962轮迭代
# 第8963轮迭代
# 第8964轮迭代
# 第8965轮迭代
# 第8966轮迭代
# 第8967轮迭代
# 第8968轮迭代
# 第8969轮迭代
# 第8970轮迭代
# 第8971轮迭代
# 第8972轮迭代
# 第8973轮迭代
# 第8974轮迭代
# 第8975轮迭代
# 第8976轮迭代
# 第8977轮迭代
# 第8978轮迭代
# 第8979轮迭代
# 第8980轮迭代
# 第8981轮迭代
# 第8982轮迭代
# 第8983轮迭代
# 第8984轮迭代
# 第8985轮迭代
# 第8986轮迭代
# 第8987轮迭代
# 第8988轮迭代
# 第8989轮迭代
# 第8990轮迭代
# 第8991轮迭代
# 第8992轮迭代
# 第8993轮迭代
# 第8994轮迭代
# 第8995轮迭代
# 第8996轮迭代
# 第8997轮迭代
# 第8998轮迭代
# 第8999轮迭代
# 第9000轮迭代
# 第9001轮迭代
# 第9002轮迭代
# 第9003轮迭代
# 第9004轮迭代
# 第9005轮迭代
# 第9006轮迭代
# 第9007轮迭代
# 第9008轮迭代
# 第9009轮迭代
# 第9010轮迭代
# 第9011轮迭代
# 第9012轮迭代
# 第9013轮迭代
# 第9014轮迭代
# 第9015轮迭代
# 第9016轮迭代
# 第9017轮迭代
# 第9018轮迭代
# 第9019轮迭代
# 第9020轮迭代
# 第9021轮迭代
# 第9022轮迭代
# 第9023轮迭代
# 第9024轮迭代
# 第9025轮迭代
# 第9026轮迭代
# 第9027轮迭代
# 第9028轮迭代
# 第9029轮迭代
# 第9030轮迭代
# 第9031轮迭代
# 第9032轮迭代
# 第9033轮迭代
# 第9034轮迭代
# 第9035轮迭代
# 第9036轮迭代
# 第9037轮迭代
# 第9038轮迭代
# 第9039轮迭代
# 第9040轮迭代
# 第9041轮迭代
# 第9042轮迭代
# 第9043轮迭代
# 第9044轮迭代
# 第9045轮迭代
# 第9046轮迭代
# 第9047轮迭代
# 第9048轮迭代
# 第9049轮迭代
# 第9050轮迭代
# 第9051轮迭代
# 第9052轮迭代
# 第9053轮迭代
# 第9054轮迭代
# 第9055轮迭代
# 第9056轮迭代
# 第9057轮迭代
# 第9058轮迭代
# 第9059轮迭代
# 第9060轮迭代
# 第9061轮迭代
# 第9062轮迭代
# 第9063轮迭代
# 第9064轮迭代
# 第9065轮迭代
# 第9066轮迭代
# 第9067轮迭代
# 第9068轮迭代
# 第9069轮迭代
# 第9070轮迭代
# 第9071轮迭代
# 第9072轮迭代
# 第9073轮迭代
# 第9074轮迭代
# 第9075轮迭代
# 第9076轮迭代
# 第9077轮迭代
# 第9078轮迭代
# 第9079轮迭代
# 第9080轮迭代
# 第9081轮迭代
# 第9082轮迭代
# 第9083轮迭代
# 第9084轮迭代
# 第9085轮迭代
# 第9086轮迭代
# 第9087轮迭代
# 第9088轮迭代
# 第9089轮迭代
# 第9090轮迭代
# 第9091轮迭代
# 第9092轮迭代
# 第9093轮迭代
# 第9094轮迭代
# 第9095轮迭代
# 第9096轮迭代
# 第9097轮迭代
# 第9098轮迭代
# 第9099轮迭代
# 第9100轮迭代
# 第9101轮迭代
# 第9102轮迭代
# 第9103轮迭代
# 第9104轮迭代
# 第9105轮迭代
# 第9106轮迭代
# 第9107轮迭代
# 第9108轮迭代
# 第9109轮迭代
# 第9110轮迭代
# 第9111轮迭代
# 第9112轮迭代
# 第9113轮迭代
# 第9114轮迭代
# 第9115轮迭代
# 第9116轮迭代
# 第9117轮迭代
# 第9118轮迭代
# 第9119轮迭代
# 第9120轮迭代
# 第9121轮迭代
# 第9122轮迭代
# 第9123轮迭代
# 第9124轮迭代
# 第9125轮迭代
# 第9126轮迭代
# 第9127轮迭代
# 第9128轮迭代
# 第9129轮迭代
# 第9130轮迭代
# 第9131轮迭代
# 第9132轮迭代
# 第9133轮迭代
# 第9134轮迭代
# 第9135轮迭代
# 第9136轮迭代
# 第9137轮迭代
# 第9138轮迭代
# 第9139轮迭代
# 第9140轮迭代
# 第9141轮迭代
# 第9142轮迭代
# 第9143轮迭代
# 第9144轮迭代
# 第9145轮迭代
# 第9146轮迭代
# 第9147轮迭代
# 第9148轮迭代
# 第9149轮迭代
# 第9150轮迭代
# 第9151轮迭代
# 第9152轮迭代
# 第9153轮迭代
# 第9154轮迭代
# 第9155轮迭代
# 第9156轮迭代
# 第9157轮迭代
# 第9158轮迭代
# 第9159轮迭代
# 第9160轮迭代
# 第9161轮迭代
# 第9162轮迭代
# 第9163轮迭代
# 第9164轮迭代
# 第9165轮迭代
# 第9166轮迭代
# 第9167轮迭代
# 第9168轮迭代
# 第9169轮迭代
# 第9170轮迭代
# 第9171轮迭代
# 第9172轮迭代
# 第9173轮迭代
# 第9174轮迭代
# 第9175轮迭代
# 第9176轮迭代
# 第9177轮迭代
# 第9178轮迭代
# 第9179轮迭代
# 第9180轮迭代
# 第9181轮迭代
# 第9182轮迭代
# 第9183轮迭代
# 第9184轮迭代
# 第9185轮迭代
# 第9186轮迭代
# 第9187轮迭代
# 第9188轮迭代
# 第9189轮迭代
# 第9190轮迭代
# 第9191轮迭代
# 第9192轮迭代
# 第9193轮迭代
# 第9194轮迭代
# 第9195轮迭代
# 第9196轮迭代
# 第9197轮迭代
# 第9198轮迭代
# 第9199轮迭代
# 第9200轮迭代
# 第9201轮迭代
# 第9202轮迭代
# 第9203轮迭代
# 第9204轮迭代
# 第9205轮迭代
# 第9206轮迭代
# 第9207轮迭代
# 第9208轮迭代
# 第9209轮迭代
# 第9210轮迭代
# 第9211轮迭代
# 第9212轮迭代
# 第9213轮迭代
# 第9214轮迭代
# 第9215轮迭代
# 第9216轮迭代
# 第9217轮迭代
# 第9218轮迭代
# 第9219轮迭代
# 第9220轮迭代
# 第9221轮迭代
# 第9222轮迭代
# 第9223轮迭代
# 第9224轮迭代
# 第9225轮迭代
# 第9226轮迭代
# 第9227轮迭代
# 第9228轮迭代
# 第9229轮迭代
# 第9230轮迭代
# 第9231轮迭代
# 第9232轮迭代
# 第9233轮迭代
# 第9234轮迭代
# 第9235轮迭代
# 第9236轮迭代
# 第9237轮迭代
# 第9238轮迭代
# 第9239轮迭代
# 第9240轮迭代
# 第9241轮迭代
# 第9242轮迭代
# 第9243轮迭代
# 第9244轮迭代
# 第9245轮迭代
# 第9246轮迭代
# 第9247轮迭代
# 第9248轮迭代
# 第9249轮迭代
# 第9250轮迭代
# 第9251轮迭代
# 第9252轮迭代
# 第9253轮迭代
# 第9254轮迭代
# 第9255轮迭代
# 第9256轮迭代
# 第9257轮迭代
# 第9258轮迭代
# 第9259轮迭代
# 第9260轮迭代
# 第9261轮迭代
# 第9262轮迭代
# 第9263轮迭代
# 第9264轮迭代
# 第9265轮迭代
# 第9266轮迭代
# 第9267轮迭代
# 第9268轮迭代
# 第9269轮迭代
# 第9270轮迭代
# 第9271轮迭代
# 第9272轮迭代
# 第9273轮迭代
# 第9274轮迭代
# 第9275轮迭代
# 第9276轮迭代
# 第9277轮迭代
# 第9278轮迭代
# 第9279轮迭代
# 第9280轮迭代
# 第9281轮迭代
# 第9282轮迭代
# 第9283轮迭代
# 第9284轮迭代
# 第9285轮迭代
# 第9286轮迭代
# 第9287轮迭代
# 第9288轮迭代
# 第9289轮迭代
# 第9290轮迭代
# 第9291轮迭代
# 第9292轮迭代
# 第9293轮迭代
# 第9294轮迭代
# 第9295轮迭代
# 第9296轮迭代
# 第9297轮迭代
# 第9298轮迭代
# 第9299轮迭代
# 第9300轮迭代
# 第9301轮迭代
# 第9302轮迭代
# 第9303轮迭代
# 第9304轮迭代
# 第9305轮迭代
# 第9306轮迭代
# 第9307轮迭代
# 第9308轮迭代
# 第9309轮迭代
# 第9310轮迭代
# 第9311轮迭代
# 第9312轮迭代
# 第9313轮迭代
# 第9314轮迭代
# 第9315轮迭代
# 第9316轮迭代
# 第9317轮迭代
# 第9318轮迭代
# 第9319轮迭代
# 第9320轮迭代
# 第9321轮迭代
# 第9322轮迭代
# 第9323轮迭代
# 第9324轮迭代
# 第9325轮迭代
# 第9326轮迭代
# 第9327轮迭代
# 第9328轮迭代
# 第9329轮迭代
# 第9330轮迭代
# 第9331轮迭代
# 第9332轮迭代
# 第9333轮迭代
# 第9334轮迭代
# 第9335轮迭代
# 第9336轮迭代
# 第9337轮迭代
# 第9338轮迭代
# 第9339轮迭代
# 第9340轮迭代
# 第9341轮迭代
# 第9342轮迭代
# 第9343轮迭代
# 第9344轮迭代
# 第9345轮迭代
# 第9346轮迭代
# 第9347轮迭代
# 第9348轮迭代
# 第9349轮迭代
# 第9350轮迭代
# 第9351轮迭代
# 第9352轮迭代
# 第9353轮迭代
# 第9354轮迭代
# 第9355轮迭代
# 第9356轮迭代
# 第9357轮迭代
# 第9358轮迭代
# 第9359轮迭代
# 第9360轮迭代
# 第9361轮迭代
# 第9362轮迭代
# 第9363轮迭代
# 第9364轮迭代
# 第9365轮迭代
# 第9366轮迭代
# 第9367轮迭代
# 第9368轮迭代
# 第9369轮迭代
# 第9370轮迭代
# 第9371轮迭代
# 第9372轮迭代
# 第9373轮迭代
# 第9374轮迭代
# 第9375轮迭代
# 第9376轮迭代
# 第9377轮迭代
# 第9378轮迭代
# 第9379轮迭代
# 第9380轮迭代
# 第9381轮迭代
# 第9382轮迭代
# 第9383轮迭代
# 第9384轮迭代
# 第9385轮迭代
# 第9386轮迭代
# 第9387轮迭代
# 第9388轮迭代
# 第9389轮迭代
# 第9390轮迭代
# 第9391轮迭代
# 第9392轮迭代
# 第9393轮迭代
# 第9394轮迭代
# 第9395轮迭代
# 第9396轮迭代
# 第9397轮迭代
# 第9398轮迭代
# 第9399轮迭代
# 第9400轮迭代
# 第9401轮迭代
# 第9402轮迭代
# 第9403轮迭代
# 第9404轮迭代
# 第9405轮迭代
# 第9406轮迭代
# 第9407轮迭代
# 第9408轮迭代
# 第9409轮迭代
# 第9410轮迭代
# 第9411轮迭代
# 第9412轮迭代
# 第9413轮迭代
# 第9414轮迭代
# 第9415轮迭代
# 第9416轮迭代
# 第9417轮迭代
# 第9418轮迭代
# 第9419轮迭代
# 第9420轮迭代
# 第9421轮迭代
# 第9422轮迭代
# 第9423轮迭代
# 第9424轮迭代
# 第9425轮迭代
# 第9426轮迭代
# 第9427轮迭代
# 第9428轮迭代
# 第9429轮迭代
# 第9430轮迭代
# 第9431轮迭代
# 第9432轮迭代
# 第9433轮迭代
# 第9434轮迭代
# 第9435轮迭代
# 第9436轮迭代
# 第9437轮迭代
# 第9438轮迭代
# 第9439轮迭代
# 第9440轮迭代
# 第9441轮迭代
# 第9442轮迭代
# 第9443轮迭代
# 第9444轮迭代
# 第9445轮迭代
# 第9446轮迭代
# 第9447轮迭代
# 第9448轮迭代
# 第9449轮迭代
# 第9450轮迭代
# 第9451轮迭代
# 第9452轮迭代
# 第9453轮迭代
# 第9454轮迭代
# 第9455轮迭代
# 第9456轮迭代
# 第9457轮迭代
# 第9458轮迭代
# 第9459轮迭代
# 第9460轮迭代
# 第9461轮迭代
# 第9462轮迭代
# 第9463轮迭代
# 第9464轮迭代
# 第9465轮迭代
# 第9466轮迭代
# 第9467轮迭代
# 第9468轮迭代
# 第9469轮迭代
# 第9470轮迭代
# 第9471轮迭代
# 第9472轮迭代
# 第9473轮迭代
# 第9474轮迭代
# 第9475轮迭代
# 第9476轮迭代
# 第9477轮迭代
# 第9478轮迭代
# 第9479轮迭代
# 第9480轮迭代
# 第9481轮迭代
# 第9482轮迭代
# 第9483轮迭代
# 第9484轮迭代
# 第9485轮迭代
# 第9486轮迭代
# 第9487轮迭代
# 第9488轮迭代
# 第9489轮迭代
# 第9490轮迭代
# 第9491轮迭代
# 第9492轮迭代
# 第9493轮迭代
# 第9494轮迭代
# 第9495轮迭代
# 第9496轮迭代
# 第9497轮迭代
# 第9498轮迭代
# 第9499轮迭代
# 第9500轮迭代
# 第9501轮迭代
# 第9502轮迭代
# 第9503轮迭代
# 第9504轮迭代
# 第9505轮迭代
# 第9506轮迭代
# 第9507轮迭代
# 第9508轮迭代
# 第9509轮迭代
# 第9510轮迭代
# 第9511轮迭代
# 第9512轮迭代
# 第9513轮迭代
# 第9514轮迭代
# 第9515轮迭代
# 第9516轮迭代
# 第9517轮迭代
# 第9518轮迭代
# 第9519轮迭代
# 第9520轮迭代
# 第9521轮迭代
# 第9522轮迭代
# 第9523轮迭代
# 第9524轮迭代
# 第9525轮迭代
# 第9526轮迭代
# 第9527轮迭代
# 第9528轮迭代
# 第9529轮迭代
# 第9530轮迭代
# 第9531轮迭代
# 第9532轮迭代
# 第9533轮迭代
# 第9534轮迭代
# 第9535轮迭代
# 第9536轮迭代
# 第9537轮迭代
# 第9538轮迭代
# 第9539轮迭代
# 第9540轮迭代
# 第9541轮迭代
# 第9542轮迭代
# 第9543轮迭代
# 第9544轮迭代
# 第9545轮迭代
# 第9546轮迭代
# 第9547轮迭代
# 第9548轮迭代
# 第9549轮迭代
# 第9550轮迭代
# 第9551轮迭代
# 第9552轮迭代
# 第9553轮迭代
# 第9554轮迭代
# 第9555轮迭代
# 第9556轮迭代
# 第9557轮迭代
# 第9558轮迭代
# 第9559轮迭代
# 第9560轮迭代
# 第9561轮迭代
# 第9562轮迭代
# 第9563轮迭代
# 第9564轮迭代
# 第9565轮迭代
# 第9566轮迭代
# 第9567轮迭代
# 第9568轮迭代
# 第9569轮迭代
# 第9570轮迭代
# 第9571轮迭代
# 第9572轮迭代
# 第9573轮迭代
# 第9574轮迭代
# 第9575轮迭代
# 第9576轮迭代
# 第9577轮迭代
# 第9578轮迭代
# 第9579轮迭代
# 第9580轮迭代
# 第9581轮迭代
# 第9582轮迭代
# 第9583轮迭代
# 第9584轮迭代
# 第9585轮迭代
# 第9586轮迭代
# 第9587轮迭代
# 第9588轮迭代
# 第9589轮迭代
# 第9590轮迭代
# 第9591轮迭代
# 第9592轮迭代
# 第9593轮迭代
# 第9594轮迭代
# 第9595轮迭代
# 第9596轮迭代
# 第9597轮迭代
# 第9598轮迭代
# 第9599轮迭代
# 第9600轮迭代
# 第9601轮迭代
# 第9602轮迭代
# 第9603轮迭代
# 第9604轮迭代
# 第9605轮迭代
# 第9606轮迭代
# 第9607轮迭代
# 第9608轮迭代
# 第9609轮迭代
# 第9610轮迭代
# 第9611轮迭代
# 第9612轮迭代
# 第9613轮迭代
# 第9614轮迭代
# 第9615轮迭代
# 第9616轮迭代
# 第9617轮迭代
# 第9618轮迭代
# 第9619轮迭代
# 第9620轮迭代
# 第9621轮迭代
# 第9622轮迭代
# 第9623轮迭代
# 第9624轮迭代
# 第9625轮迭代
# 第9626轮迭代
# 第9627轮迭代
# 第9628轮迭代
# 第9629轮迭代
# 第9630轮迭代
# 第9631轮迭代
# 第9632轮迭代
# 第9633轮迭代
# 第9634轮迭代
# 第9635轮迭代
# 第9636轮迭代
# 第9637轮迭代
# 第9638轮迭代
# 第9639轮迭代
# 第9640轮迭代
# 第9641轮迭代
# 第9642轮迭代
# 第9643轮迭代
# 第9644轮迭代
# 第9645轮迭代
# 第9646轮迭代
# 第9647轮迭代
# 第9648轮迭代
# 第9649轮迭代
# 第9650轮迭代
# 第9651轮迭代
# 第9652轮迭代
# 第9653轮迭代
# 第9654轮迭代
# 第9655轮迭代
# 第9656轮迭代
# 第9657轮迭代
# 第9658轮迭代
# 第9659轮迭代
# 第9660轮迭代
# 第9661轮迭代
# 第9662轮迭代
# 第9663轮迭代
# 第9664轮迭代
# 第9665轮迭代
# 第9666轮迭代
# 第9667轮迭代
# 第9668轮迭代
# 第9669轮迭代
# 第9670轮迭代
# 第9671轮迭代
# 第9672轮迭代
# 第9673轮迭代
# 第9674轮迭代
# 第9675轮迭代
# 第9676轮迭代
# 第9677轮迭代
# 第9678轮迭代
# 第9679轮迭代
# 第9680轮迭代
# 第9681轮迭代
# 第9682轮迭代
# 第9683轮迭代
# 第9684轮迭代
# 第9685轮迭代
# 第9686轮迭代
# 第9687轮迭代
# 第9688轮迭代
# 第9689轮迭代
# 第9690轮迭代
# 第9691轮迭代
# 第9692轮迭代
# 第9693轮迭代
# 第9694轮迭代
# 第9695轮迭代
# 第9696轮迭代
# 第9697轮迭代
# 第9698轮迭代
# 第9699轮迭代
# 第9700轮迭代
# 第9701轮迭代
# 第9702轮迭代
# 第9703轮迭代
# 第9704轮迭代
# 第9705轮迭代
# 第9706轮迭代
# 第9707轮迭代
# 第9708轮迭代
# 第9709轮迭代
# 第9710轮迭代
# 第9711轮迭代
# 第9712轮迭代
# 第9713轮迭代
# 第9714轮迭代
# 第9715轮迭代
# 第9716轮迭代
# 第9717轮迭代
# 第9718轮迭代
# 第9719轮迭代
# 第9720轮迭代
# 第9721轮迭代
# 第9722轮迭代
# 第9723轮迭代
# 第9724轮迭代
# 第9725轮迭代
# 第9726轮迭代
# 第9727轮迭代
# 第9728轮迭代
# 第9729轮迭代
# 第9730轮迭代
# 第9731轮迭代
# 第9732轮迭代
# 第9733轮迭代
# 第9734轮迭代
# 第9735轮迭代
# 第9736轮迭代
# 第9737轮迭代
# 第9738轮迭代
# 第9739轮迭代
# 第9740轮迭代
# 第9741轮迭代
# 第9742轮迭代
# 第9743轮迭代
# 第9744轮迭代
# 第9745轮迭代
# 第9746轮迭代
# 第9747轮迭代
# 第9748轮迭代
# 第9749轮迭代
# 第9750轮迭代
# 第9751轮迭代
# 第9752轮迭代
# 第9753轮迭代
# 第9754轮迭代
# 第9755轮迭代
# 第9756轮迭代
# 第9757轮迭代
# 第9758轮迭代
# 第9759轮迭代
# 第9760轮迭代
# 第9761轮迭代
# 第9762轮迭代
# 第9763轮迭代
# 第9764轮迭代
# 第9765轮迭代
# 第9766轮迭代
# 第9767轮迭代
# 第9768轮迭代
# 第9769轮迭代
# 第9770轮迭代
# 第9771轮迭代
# 第9772轮迭代
# 第9773轮迭代
# 第9774轮迭代
# 第9775轮迭代
# 第9776轮迭代
# 第9777轮迭代
# 第9778轮迭代
# 第9779轮迭代
# 第9780轮迭代
# 第9781轮迭代
# 第9782轮迭代
# 第9783轮迭代
# 第9784轮迭代
# 第9785轮迭代
# 第9786轮迭代
# 第9787轮迭代
# 第9788轮迭代
# 第9789轮迭代
# 第9790轮迭代
# 第9791轮迭代
# 第9792轮迭代
# 第9793轮迭代
# 第9794轮迭代
# 第9795轮迭代
# 第9796轮迭代
# 第9797轮迭代
# 第9798轮迭代
# 第9799轮迭代
# 第9800轮迭代
# 第9801轮迭代
# 第9802轮迭代
# 第9803轮迭代
# 第9804轮迭代
# 第9805轮迭代
# 第9806轮迭代
# 第9807轮迭代
# 第9808轮迭代
# 第9809轮迭代
# 第9810轮迭代
# 第9811轮迭代
# 第9812轮迭代
# 第9813轮迭代
# 第9814轮迭代
# 第9815轮迭代
# 第9816轮迭代
# 第9817轮迭代
# 第9818轮迭代
# 第9819轮迭代
# 第9820轮迭代
# 第9821轮迭代
# 第9822轮迭代
# 第9823轮迭代
# 第9824轮迭代
# 第9825轮迭代
# 第9826轮迭代
# 第9827轮迭代
# 第9828轮迭代
# 第9829轮迭代
# 第9830轮迭代
# 第9831轮迭代
# 第9832轮迭代
# 第9833轮迭代
# 第9834轮迭代
# 第9835轮迭代
# 第9836轮迭代
# 第9837轮迭代
# 第9838轮迭代
# 第9839轮迭代
# 第9840轮迭代
# 第9841轮迭代
# 第9842轮迭代
# 第9843轮迭代
# 第9844轮迭代
# 第9845轮迭代
# 第9846轮迭代
# 第9847轮迭代
# 第9848轮迭代
# 第9849轮迭代
# 第9850轮迭代
# 第9851轮迭代
# 第9852轮迭代
# 第9853轮迭代
# 第9854轮迭代
# 第9855轮迭代
# 第9856轮迭代
# 第9857轮迭代
# 第9858轮迭代
# 第9859轮迭代
# 第9860轮迭代
# 第9861轮迭代
# 第9862轮迭代
# 第9863轮迭代
# 第9864轮迭代
# 第9865轮迭代
# 第9866轮迭代
# 第9867轮迭代
# 第9868轮迭代
# 第9869轮迭代
# 第9870轮迭代
# 第9871轮迭代
# 第9872轮迭代
# 第9873轮迭代
# 第9874轮迭代
# 第9875轮迭代
# 第9876轮迭代
# 第9877轮迭代
# 第9878轮迭代
# 第9879轮迭代
# 第9880轮迭代
# 第9881轮迭代
# 第9882轮迭代
# 第9883轮迭代
# 第9884轮迭代
# 第9885轮迭代
# 第9886轮迭代
# 第9887轮迭代
# 第9888轮迭代
# 第9889轮迭代
# 第9890轮迭代
# 第9891轮迭代
# 第9892轮迭代
# 第9893轮迭代
# 第9894轮迭代
# 第9895轮迭代
# 第9896轮迭代
# 第9897轮迭代
# 第9898轮迭代
# 第9899轮迭代
# 第9900轮迭代
# 第9901轮迭代
# 第9902轮迭代
# 第9903轮迭代
# 第9904轮迭代
# 第9905轮迭代
# 第9906轮迭代
# 第9907轮迭代
# 第9908轮迭代
# 第9909轮迭代
# 第9910轮迭代
# 第9911轮迭代
# 第9912轮迭代
# 第9913轮迭代
# 第9914轮迭代
# 第9915轮迭代
# 第9916轮迭代
# 第9917轮迭代
# 第9918轮迭代
# 第9919轮迭代
# 第9920轮迭代
# 第9921轮迭代
# 第9922轮迭代
# 第9923轮迭代
# 第9924轮迭代
# 第9925轮迭代
# 第9926轮迭代
# 第9927轮迭代
# 第9928轮迭代
# 第9929轮迭代
# 第9930轮迭代
# 第9931轮迭代
# 第9932轮迭代
# 第9933轮迭代
# 第9934轮迭代
# 第9935轮迭代
# 第9936轮迭代
# 第9937轮迭代
# 第9938轮迭代
# 第9939轮迭代
# 第9940轮迭代
# 第9941轮迭代
# 第9942轮迭代
# 第9943轮迭代
# 第9944轮迭代
# 第9945轮迭代
# 第9946轮迭代
# 第9947轮迭代
# 第9948轮迭代
# 第9949轮迭代
# 第9950轮迭代
# 第9951轮迭代
# 第9952轮迭代
# 第9953轮迭代
# 第9954轮迭代
# 第9955轮迭代
# 第9956轮迭代
# 第9957轮迭代
# 第9958轮迭代
# 第9959轮迭代
# 第9960轮迭代
# 第9961轮迭代
# 第9962轮迭代
# 第9963轮迭代
# 第9964轮迭代
# 第9965轮迭代
# 第9966轮迭代
# 第9967轮迭代
# 第9968轮迭代
# 第9969轮迭代
# 第9970轮迭代
# 第9971轮迭代
# 第9972轮迭代
# 第9973轮迭代
# 第9974轮迭代
# 第9975轮迭代
# 第9976轮迭代
# 第9977轮迭代
# 第9978轮迭代
# 第9979轮迭代
# 第9980轮迭代
# 第9981轮迭代
# 第9982轮迭代
# 第9983轮迭代
# 第9984轮迭代
# 第9985轮迭代
# 第9986轮迭代
# 第9987轮迭代
# 第9988轮迭代
# 第9989轮迭代
# 第9990轮迭代
# 第9991轮迭代
# 第9992轮迭代
# 第9993轮迭代
# 第9994轮迭代
# 第9995轮迭代
# 第9996轮迭代
# 第9997轮迭代
# 第9998轮迭代
# 第9999轮迭代
# 第10000轮迭代

# %%
colors = plt.cm.viridis(np.linspace(0, 1, len(all_projection_errors)))
for i in all_projection_errors:
    plt.plot(all_projection_errors[i],color=colors[i], label=f"window {i}({best_iters[i]-1})",alpha=0.8)
    # plt.axvline(x=best_iters[i], color='r', linestyle='--', label=f"最小误差 (窗口 {i})")
plt.xlabel("N")
plt.ylabel("Error")
plt.legend()
# plt.title("每轮 Pauli 投影误差（最小误差标记）")
plt.grid(False)
plt.show()

# %%
def plot_3d_error_lines(all_projection_errors, best_iters=None, alpha=0.6):
    """
    绘制带半透明效果的 3D 投影误差曲线图，并在图例中加入最佳迭代次数。
    参数：
        all_projection_errors: dict[i] = list of errors
        best_iters: dict[i] = int（最小误差所在迭代）
        alpha: 透明度，0~1，默认 0.6
    """
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    colors = plt.cm.viridis(np.linspace(0, 1, len(all_projection_errors)))
    # 存储图例的标签
    legend_labels = []
    for idx, (window_id, errors) in enumerate(sorted(all_projection_errors.items())):
        T = len(errors)
        x = np.arange(T)
        y = np.full(T, window_id)
        z = np.array(errors)
        # 画半透明曲线
        ax.plot(x, y, z, color=colors[idx], alpha=alpha)
        # 标记误差最小点为红色半透明球（不显示在 legend 中）
        if best_iters is not None:
            best_iter = best_iters[window_id]
            ax.scatter([best_iter-1], [window_id], [z[best_iter-1]], 
                       color='red', s=60, alpha=0.9, label='_nolegend_')
        # 生成图例标签：窗口号 + 最佳迭代次数（括号内）
        if best_iters is not None:
            best_iter = best_iters[window_id]
            legend_labels.append(f"Window {window_id} ({best_iter-1})")
        else:
            legend_labels.append(f"Window {window_id}")
    ax.set_xlabel("N", fontsize=12)
    ax.set_ylabel("Windows", fontsize=12)
    ax.set_zlabel("Error", fontsize=12)
    # ax.set_title("带透明度的三维误差曲线图", fontsize=14)
    ax.view_init(elev=30, azim=-60)  # 设置视角：仰角 & 方位角
    ax.grid(True)
    # 更新图例
    ax.legend(legend_labels)
    plt.tight_layout()
    plt.show()

plot_3d_error_lines(all_projection_errors, best_iters,alpha=0.8)

# %%
def project_H_to_custom_basis(H_local, k, site_offset):
    """
    将 H_local 投影到 {I, Z, X, σ_+ - σ_-} 张量积空间，
    投影时作为整体计算，写入时将 σ_+-σ_- 拆成两项带正负号。
    """
    # 定义可用于 Op 的原子符号
    primitive_ops = {
        "I": np.eye(2, dtype=complex),
        "Z": np.array([[1, 0], [0, -1]], dtype=complex),
        "X": np.array([[0, 1], [1, 0]], dtype=complex),
        "Y": np.array([[0, -1j], [1j, 0]], dtype=np.complex128),
        "sigma_+": np.array([[0, 1], [0, 0]], dtype=complex),
        "sigma_-": np.array([[0, 0], [1, 0]], dtype=complex),
        "sigma_+-sigma_-": np.array([[0, 1], [-1, 0]], dtype=complex),  # 用于投影
    }
    allowed_basis = ["I", "Z", "X", "Y"]
    ops = []
    for label_seq in itertools.product(allowed_basis, repeat=k):
        # 构造投影用的张量算符
        P = primitive_ops[label_seq[0]]
        for label in label_seq[1:]:
            P = np.kron(P, primitive_ops[label])
        coeff = np.trace(P.conj().T @ H_local)/ (2 ** k)
        if abs(coeff) < 1e-15:
            continue
        # 拆解写入 renormalizer 支持的符号组合
        def expand_labels(label):
            if label == "sigma_+-sigma_-":
                return [("sigma_+", 1), ("sigma_-", -1)]
            else:
                return [(label, 1)]

        # 构造所有组合（带系数符号）
        label_choices = [expand_labels(label) for label in label_seq]
        all_combinations = itertools.product(*label_choices)

        for combo in all_combinations:
            labels, signs = zip(*combo)
            symbol = " ".join(labels)
            total_coeff = coeff * np.prod(signs)
            sites = list(range(site_offset, site_offset + k))
            ops.append(Op(symbol, sites, np.complex128(total_coeff)))

    return ops

def compute_fidelity(state1, state2):
    return abs(np.vdot(state1, state2)) ** 2

def run_dmrg_fidelity_selection_renormalizer(
    all_variants,
    n,
    k,
    original_state_vector,
    bond_dim=64,
    procedure=None,
    verbose=True
):
    """
    对 all_penalized_variants 中每一个版本的哈密顿量使用 renormalizer DMRG，
    用 todense() 还原态矢量并计算保真度，选出最优版本。

    参数：
        all_variants: List[Dict[int, ndarray]] — 多版本局部哈密顿量
        n: int — 总 qubit 数
        k: int — 每个 H_local 的作用范围
        original_state_vector: ndarray — 参考态
        bond_dim: int — 默认最大 bond 维度
        procedure: List[[int, float]] — DMRG 多轮扫描策略
        verbose: bool — 是否打印日志

    返回：
        best_mps, best_idx, best_fid
    """
    if procedure is None:
        procedure = [[bond_dim, 0.5], [bond_dim, 0.2], [bond_dim, 0.0], [bond_dim, 0.0]]

    best_fid = -1
    best_idx = -1
    best_mps = None
    best_energy = None

    for idx, svt_rhos in enumerate(all_variants):
        if verbose:
            print(f"\n 正在运行版本 {idx} 的 DMRG...")

            # 1. 构建 Op 项
        ham_terms = []
        for site, H_local in svt_rhos.items():
            ham_terms.extend(project_H_to_custom_basis(H_local, k, site))

            # 2. 构建 Model 和 MPO
        basis = [BasisHalfSpin(i) for i in range(n)]
        model = Model(basis, ham_terms)
        mpo = Mpo(model)

            # 3. 初始化 MPS + 配置 DMRG
        mps = Mps.random(model, 0, bond_dim)
    
        mps.dtype = np.complex128  
        mps.optimize_config.procedure = procedure
        mps.optimize_config.method = "2site"

            # 4. 优化 MPS
        energies, _ = optimize_mps(mps, mpo)
        energy = min(energies)

            # 5. 恢复态矢量 + 保真度计算
        state_vec = mps.todense()
        # print(state_vec)
        state_vec /= np.linalg.norm(state_vec)
        fid = compute_fidelity(original_state_vector, state_vec)

        if verbose:
            print(f" 版本 {idx}：能量 = {energy:.12f}，保真度 = {fid:.12f}")

        if fid > best_fid:
            best_fid = fid
            best_energy = energy
            best_idx = idx
            best_mps = mps
        print(f"\n 最优版本 = {best_idx}，保真度 = {best_fid:.16f}，能量 = {best_energy:.16f}")
    return best_mps, best_idx, best_fid


def penalize_max_eigenstates_chain(svt_Y_rhos_init, num_variants=2**k, shift_per_round=-20.0):
    """
    每一轮将每个 H_i 的最大本征值降低 shift_per_round，生成新哈密顿量版本
    返回：List of svt_Y_rhos 版本
    """
    variants = [svt_Y_rhos_init]

    current = svt_Y_rhos_init
    for _ in range(1, num_variants):
        new_version = {}
        for i, H in current.items():
            eigvals, eigvecs = np.linalg.eigh(H)
            min_idx = np.argmin(eigvals)
            eigvals[min_idx] += shift_per_round  

            H_new = sum(
                eigvals[j] * np.outer(eigvecs[:, j], eigvecs[:, j].conj())
                for j in range(len(eigvals))
            )
            new_version[i] = H_new

        variants.append(new_version)
        current = new_version  

    return variants

# %%
# 禁用 renormalizer 内部所有日志输出
logging.getLogger("renormalizer").setLevel(logging.CRITICAL + 1)
all_penalized_variants = penalize_max_eigenstates_chain(svt_Y_rhos, num_variants=2**k, shift_per_round=20.0)
bond_dim=64
procedure_custom = [
    [bond_dim, 0.5],[bond_dim, 0.4],[bond_dim, 0.2],[bond_dim, 0.0]
]*100

best_mps, best_idx, best_fid = run_dmrg_fidelity_selection_renormalizer(
    all_variants=all_penalized_variants,
    n=n,
    k=k,
    original_state_vector=evolved_state,
    bond_dim=bond_dim,
    procedure=procedure_custom,
    verbose=True
)
print(best_mps.bond_dims)
# Out:
#  正在运行版本 0 的 DMRG...
#  版本 0：能量 = 0.001324568724，保真度 = 0.000000000000
#
#  最优版本 = 0，保真度 = 0.0000000000000000，能量 = 0.0013245687243145
#
#  正在运行版本 1 的 DMRG...
#  版本 1：能量 = 0.012105952599，保真度 = 0.000000000000
#
#  最优版本 = 1，保真度 = 0.0000000000000000，能量 = 0.0121059525989472
#
#  正在运行版本 2 的 DMRG...
#  版本 2：能量 = 0.106981154464，保真度 = 0.000000000000
#
#  最优版本 = 1，保真度 = 0.0000000000000000，能量 = 0.0121059525989472
#
#  正在运行版本 3 的 DMRG...
#  版本 3：能量 = 0.252458564439，保真度 = 0.001450119800
#
#  最优版本 = 3，保真度 = 0.0014501197996223，能量 = 0.2524585644385767
#
#  正在运行版本 4 的 DMRG...
#  版本 4：能量 = 0.480221949478，保真度 = 0.991680473932
#
#  最优版本 = 4，保真度 = 0.9916804739320874，能量 = 0.4802219494775670
#
#  正在运行版本 5 的 DMRG...
#  版本 5：能量 = 0.916427700952，保真度 = 0.991619469254
#
#  最优版本 = 4，保真度 = 0.9916804739320874，能量 = 0.4802219494775670
#
#  正在运行版本 6 的 DMRG...
#  版本 6：能量 = 4.120589554826，保真度 = 0.971458466997
#
#  最优版本 = 4，保真度 = 0.9916804739320874，能量 = 0.4802219494775670
#
#  正在运行版本 7 的 DMRG...
#  版本 7：能量 = 9.822995631431，保真度 = 0.875248820362
#
#  最优版本 = 4，保真度 = 0.9916804739320874，能量 = 0.4802219494775670
# [1, 4, 8, 16, 16, 8, 4, 2, 1]

# %%
evolved_state=best_mps.todense()
mat_YY = build_corr_matrix(evolved_state, "Y", "Y", n)
mat_XY = build_corr_matrix(evolved_state, "X", "Y", n)
mat_ZZ = build_corr_matrix(evolved_state, "Z", "Z", n)

# 绘图
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

for ax, mat, title in zip(
    axs,
    [mat_YY, mat_XY, mat_ZZ],
    [r"Theory: $\langle YY\rangle - \langle Y\rangle\langle Y\rangle$",
     r"Theory: $\langle XY\rangle - \langle X\rangle\langle Y\rangle$",
     r"Theory: $\langle ZZ\rangle - \langle Z\rangle\langle Z\rangle$"]
):
    im = ax.imshow(mat, cmap="bwr", vmin=-0.25, vmax=0.25)  # 设置vmin和vmax以确保一致性
    ax.set_title(title, fontsize=10)
    ax.set_xlabel("Spin", fontsize=10)
    ax.set_ylabel("Spin", fontsize=10)

# 调整子图间距，避免颜色条与图形重叠
fig.subplots_adjust(hspace=0.4, wspace=0.4, right=0.85)  # 调整右侧边距以为颜色条腾出空间

# 将颜色条放置在最右侧，并设置为竖直方向
cbar = fig.colorbar(im, ax=axs.ravel().tolist(), orientation='vertical', shrink=0.4, pad=0.01)
cbar.ax.tick_params(labelsize=10)  # 调整颜色条刻度标签的字体大小

plt.show()
